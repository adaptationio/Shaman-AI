# %%
import numpy as np
import pyautogui
import imutils
import cv2
import pytesseract
from pynput import mouse
import time
import easyocr
import torch
#from PIL import ImageGrab
import pyscreenshot
import pyscreenshot as ImageGrab
#pytesseract.pytesseract.tesseract_cmd = r'C:\Users\adaptation\anaconda3\envs\Shaman-AI\Library\bin\tesseract.exe'
from detecto import core, utils, visualize
from detecto.visualize import show_labeled_image, plot_prediction_grid
from torchvision import transforms
import matplotlib.pyplot as plt
from detecto import utils as ut

# %%
class ImageProcess():
    def __init__(self):
        self.love = "ramona"
        self.reader = easyocr.Reader(['en'])
        self.model = core.Model.load('model_weights.pth', ['bird', 'hole'])

    def on_click(self, x, y, button, pressed):
        if button == mouse.Button.left:
            print('{} at {}'.format('Pressed Left Click' if pressed else 'Released Left Click', (x, y)))
        
            return False # Returning False if you need to stop the program when Left clicked.
        else:
            print('{} at {}'.format('Pressed Right Click' if pressed else 'Released Right Click', (x, y)))
            return False # Returning False if you need to stop the program when Left clicked.

    def get_position(self):
        print("Please select top corner")
        listener = mouse.Listener(on_click=self.on_click)
        listener.start()
        listener.join()
        X=pyautogui.position()
        self.topx = X[0]
        self.topy= X[1]
        time.sleep(1)
        print(self.topx)
        print(self.topy)
        print("Please select bottom corner")
        listener = mouse.Listener(on_click=self.on_click)
        listener.start()
        listener.join()
        B=pyautogui.position()
        self.bottomx = B[0]
        self.bottomy= B[1]
        print(self.bottomx)
        print(self.bottomy)
        return self.topx, self.topy, self.bottomx, self.bottomy

    def object_detection(self):
        state = ImageGrab.grab(bbox=(871, 186, 1227, 821), backend="mss", childprocess=False)
        #state= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
        state = cv2.cvtColor(np.array(state), cv2.COLOR_RGB2GRAY)
        state = cv2.cvtColor(state,cv2.COLOR_GRAY2RGB)
        #state = np.array(state)
        #cv2.imwrite('gray.jpg', state)
        #state = ut.read_image(state) 
        #state= cv2.imread('gray.jpg')
        image = state
        predictions = self.model.predict(image)
        labels, boxes, scores = predictions

        thresh=0.80
        filtered_indices=np.where(scores>thresh)
        filtered_scores=scores[filtered_indices]
        filtered_boxes=boxes[filtered_indices]
        num_list = filtered_indices[0].tolist()
        filtered_labels = [labels[i] for i in num_list]
        #print(filtered_labels)
        if len(filtered_labels) == 2:
            if filtered_labels[0] == "bird":
                bird = filtered_boxes[0]
            else:
                bird = [0,0,0,0]
            if filtered_labels[1] == "hole":
                hole = filtered_boxes[1]
            else:
                hole = [0,0,0,0]
        else:
            try:
                bird = filtered_boxes[0]
                hole = [0,0,0,0]

            except:
                bird = [0,0,0,0]
                hole = [0,0,0,0]
        

        #u = np.concatenate((u), axis=None)
        #m = np.concatenate((m), axis=None)
        #c = np.concatenate((c), axis=None)
        flattened = np.concatenate((bird, hole), axis=None)
        #print(flattened)
        return flattened
        



    def image_ocr(self):
        topx = self.topx
        topy = self.topy
        bottomx = self.bottomx - topx
        bottomy =  self.bottomy - topy
        state= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
        #state = cv2.cvtColor(np.array(state), cv2.COLOR_BGR2GRAY)
        state = cv2.cvtColor(np.array(state), cv2.COLOR_RGB2BGR)
        #cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        text = pytesseract.image_to_string(state)
        print(text)
        return text

    def easy_ocr(self):
        topx = self.topx
        topy = self.topy
        bottomx = self.bottomx - topx
        bottomy =  self.bottomy - topy
        state= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
        state = cv2.cvtColor(np.array(state), cv2.COLOR_RGB2BGR)
        

        #state = 255 - cv2.threshold(state, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

        # Blur and perform text extraction
        #state = cv2.GaussianBlur(state, (3,3), 0)
        #self.reader = easyocr.Reader(['en'])
        result = self.reader.readtext(state)
        return result
    
  
    
    def game_start(self,tx, ty, bx, by):
        topx = tx
        topy = ty
        bottomx = bx - topx
        bottomy = by - topy
        state= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
        state = cv2.cvtColor(np.array(state), cv2.COLOR_RGB2BGR)
        
        

        #state = 255 - cv2.threshold(state, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

        # Blur and perform text extraction
        #state = cv2.GaussianBlur(state, (3,3), 0)
        #self.reader = easyocr.Reader(['en'])
        result = self.reader.readtext(state)
        print(result)
        if len(result) == 1:

            print(result[0][1])
            if result[0][1] == "RESTART":
                return True
            else:
                return False
        else:
            return False

    def game_start_2(self,tx, ty, bx, by, a):
        topx = tx
        topy = ty
        bottomx = bx - topx
        bottomy = by - topy
        #state= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
        state = ImageGrab.grab(bbox=(955, 391, 1019, 406), backend="mss", childprocess=False)
        b = cv2.cvtColor(np.array(state), cv2.COLOR_RGB2BGR)
        difference = cv2.subtract(a, b)    
        result = not np.any(difference)
        if result is True:
            return True
        else:
            return False
        
    def game_start_make(self,tx, ty, bx, by):
        topx = tx
        topy = ty
        bottomx = bx - topx
        bottomy = by - topy
        state= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
        state = cv2.cvtColor(np.array(state), cv2.COLOR_RGB2BGR)
        np.save('games_start.npy', state)
        return state


    def get_state(self,tx, ty, bx, by):
        topx = tx
        topy = ty
        bottomx = bx - topx
        bottomy = by - topy
        state = ImageGrab.grab(bbox=(753, 186, 1227, 821), backend="mss", childprocess=False)
        #state= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
        state = cv2.cvtColor(np.array(state), cv2.COLOR_RGB2GRAY)[..., np.newaxis]
        
        state= cv2.resize(state, (84, 84), interpolation=cv2.INTER_AREA)[..., np.newaxis]
        #cv2.imwrite('red.jpg', state)
        #state = torch.from_numpy(state)
        #state = state.unsqueeze(dim=0)
        return state

    def get_state_save(self,tx, ty, bx, by, count, epoc):
        count = count
        epoc = epoc
        topx = tx
        topy = ty
        bottomx = bx - topx
        bottomy = by - topy
        state = ImageGrab.grab(bbox=(871, 186, 1227, 821), backend="mss", childprocess=False)
        #state= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
        state = cv2.cvtColor(np.array(state), cv2.COLOR_RGB2GRAY)[..., np.newaxis]
        
        #state= cv2.resize(state, (84, 84), interpolation=cv2.INTER_AREA)[..., np.newaxis]
        cv2.imwrite('images/flappy/state'+str(count)+str(epoc)+'.jpeg', state)
        #state = torch.from_numpy(state)
        #state = state.unsqueeze(dim=0)
        return state
    
    def get_state_test(self,tx, ty, bx, by):
        topx = tx
        topy = ty
        bottomx = bx - topx
        bottomy = by - topy
        state= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
        state = cv2.cvtColor(np.array(state), cv2.COLOR_RGB2GRAY)[..., np.newaxis]
        state2= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
        state2 = cv2.cvtColor(np.array(state2), cv2.COLOR_RGB2GRAY)[..., np.newaxis]
        state3= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
        state3 = cv2.cvtColor(np.array(state3), cv2.COLOR_RGB2GRAY)[..., np.newaxis]
        state4= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
        state4 = cv2.cvtColor(np.array(state4), cv2.COLOR_RGB2GRAY)[..., np.newaxis]
        #vis = np.concatenate((state, state2, state3, state4), axis=1)
        vis = np.stack((state, state2, state3, state4))
        #state= cv2.resize(state, (84, 84), interpolation=cv2.INTER_AREA)
        #state = torch.from_numpy(state)
        #state = state.unsqueeze(dim=0)
        return vis

    def get_reward(self,tx, ty, bx, by):
        topx = tx
        topy = ty
        bottomx = bx - topx
        bottomy = by - topy
        state= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
        state = cv2.cvtColor(np.array(state), cv2.COLOR_RGB2BGR)
        
        

        #state = 255 - cv2.threshold(state, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

        # Blur and perform text extraction
        #state = cv2.GaussianBlur(state, (3,3), 0)
        #self.reader = easyocr.Reader(['en'])
        result = self.reader.readtext(state)
    
        print(result)
        if len(result) == 1:

            return int(0)
        if len(result) == 2:
                if result[1][1] == "I": 
                    return int(1)
                elif result[1][1] == "2":
                    return int(2)
                elif result[1][1] == "8":
                    return int(3)
                else:
                    return(4)
        else:
            return int(0)
        
    def image_ocr_2(self):
        topx = self.topx
        topy = self.topy
        bottomx = self.bottomx - topx
        bottomy =  self.bottomy - topy
        custom_config = r'--oem 3 --psm 10'
        image = pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
        gray= cv2.cvtColor(np.array(image), cv2.COLOR_BGR2GRAY)
        thresh = 255 - cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

        # Blur and perform text extraction
        thresh = cv2.GaussianBlur(thresh, (3,3), 0)
        text = pytesseract.image_to_string(thresh, config=custom_config)
        print(text)
        return text

    def image_stream(self):
        topx = self.topx
        topy = self.topy
        bottomx = self.bottomx - topx
        bottomy =  self.bottomy - topy 
        while True:
            try:
                state= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
                state = cv2.cvtColor(np.array(state), cv2.COLOR_RGB2BGR)
                cv2.imshow("Stream", state)
                if cv2.waitKey(1)& 0xFF == ord('q'):
                    break      
            except KeyboardInterrupt:
                cv2.destroyAllWindows()
                break

    def get_image(self, ):
        topx = self.topx
        topy = self.topy
        bottomx = self.bottomx - topx
        bottomy =  self.bottomy - topy
        state= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
        state = cv2.cvtColor(np.array(state), cv2.COLOR_RGB2BGR)
        return state

    def check_image(self, a, b):
        difference = cv2.subtract(a, b)    
        result = not np.any(difference)
        if result is True:
            print("Pictures are the same")
        else:
            print("Pictures are different")

# %%
import pyscreenshot as ImageGrab

# %%
#image = pyscreenshot.grab()
im = ImageGrab.grab(bbox=(753, 186, 1227, 821), backend="mss", childprocess=False)
im.show()

# %%
from PIL import ImageGrab
import pyautogui

emark = ( 1440, 1026 )
pyautogui .click( x=1063, y=544 )

pixel = ( emark[0]-1, emark[1]-1, emark[0]+1, emark[1]+1 )
original_pixel_color = ImageGrab .grab( pixel ) .getpixel( (0,0) )
##  print( original_pixel_color )

def image_grab():
    new_pixel_color = ImageGrab .grab( pixel ) .getpixel( (0,0) )
    return new_pixel_color == original_pixel_color

def clickButton():
    ##  print('yup')
    pyautogui .click( x=1160, y=600 )

while True:
    if not image_grab():
        clickButton()
        ##  I don't know if pyautogui has a built in pause function,  
        ##  or repeat delay, but you probably want a time.sleep(1)
        ##  or similar here, so it doesn't rapid-fire autoclick
        ##  500 times in a row, once that pixel changes color.
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-44-fe31efee88d6> in <module>
# ----> 1 from PIL import ImageGrab
#       2 import pyautogui
#       3
#       4 emark = ( 1440, 1026 )
#       5 pyautogui .click( x=1063, y=544 )
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/PIL/ImageGrab.py in <module>
#      27     import subprocess
#      28 else:
# ---> 29     raise ImportError("ImageGrab is macOS and Windows only")
#      30
#      31
#
# ImportError: ImageGrab is macOS and Windows only

# %%
image_process.image_ocr_2()
#a = image_process.get_image()
image_process

#np.save('test.npy', a)
#a = np.load('test.npy')
#b = image_process.get_image()
#image_process.check_image(a,b)

# %%
image_process = ImageProcess()
image_process.get_position()
#image_process. image_ocr()
#image_process.image_stream()
#image_process.game_start_make(1029, 486, 1030, 487)#
# Out:
# Please select top corner
# Pressed Left Click at (955, 391)
# 955
# 391
# Please select bottom corner
# Pressed Left Click at (1019, 406)
# 1019
# 406
# (955, 391, 1019, 406)

# %%
#image_process.easy_ocr()
#test= image_process.get_reward(959, 392, 1019, 446)
image_process.game_start(859, 455, 974, 479)
test
# Out:
# [([[0, 0], [51, 0], [51, 17], [0, 17]], 'SCOR', 0.9772217869758606)]
# 0

# %%
test = image_process.get_state(752, 188, 1228, 823)
test.shape
# Out:
# (84, 84, 1)

# %%
class FlappyBirdsEnv():
    def __init__(self):
        self.love = 14
        self.actions = [0,1]
        self.state = None
        self.count = 0
        self.load = True
        self.eval = False
        self.image_pro = ImageProcess()
        self.frame = []
        #self.game_start = np.load('games_start.npy')
        #self.game_start2 = pyautogui.pixel(1029, 486)
        self.game_start = ImageGrab.grab(bbox=(955, 391, 1019, 406), backend="mss", childprocess=False)
        self.game_start = cv2.cvtColor(np.array(self.game_start), cv2.COLOR_RGB2BGR)
        self.total_reward = 0
        self.epoc = 0
        #self.emark = (1029, 486)
        #self.pixel = (self.emark[0]-1, self.emark[1]-1, self.emark[0]+1, self.emark[1]+1)
        #self.original_pixel_color = ImageGrab.grab(self.pixel).getpixel((0,0))

    def controller(self):
        jack = "mose"
    
    def state_maker(self):
        frame = self.image_pro.get_state(752, 188, 1228, 823)
        #self.frame.insert(0, frame)
        #elf.frame.pop()
        #state = np.stack((self.frame[0], self.frame[1], self.frame[2], self.frame[3]))
        return frame

    def state_maker_start(self):
        frame = self.image_pro.get_state(752, 188, 1228, 823)
        
        #self.frame.pop()
        return frame

    
        
        rame2 = self.image_pro.get_state(752, 188, 1228, 823)
        frame3 = self.image_pro.get_state(752, 188, 1228, 823)
        frame4 = self.image_pro.get_state(752, 188, 1228, 823)
        self.frame.insert(3, frame)
        self.frame.insert(2, frame2)
        self.frame.insert(1, frame3)
        self.frame.insert(0, frame4)
        state = np.stack((self.frame[0], self.frame[1], self.frame[2], self.frame[3]))
        

    def step(self, action):
        
        self.count += 1
        if action == 1:
            pyautogui.click(x=795, y= 219, button='left')
            #self.rewards = self.rewards - 0.01
        else:
            d=1
        #self.player.action(self.action)
        #time.sleep(0.1)
        #state = self.state_maker()
        #self.image_pro.get_state_save(752, 188, 1228, 823, self.count, self.epoc)
        #self.state = state
        state = self.image_pro.object_detection()
        
        self.rewards = 0.0015
        self.total_reward = self.total_reward + self.rewards
        
        #reward = self.reward(self.get_state(), self.bet_value)
        #self.player.balance += reward
        remainder = self.count % 1
        is_divisible = remainder == 0
        if is_divisible == True:
            done = self.check_start()

        else:
            done = False
        if done == True:
            self.rewards = -1
            self.total_reward = self.total_reward + self.rewards
            print(self.total_reward)
        #time.sleep(0.1)
        
        return state, self.rewards, done

    def check_start(self):
        check = self.image_pro.game_start_2(955, 391, 1019, 406, self.game_start)
        #check = pyautogui.pixelMatchesColor(1029, 486,(222, 216, 149))
        #self.new_pixel_color = ImageGrab.grab(pixel).getpixel((0,0))
        #check = self.new_pixel_color == self.original_pixel_color
        return check



    def reset(self):
        self.total_reward = 0
        #self.player.balance = 0
        self.count = 0
        self.epoc += 1
        for i in range(10000):
            start = self.check_start()
            if start == True:
                pyautogui.click(x=914, y=566, button='left')
                print("start")
                break
            else:
                time.sleep(3)

        #self.make_episode()
        
        #print(len(self.state))
        time.sleep(1)
        pyautogui.click(x=795, y= 219, button='left')
        time.sleep(.425)
        pyautogui.click(x=795, y= 219, button='left')
        time.sleep(.425)
        pyautogui.click(x=795, y= 219, button='left')
        time.sleep(.425)
        pyautogui.click(x=795, y= 219, button='left')
        time.sleep(.425)
        pyautogui.click(x=795, y= 219, button='left')
        time.sleep(.425)
        pyautogui.click(x=795, y= 219, button='left')
        time.sleep(.425)
        pyautogui.click(x=795, y= 219, button='left')
        
        
        
        #state = self.state_maker()
        state = self.image_pro.object_detection()
        self.rewards = 0
        return state

    def render(self):
        print(self.player.balance)

    def reward(self, state):
        reward = 0
    

        return reward
    
    def done(self, count):
        if count == 10000:
            
            return True
        else:
            return False

    def start(self):
        self.something = "lala"

# %%
pyautogui.pixel(1029, 486)
# Out:
# RGB(red=222, green=216, blue=149)

# %%
flappy = FlappyBirdsEnv()

flappy.reset()
flappy.step(1)
# Out:
# [([[12, 8], [124, 8], [124, 34], [12, 34]], 'RESTART', 0.9832305775554079)]
# RESTART
# start
# (array([[[173],
#          [173],
#          [173],
#          ...,
#          [173],
#          [173],
#          [173]],
#
#         [[173],
#          [173],
#          [173],
#          ...,
#          [173],
#          [173],
#          [173]],
#
#         [[173],
#          [173],
#          [173],
#          ...,
#          [173],
#          [173],
#          [173]],
#
#         ...,
#
#         [[210],
#          [210],
#          [210],
#          ...,
#          [210],
#          [210],
#          [210]],
#
#         [[210],
#          [210],
#          [210],
#          ...,
#          [210],
#          [210],
#          [210]],
#
#         [[210],
#          [210],
#          [210],
#          ...,
#          [210],
#          [210],
#          [210]]], dtype=uint8),
#  0.09000000000000001,
#  False)

# %%
remainder = 11 % 10


is_divisible = remainder == 0



print(is_divisible)
# Out:
# False

# %%
class Player():
    def __init__(self):
        self.love = "Ramona"
        self.score = 0
        self.state = []
        self.reward = []
        self.done = False

    #pyautogui.keyDown('shift')  # hold down the shift key
    #pyautogui.press('left')     # press the left arrow key
    #pyautogui.press('left')     # press the left arrow key
    #pyautogui.press('left')     # press the left arrow key
    #pyautogui.keyUp('shift')    # release the shift key

    def action(self, action):
        self.love2 = "ramona"
        
        if action == 0:
            pyautogui.press("space")
        else:   
            pyautogui.keyUp("space")

# %%
import numpy as np
#from .state import *
import gym
from gym import error, spaces, utils
from gym.utils import seeding
import numpy as np

#MAIN WRAPPER FOR THE ENVIRONMENT TO WORK WITH OPEN AI GYM

class Template_Gym(gym.Env):
    metadata = {
        "render.modes": ["human", "rgb_array"],
    }
    #Define Actions
    ACTION = [0,1]

    def __init__(self):
        #self.config = config
        #self.eval= self.config.eval
        self.start = 0
        self.env = FlappyBirdsEnv()
        self.viewer = None
        self.info = None
        self.reward = 0
        self.done = False
        self.state = None
        self.action_dim = 4
        self.state_dim = 32
        self.num_envs = 1
        self.num_envs_per_sub_batch = 1
        self.starter = 0
        self.discrete = True
        
        #self.shape = len(self.env.reset())
        #print(self.shape)
        #self.action_shape = len(self.env.actions)


        #self.df = df
        #self.reward_range = (0, MAX_ACCOUNT_BAL2NCE) 
        if self.discrete:
            # forward or backward in each dimension
            self.action_space = spaces.Discrete(2)
            #self.action_space = spaces.Box(low=np.array([0, 0]), high=np.array([1, 1]), dtype=np.float32)

            # observation is the x, y coordinate of the grid
            #low = np.zeros(0, dtype=int)
            #high =  np.array(1, dtype=int) - np.ones(len(self.maze_size), dtype=int)
            #aud = 3339
            #self.observation_space = spaces.Box(low=-10000, high=10000, shape=(3333,))
            #self.observation_space = spaces.Box(low=0, high=255,shape=(84,84,1), dtype=np.uint8)
            self.observation_space = spaces.Box(low=0, high=255, shape=(8,))
        else:
            # Actions of the format Buy x%, Sell x%, Hold, etc.
            self.action_space = spaces.Box(low=np.array([0, 0]), high=np.array([3, 1]), dtype=np.float32)
            #or
            #self.action_space = spaces.Box(low=np.array([0, 0, 0, 0]), high=np.array([3, 1, 1, 1]), dtype=np.float16)


            # Prices contains the OHCL values for the last five prices
            self.observation_space = spaces.Box(low=0, high=1, shape=(6, 6), dtype=np.float16)

        

        # initial condition
        #self.state = self.env.generate_number()
        self.steps_beyond_done = None

        # Simulation related variables.
        self.seed()
        #self.reset()

        # Just need to initialize the relevant attributes
        self.configure()

    def __del__(self):
        pass

    def configure(self, display=None):
        self.display = display

    def seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def step(self, action):
        #self.state = self.env.generate_number()
        #self.env.display()
        #print(action)
        #self.placement = self.env.placement
        self.next_state, self.reward, self.done= self.env.step(action)
        #self.info = 0
        #print(self.reward)
        self.info = { 'pnl':1, 'nav':1, 'costs':1 }
        #self.next_state = self.next_state.tolist()
        
        #if self.done:
            #print("total pips")
            #print(np.sum(self.total_pips))
            #print(len(self.total_pips))
            #self.starter += 1
            #pass
        return self.next_state, self.reward, self.done, self.info

    def step_async(self, action):
        #self.state = self.env.generate_number()
        #self.env.display()
        #print(action)
        #self.placement = self.env.placement
        self.next_state, self.reward, self.done= self.env.step(action)
        #self.info = 0
        #print(self.reward)
        self.info = { 'pnl':1, 'nav':1, 'costs':1 }
        #self.next_state = self.next_state.tolist()
        
        #if self.done:
            #print("total pips")
            #print(np.sum(self.total_pips))
            #print(len(self.total_pips))
            #self.starter += 1
            #pass
        return self.next_state, self.reward, self.done, self.info

    def step_wait(self):
        #self.state = self.env.generate_number()
        #self.env.display()
        #print(action)
        #self.placement = self.env.placement
        self.next_state, self.reward, self.done= self.env.step(action)
        #self.info = 0
        #print(self.reward)
        self.info = { 'pnl':1, 'nav':1, 'costs':1 }
        #self.next_state = self.next_state.tolist()
        
        #if self.done:
            #print("total pips")
            #print(np.sum(self.total_pips))
            #print(len(self.total_pips))
            #self.starter += 1
            #pass
        return self.next_state, self.reward, self.done, self.info
    

    def reset(self):
        
        self.state = self.env.reset()
        #self.reward = np.array([reward])
        #self.state = self.state.tolist()
        #self.state = np.array([self.state])
        #self.steps_beyond_done = None
        self.done = False
        #self.done = np.array([self.done])
        return self.state

    def is_game_over(self):
        pass
        return

    def render(self, mode="human", close=False):
        #self.env.display()
        pass

        return 


test = Template_Gym()

# %%
import gym
import numpy as np
from gym import spaces

try:
    import cv2  # pytype:disable=import-error

    cv2.ocl.setUseOpenCL(False)
except ImportError:
    cv2 = None

from stable_baselines3.common.type_aliases import GymObs, GymStepReturn

class MaxAndSkipEnv(gym.Wrapper):
    """
    Return only every ``skip``-th frame (frameskipping)

    :param env: the environment
    :param skip: number of ``skip``-th frame
    """

    def __init__(self, env: gym.Env, skip: int = 4):
        gym.Wrapper.__init__(self, env)
        # most recent raw observations (for max pooling across time steps)
        self._obs_buffer = np.zeros((2,) + env.observation_space.shape, dtype=env.observation_space.dtype)
        self._skip = skip

    def step(self, action: int) -> GymStepReturn:
        """
        Step the environment with the given action
        Repeat action, sum reward, and max over last observations.

        :param action: the action
        :return: observation, reward, done, information
        """
        total_reward = 0.0
        done = None
        for i in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            if i == self._skip - 2:
                self._obs_buffer[0] = obs
            if i == self._skip - 1:
                self._obs_buffer[1] = obs
            total_reward += reward
            if done:
                break
        # Note that the observation on the done=True frame
        # doesn't matter
        max_frame = self._obs_buffer.max(axis=0)

        return max_frame, total_reward, done, info


    def reset(self, **kwargs) -> GymObs:
        return self.env.reset(**kwargs)

# %%
class ImageToPyTorch(gym.ObservationWrapper):
    def __init__(self, env):
        super(ImageToPyTorch, self).__init__(env)
        old_shape = self.observation_space.shape
        self.observation_space = gym.spaces.Box(low=0.0, high=1.0,            
                                shape=(old_shape[-1], 
                                old_shape[0], old_shape[1]),
                                dtype=np.float32)
    def observation(self, observation):
        return np.moveaxis(observation, 2, 0)

# %%
class ScaledFloatFrame(gym.ObservationWrapper):
    def observation(self, obs):
        return np.array(obs).astype(np.float32) / 255.0

# %%
class BufferWrapper(gym.ObservationWrapper):
    def __init__(self, env, n_steps, dtype=np.float32):
        super(BufferWrapper, self).__init__(env)
        self.dtype = dtype
        old_space = env.observation_space
        self.observation_space = gym.spaces.Box(old_space.low.repeat(n_steps, axis=0),old_space.high.repeat(n_steps, axis=0),dtype=dtype)
    def reset(self):
        self.buffer = np.zeros_like(self.observation_space.low,dtype=self.dtype)
        return self.observation(self.env.reset())
        
    def observation(self, observation):
        self.buffer[:-1] = self.buffer[1:]
        self.buffer[-1] = observation
        return self.buffer

# %%
class ProcessFrame84(gym.ObservationWrapper):
    def __init__(self, env=None):
        super(ProcessFrame84, self).__init__(env)
        self.observation_space = gym.spaces.Box(low=0, high=255, shape=(84, 84, 1), dtype=np.uint8)
    def observation(self, obs):
        return ProcessFrame84.process(obs)
    @staticmethod 
    def process(frame):
        if frame.size == 84 * 84 * 1:
            img = np.reshape(frame, [84, 84, 1]).astype(np.float32)
            
        elif frame.size == 250 * 160 * 3:
                img = np.reshape(frame, [250, 160, 3]).astype(np.float32)
        else:
            assert False     
        img = img[:, :, 0] * 0.299 + img[:, :, 1] * 0.587 + img[:, :, 2] * 0.114
        resized_screen = cv2.resize(img, (84, 110),interpolation=cv2.INTER_AREA)
        x_t = resized_screen[18:102, :]
        x_t = np.reshape(x_t, [84, 84, 1])
        return x_t.astype(np.uint8)

# %%
class VecFrameStack(gym.ObservationWrapper):
    """
    Frame stacking wrapper for vectorized environment

    :param venv: (VecEnv) the vectorized environment to wrap
    :param n_stack: (int) Number of frames to stack
    """

    def __init__(self, venv, n_stack):
        self.venv = venv
        self.n_stack = n_stack
        wrapped_obs_space = venv.observation_space
        low = np.repeat(wrapped_obs_space.low, self.n_stack, axis=-1)
        high = np.repeat(wrapped_obs_space.high, self.n_stack, axis=-1)
        self.stackedobs = np.zeros((venv.num_envs,) + low.shape, low.dtype)
        observation_space = spaces.Box(low=low, high=high, dtype=venv.observation_space.dtype)
    

    def step_wait(self):
        observations, rewards, dones, infos = self.venv.step_wait()
        last_ax_size = observations.shape[-1]
        self.stackedobs = np.roll(self.stackedobs, shift=-last_ax_size, axis=-1)
        for i, done in enumerate(dones):
            if done:
                if 'terminal_observation' in infos[i]:
                    old_terminal = infos[i]['terminal_observation']
                    new_terminal = np.concatenate(
                        (self.stackedobs[i, ..., :-last_ax_size], old_terminal), axis=-1)
                    infos[i]['terminal_observation'] = new_terminal
                else:
                    warnings.warn(
                        "VecFrameStack wrapping a VecEnv without terminal_observation info")
                self.stackedobs[i] = 0
        self.stackedobs[..., -observations.shape[-1]:] = observations
        return self.stackedobs, rewards, dones, infos


    def reset(self):
        """
        Reset all environments
        """
        obs = self.venv.reset()
        self.stackedobs[...] = 0
        self.stackedobs[..., -obs.shape[-1]:] = obs
        return self.stackedobs

# %%
for i in range(10):
            #
            #self.total_pips = []
            obs = test.reset()
            print(obs.shape)
            print(obs.size)
            state = None
            
            # When using VecEnv, done is a vector
            
            for i in range(100):
                # _states are only useful when using LSTM policies
                #action, state = self.model.predict(obs, state=state, mask=done, deterministic=True)
                obs, rewards , dones, _ = test.step(1)
                if dones == True:
                    break
                #actions, _states = self.model.predict(obs)
                # # here, action, rewards and dones are arrays
                 # # because we are using vectorized env
                #obs, rewards, dones, info = self.env.step(actions)
                #self.total_pips.append(self.env.player.placement)
# Out:
# start
# (84, 84, 1)
# 7056
# []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-129-25dfaefe002a> in <module>
#       2             #
#       3             #self.total_pips = []
# ----> 4             obs = test.reset()
#       5             print(obs.shape)
#       6             print(obs.size)
#
# <ipython-input-102-d20ae92f1fdb> in reset(self)
#     141
#     142     def reset(self):
# --> 143         self.state = self.env.reset()
#     144         #self.reward = np.array([reward])
#     145         #self.state = self.state.tolist()
#
# <ipython-input-101-171fc7654cfd> in reset(self)
#      80                 break
#      81             else:
# ---> 82                 time.sleep(3)
#      83
#      84         #self.make_episode()
#
# KeyboardInterrupt:

# %%
import gym
import numpy as np
from gym import spaces

try:
    import cv2  # pytype:disable=import-error

    cv2.ocl.setUseOpenCL(False)
except ImportError:
    cv2 = None

from stable_baselines3.common.type_aliases import GymObs, GymStepReturn


class NoopResetEnv(gym.Wrapper):
    """
    Sample initial states by taking random number of no-ops on reset.
    No-op is assumed to be action 0.

    :param env: the environment to wrap
    :param noop_max: the maximum value of no-ops to run
    """

    def __init__(self, env: gym.Env, noop_max: int = 30):
        gym.Wrapper.__init__(self, env)
        self.noop_max = noop_max
        self.override_num_noops = None
        self.noop_action = 0
        assert env.unwrapped.get_action_meanings()[0] == "NOOP"
        
    def reset(self, **kwargs) -> np.ndarray:
        self.env.reset(**kwargs)
        if self.override_num_noops is not None:
            noops = self.override_num_noops
        else:
            noops = self.unwrapped.np_random.randint(1, self.noop_max + 1)
        assert noops > 0
        obs = np.zeros(0)
        for _ in range(noops):
            obs, _, done, _ = self.env.step(self.noop_action)
            if done:
                obs = self.env.reset(**kwargs)
        return obs



class FireResetEnv(gym.Wrapper):
    """
    Take action on reset for environments that are fixed until firing.

    :param env: the environment to wrap
    """

    def __init__(self, env: gym.Env):
        gym.Wrapper.__init__(self, env)
        assert env.unwrapped.get_action_meanings()[1] == "FIRE"
        assert len(env.unwrapped.get_action_meanings()) >= 3

    def reset(self, **kwargs) -> np.ndarray:
        self.env.reset(**kwargs)
        obs, _, done, _ = self.env.step(1)
        if done:
            self.env.reset(**kwargs)
        obs, _, done, _ = self.env.step(2)
        if done:
            self.env.reset(**kwargs)
        return obs



class EpisodicLifeEnv(gym.Wrapper):
    """
    Make end-of-life == end-of-episode, but only reset on true game over.
    Done by DeepMind for the DQN and co. since it helps value estimation.

    :param env: the environment to wrap
    """

    def __init__(self, env: gym.Env):
        gym.Wrapper.__init__(self, env)
        self.lives = 0
        self.was_real_done = True

    def step(self, action: int) -> GymStepReturn:
        obs, reward, done, info = self.env.step(action)
        self.was_real_done = done
        # check current lives, make loss of life terminal,
        # then update lives to handle bonus lives
        lives = self.env.unwrapped.ale.lives()
        if 0 < lives < self.lives:
            # for Qbert sometimes we stay in lives == 0 condtion for a few frames
            # so its important to keep lives > 0, so that we only reset once
            # the environment advertises done.
            done = True
        self.lives = lives
        return obs, reward, done, info


    def reset(self, **kwargs) -> np.ndarray:
        """
        Calls the Gym environment reset, only when lives are exhausted.
        This way all states are still reachable even though lives are episodic,
        and the learner need not know about any of this behind-the-scenes.

        :param kwargs: Extra keywords passed to env.reset() call
        :return: the first observation of the environment
        """
        if self.was_real_done:
            obs = self.env.reset(**kwargs)
        else:
            # no-op step to advance from terminal/lost life state
            obs, _, _, _ = self.env.step(0)
        self.lives = self.env.unwrapped.ale.lives()
        return obs



class MaxAndSkipEnv(gym.Wrapper):
    """
    Return only every ``skip``-th frame (frameskipping)

    :param env: the environment
    :param skip: number of ``skip``-th frame
    """

    def __init__(self, env: gym.Env, skip: int = 4):
        gym.Wrapper.__init__(self, env)
        # most recent raw observations (for max pooling across time steps)
        self._obs_buffer = np.zeros((2,) + env.observation_space.shape, dtype=env.observation_space.dtype)
        self._skip = skip

    def step(self, action: int) -> GymStepReturn:
        """
        Step the environment with the given action
        Repeat action, sum reward, and max over last observations.

        :param action: the action
        :return: observation, reward, done, information
        """
        total_reward = 0.0
        done = None
        for i in range(self._skip):
            obs, reward, done, info = self.env.step(action)
            if i == self._skip - 2:
                self._obs_buffer[0] = obs
            if i == self._skip - 1:
                self._obs_buffer[1] = obs
            total_reward += reward
            if done:
                break
        # Note that the observation on the done=True frame
        # doesn't matter
        max_frame = self._obs_buffer.max(axis=0)

        return max_frame, total_reward, done, info


    def reset(self, **kwargs) -> GymObs:
        return self.env.reset(**kwargs)



class ClipRewardEnv(gym.RewardWrapper):
    """
    Clips the reward to {+1, 0, -1} by its sign.

    :param env: the environment
    """

    def __init__(self, env: gym.Env):
        gym.RewardWrapper.__init__(self, env)

    def reward(self, reward: float) -> float:
        """
        Bin reward to {+1, 0, -1} by its sign.

        :param reward:
        :return:
        """
        return np.sign(reward)



class WarpFrame(gym.ObservationWrapper):
    """
    Convert to grayscale and warp frames to 84x84 (default)
    as done in the Nature paper and later work.

    :param env: the environment
    :param width:
    :param height:
    """

    def __init__(self, env: gym.Env, width: int = 84, height: int = 84):
        gym.ObservationWrapper.__init__(self, env)
        self.width = width
        self.height = height
        self.observation_space = spaces.Box(
            low=0, high=255, shape=(self.height, self.width, 1), dtype=env.observation_space.dtype
        )

    def observation(self, frame: np.ndarray) -> np.ndarray:
        """
        returns the current observation from a frame

        :param frame: environment frame
        :return: the observation
        """
        frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
        frame = cv2.resize(frame, (self.width, self.height), interpolation=cv2.INTER_AREA)
        return frame[:, :, None]



class AtariWrapper(gym.Wrapper):
    """
    Atari 2600 preprocessings

    Specifically:

    * NoopReset: obtain initial state by taking random number of no-ops on reset.
    * Frame skipping: 4 by default
    * Max-pooling: most recent two observations
    * Termination signal when a life is lost.
    * Resize to a square image: 84x84 by default
    * Grayscale observation
    * Clip reward to {-1, 0, 1}

    :param env: gym environment
    :param noop_max: max number of no-ops
    :param frame_skip: the frequency at which the agent experiences the game.
    :param screen_size: resize Atari frame
    :param terminal_on_life_loss: if True, then step() returns done=True whenever a life is lost.
    :param clip_reward: If True (default), the reward is clip to {-1, 0, 1} depending on its sign.
    """

    def __init__(
        self,
        env: gym.Env,
        noop_max: int = 30,
        frame_skip: int = 4,
        screen_size: int = 84,
        terminal_on_life_loss: bool = True,
        clip_reward: bool = True,
    ):
        env = NoopResetEnv(env, noop_max=noop_max)
        env = MaxAndSkipEnv(env, skip=frame_skip)
        if terminal_on_life_loss:
            env = EpisodicLifeEnv(env)
        if "FIRE" in env.unwrapped.get_action_meanings():
            env = FireResetEnv(env)
        env = WarpFrame(env, width=screen_size, height=screen_size)
        if clip_reward:
            env = ClipRewardEnv(env)

        super(AtariWrapper, self).__init__(env)

import warnings

import numpy as np
from gym import spaces

from stable_baselines.common.vec_env.base_vec_env import VecEnvWrapper


class VecFrameStack(VecEnvWrapper):
    """
    Frame stacking wrapper for vectorized environment

    :param venv: (VecEnv) the vectorized environment to wrap
    :param n_stack: (int) Number of frames to stack
    """

    def __init__(self, venv, n_stack):
        self.venv = venv
        self.n_stack = n_stack
        wrapped_obs_space = venv.observation_space
        low = np.repeat(wrapped_obs_space.low, self.n_stack, axis=-1)
        high = np.repeat(wrapped_obs_space.high, self.n_stack, axis=-1)
        self.stackedobs = np.zeros((venv.num_envs,) + low.shape, low.dtype)
        observation_space = spaces.Box(low=low, high=high, dtype=venv.observation_space.dtype)
        VecEnvWrapper.__init__(self, venv, observation_space=observation_space)

    def step_wait(self):
        observations, rewards, dones, infos = self.venv.step_wait()
        last_ax_size = observations.shape[-1]
        self.stackedobs = np.roll(self.stackedobs, shift=-last_ax_size, axis=-1)
        for i, done in enumerate(dones):
            if done:
                if 'terminal_observation' in infos[i]:
                    old_terminal = infos[i]['terminal_observation']
                    new_terminal = np.concatenate(
                        (self.stackedobs[i, ..., :-last_ax_size], old_terminal), axis=-1)
                    infos[i]['terminal_observation'] = new_terminal
                else:
                    warnings.warn(
                        "VecFrameStack wrapping a VecEnv without terminal_observation info")
                self.stackedobs[i] = 0
        self.stackedobs[..., -observations.shape[-1]:] = observations
        return self.stackedobs, rewards, dones, infos


    def reset(self):
        """
        Reset all environments
        """
        obs = self.venv.reset()
        self.stackedobs[...] = 0
        self.stackedobs[..., -obs.shape[-1]:] = obs
        return self.stackedobs


    def close(self):
        self.venv.close()

class ProcessFrame84(gym.ObservationWrapper):
    def __init__(self, env=None):
        super(ProcessFrame84, self).__init__(env)
        self.observation_space = gym.spaces.Box(low=0, high=255, shape=(84, 84, 1), dtype=np.uint8)
    def observation(self, obs):
        return ProcessFrame84.process(obs)@staticmethod
    def process(frame):
        if frame.size == 210 * 160 * 3:
                img = np.reshape(frame, [210, 160,  3]).astype(np.float32)
        elif frame.size == 250 * 160 * 3:
            img = np.reshape(frame, [250, 160, 3]).astype(np.float32)
        else:
            assert False     
            mg = img[:, :, 0] * 0.299 + img[:, :, 1] * 0.587 + img[:, :, 2] * 0.114
            resized_screen = cv2.resize(img, (84, 110),interpolation=cv2.INTER_AREA)
            x_t = resized_screen[18:102, :]
            x_t = np.reshape(x_t, [84, 84, 1])
            return x_t.astype(np.uint8)


class BufferWrapper(gym.ObservationWrapper):
    def __init__(self, env, n_steps, dtype=np.float32):
        super(BufferWrapper, self).__init__(env)
        self.dtype = dtype
        old_space = env.observation_space
        self.observation_space = gym.spaces.Box(old_space.low.repeat(n_steps, axis=0),old_space.high.repeat(n_steps, axis=0),dtype=dtype)
    def reset(self):
        self.buffer = np.zeros_like(self.observation_space.low,
        dtype=self.dtype)
        return self.observation(self.env.reset())
        
    def observation(self, observation):
        self.buffer[:-1] = self.buffer[1:]
        self.buffer[-1] = observation
        return self.buffer

# %%
from pynput import keyboard
from pynput.keyboard import Key, Controller
moves =[False, False]

class KeyLogger():
    def __init__(self):
        self.moose = "9"
        self.listener = keyboard.Listener(on_press=self.on_press,on_release=self.on_release)
        self.listener.start()
        self.moves = [False, False, False, False, False]
        self.action = 0
    def on_press(self, key):
        try:
            print('alphanumeric key {0} pressed'.format(
                key.char))
            self.moose = key
            print(key)
            if key.char == '1':
                self.moves[1] = True
            if key.char == '0':
                self.moves[0] = True
            if key.char == '2':
                self.moves[2] = True
            if key.char == '3':
                self.moves[3] = True
            if key.char == '4':
                self.moves[4] = True
                
        
        except AttributeError:
            print('special key {0} pressed'.format(
                key))
        return 

    def on_release(self, key):
        print('{0} released'.format(
            key))
        #self.moose = ''
        moose = key
        if key.char == "0":
            self.moves[0] = False
        if key.char == "1":
            self.moves[1] = False
        if key.char == "2":
            self.moves[2] = False
        if key.char == "3":
            self.moves[3] = False
        if key.char == "4":
            self.moves[4] = False
        if key == keyboard.Key.esc:
            # Stop listener
            return False
    def actions(self):
        if self.moves[3] == True and self.moves[2] == True:
            self.action = 4  
        elif self.moves[1] == True:
            self.action = 1
        elif self.moves[2] == True:
            self.action = 2
        elif self.moves[3] == True:
            self.action = 3
        elif self.moves[3] == True:
            self.action = 3
        

        else:
            self.action = 0
        return self.action




class KeyboardController():
    def __init__(self):
        self.moose = "yeah"
        self.keyboard = Controller()
    
    def press(self, key):
        self.keyboard.press(Key.key)

    def release(self, key):
        self.keyboard.release(Key.key)

    def press_release(self, key):
        self.keyboard.press(Key.key)
        self.keyboard.release(Key.key)
    
    def typeing(self, string):
        self.keyboard.type(string)



from pynput import mouse
from pynput.mouse import Button, Controller

class MouseLogger():
    def __init__(self):
        self.test= "test"
        self.listener = mouse.Listener(on_move=self.on_move,on_click=self.on_click,on_scroll=self.on_scroll)
        self.listener.start()
        self.action = 0
        self.moves = [False, False, False, False, False]
    def on_move(self, x, y):
        print('Pointer moved to {0}'.format(
            (x, y)))

    def on_click(self, x, y, button, pressed):
        print('{0} at {1}'.format(
            'Pressed' if pressed else 'Released',
            (x, y)))
        self.moves[1] = True
        if not pressed:
            # Stop listener
            self.moves[1] = False
            return False

    def on_scroll(self, x, y, dx, dy):
        print('Scrolled {0} at {1}'.format(
            'down' if dy < 0 else 'up',
            (x, y)))

    def listener_block(self):
        with mouse.Listener(
            on_move=self.on_move,
            on_click=self.on_click,
            on_scroll=self.on_scroll) as self.listener:
            self.listener.join()
            
    def actions(self, obs):
        
        if self.moves[3] == True and self.moves[2] == True:
            self.action = 4  
        elif self.moves[1] == True:
            self.action = 1
        elif self.moves[2] == True:
            self.action = 2
        elif self.moves[3] == True:
            self.action = 3
        elif self.moves[3] == True:
            self.action = 3
        
        #a = np.array([0,1])
        else:
            self.action = 0
        r= [(0,None), (1,None)]
        #2 = (np.array(r), None)
        r2 = np.array((1, None))
        #r = ((0,None), (1,None) )
        self.response = (self.action, None)
        return self.response

class MouseController():
    def __init__(self):
        pass
        self.mouse = Controller()

    def mouse_position(self):
        # Read pointer position
        print('The current pointer position is {0}'.format(
        self.mouse.position))
        return self.mouse.position
    
    def mouse_postiion_set(self, x, y):

        # Set pointer position
        self.mouse.position = (x, y)
        print('Now we have moved it to {0}'.format(
        self.mouse.position))

    def mouse_move(self, x, y):
        # Move pointer relative to current position
        self.mouse.move(x, y)

    def mouse_press(self, right=False):
        if right == True:
            self.mouse.press(Button.right)
        else:
            self.mouse.press(Button.left)

    def mouse_release(self, right=False):
        if right == True:
            self.mouse.release(Button.right)
        else:
            self.mouse.release(Button.left)

    def mouse_double_click(self, right=False):
        # Double click; this is different from pressing and releasing
        # twice on Mac OSX
        if right == 'right' or right == True:
            self.mouse.click(Button.right, 2)
        else:
            self.mouse.click(Button.right, 2)

    def mouse_scroll(self, x, y):
        # Scroll two steps down
        self.mouse.scroll(x, y)

# %%
import numpy as np

import gym
from gym import error, spaces, utils
from gym.utils import seeding
import numpy as np
#from .keyboard import KeyboardController, KeyLogger
#from .mouse import MouseController, MouseLogger

class Controller_Gym(gym.Env):
    metadata = {
        "render.modes": ["human", "rgb_array"],
    }
    #Define Actions
    ACTION = [0,1]

    def __init__(self, env):
        self.controlling = True
        self.logging = True
        #self.mouse_logger = MouseLogger()
        #self.mouse_controller = MouseController()
        self.keyboard_logger = KeyLogger()
        #self.keyboard_controller = KeyboardController()
        self.env = env
        self.viewer = None
        self.info = None
        self.reward = None
        self.done = False
        self.state = None
        #self.action_dim = 3
        #self.state_dim = 109
        self.num_envs = 1
        self.num_envs_per_sub_batch = 1
        self.total_pips = []
        #self.player = self.env.player
        #self.pips = self.env.pips
        #self.starter = 0

        # forward or backward in each dimension
        #self.action_space = spaces.Discrete(3)
        self.action_space = self.env.action_space

        # observation is the x, y coordinate of the grid
        #low = np.zeros(0, dtype=int)
        #high =  np.array(1, dtype=int) - np.ones(len(self.maze_size), dtype=int)
        #self.observation_space = spaces.Box(low=-100000, high=100000, shape=(109,))
        self.observation_space = self.env.observation_space
        #print("obs")
        #print (self.observation_space)

        # initial condition
        #self.state = self.env.generate_number()
        self.steps_beyond_done = None

        # Simulation related variables.
        self.seed()
        #self.reset()

        # Just need to initialize the relevant attributes
        self.configure()

    def __del__(self):
        pass

    def configure(self, display=None):
        self.display = display

    def seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def step(self, action):
        #self.state = self.env.generate_number()
        #self.env.display()
        #print(action)
        action = self.keyboard_logger.actions()
        #action = 1
        #self.placement = self.env.placement
        self.next_state, self.reward, self.done, info = self.env.step(action)
        #self.info = 0
        #print(self.reward)
        self.info = { 'pnl':1, 'nav':1, 'costs':1 }
        #self.next_state = self.next_state.tolist()
        #self.total_pips.append(self.pips)
        if self.done:
            pass
        return self.next_state, self.reward, self.done, info

    def reset(self):
        self.state = self.env.reset()
        #self.reward = np.array([reward])
        #self.state = self.state.tolist()
        #self.state = np.array([self.state])
        #self.steps_beyond_done = None
        self.done = False
        #self.done = np.array([self.done])
        return self.state

    def is_game_over(self):
        pass
        return

    def render(self, mode="human", close=False):
        self.env.render()
        #self.env.display()
        pass

        return

# %%
from stable_baselines.gail import generate_expert_traj

from stable_baselines.gail import ExpertDataset

# %%
def pre_train(self, num_e=1, load="saves/m19"):
        env_id = 'default'
        num_e = 1
        log_dir = "saves"
        # Usingenv = make_env() only one expert trajectory
        # you can specify `traj_limitation=-1` for using the whole dataset
        dataset = ExpertDataset(expert_path='default2.npz',traj_limitation=1, batch_size=128)
        env = Template_Gym()
        #env = Controller_Gym(env)
        env = DummyVecEnv([lambda: env])
        env = VecFrameStack(env, n_stack=1)
        #env = make_env()
        #model = GAIL("MlpPolicy", env=env, expert_dataset=dataset, verbose=1)
        #self.env.save_running_average("saves"+self.config.pair)
        model = PPO('CnnPolicy', env, verbose=1)
        #self.model = PPO2.load("saves/m19", self.env, policy=CustomPolicy, tensorboard_log="./default/" )
        #self.env.save_running_average("saves"+self.config.pair)
        # Pretrain the PPO2 model
        model.pretrain(dataset, n_epochs=10000)

        # As an option, you can train the RL agent
        #self.model.learn(int(100000000))

        # Test the pre-trained model
        env = model.get_env()
        #env.save_running_average("saves"+self.config.pair)
        obs = env.reset()

        reward_sum = 0.0
        for _ in range(1000000):
            action, _ = model.predict(obs)
            obs, reward, done, _ = env.step(action)
            reward_sum += reward
            #self.env.render()
            if done:
                print(reward_sum)
                reward_sum = 0.0
                obs = self.env.reset()

        self.env.close()

def gen_pre_train(game, state, num_e=1, save='default2', episodes=10):
    
    env = Template_Gym()
    env = Controller_Gym(env)
    env = DummyVecEnv([lambda: env])
    env = VecFrameStack(env, n_stack=1)
    expert_agent = "moose"
    generate_expert_traj(expert_agent, save, env, n_episodes=episodes)
# Out:
# Pressed at (2247, 207)
# Released at (2247, 207)

# %%
expert = MouseLogger()
test = expert.actions(1)
print(test)
# Out:
# (0, None)
# Pointer moved to (2256, 237)
# Pointer moved to (2257, 238)
# Pointer moved to (2261, 240)
# Pointer moved to (2270, 243)
# Pointer moved to (2272, 244)
# Pointer moved to (2287, 250)
# Pointer moved to (2299, 252)
# Pointer moved to (2320, 257)
# Pointer moved to (2342, 263)
# Pointer moved to (2366, 274)
# Pointer moved to (2383, 280)
# Pointer moved to (2405, 290)
# Pointer moved to (2424, 303)
# Pointer moved to (2437, 307)
# Pointer moved to (2439, 308)
# Pointer moved to (2441, 309)
# Pointer moved to (2444, 309)
# Pointer moved to (2446, 310)
# Pointer moved to (2447, 310)
# Pointer moved to (2447, 311)
# Pointer moved to (2449, 311)
# Pointer moved to (2450, 311)
# Pointer moved to (2451, 311)
# Pointer moved to (2452, 310)
# Pointer moved to (2454, 309)
# Pointer moved to (2456, 308)
# Pointer moved to (2457, 307)
# Pointer moved to (2458, 306)
# Pointer moved to (2459, 305)
# Pointer moved to (2460, 305)
# Pointer moved to (2460, 303)
# Pointer moved to (2460, 302)
# Pointer moved to (2460, 301)
# Pointer moved to (2460, 300)
# Pointer moved to (2459, 300)
# Pointer moved to (2458, 300)
# Pointer moved to (2457, 299)
# Pointer moved to (2455, 299)
# Pointer moved to (2453, 299)
# Pointer moved to (2451, 298)
# Pointer moved to (2450, 298)
# Pointer moved to (2447, 297)
# Pointer moved to (2445, 297)
# Pointer moved to (2444, 297)
# Pointer moved to (2444, 296)
# Pointer moved to (2443, 296)
# Pointer moved to (2441, 296)
# Pointer moved to (2437, 296)
# Pointer moved to (2435, 296)
# Pointer moved to (2431, 296)
# Pointer moved to (2429, 296)
# Pointer moved to (2425, 296)
# Pointer moved to (2422, 296)
# Pointer moved to (2419, 296)
# Pointer moved to (2418, 296)
# Pointer moved to (2417, 296)
# Pointer moved to (2416, 296)
# Pointer moved to (2415, 296)
# Pointer moved to (2413, 296)
# Pointer moved to (2411, 296)
# Pointer moved to (2409, 296)
# Pointer moved to (2405, 297)
# Pointer moved to (2404, 297)
# Pointer moved to (2402, 297)
# Pointer moved to (2399, 297)
# Pointer moved to (2396, 297)
# Pointer moved to (2395, 297)
# Pointer moved to (2394, 297)
# Pointer moved to (2393, 297)
# Pointer moved to (2391, 297)
# Pointer moved to (2390, 297)
# Pointer moved to (2389, 297)
# Pointer moved to (2388, 297)
# Pointer moved to (2386, 297)
# Pointer moved to (2385, 297)
# Pointer moved to (2384, 297)
# Pointer moved to (2383, 297)
# Pointer moved to (2382, 297)
# Pointer moved to (2381, 297)
# Pointer moved to (2380, 297)
# Pointer moved to (2379, 297)
# Pointer moved to (2378, 297)
# Pointer moved to (2377, 297)
# Pointer moved to (2376, 296)
# Pointer moved to (2375, 296)
# Pointer moved to (2374, 295)
# Pointer moved to (2373, 295)
# Pointer moved to (2372, 294)
# Pointer moved to (2370, 294)
# Pointer moved to (2369, 293)
# Pointer moved to (2368, 292)
# Pointer moved to (2367, 292)
# Pointer moved to (2367, 291)
# Pointer moved to (2367, 290)
# Pointer moved to (2367, 289)
# Pointer moved to (2367, 288)
# Pointer moved to (2367, 287)
# Pointer moved to (2367, 286)
# Pointer moved to (2367, 285)
# Pointer moved to (2367, 286)
# Pointer moved to (2367, 287)
# Pointer moved to (2367, 289)
# Pointer moved to (2367, 291)
# Pointer moved to (2367, 292)
# Pointer moved to (2367, 293)
# Pointer moved to (2367, 294)
# Pointer moved to (2367, 295)
# Pointer moved to (2369, 295)
# Pointer moved to (2370, 295)
# Pointer moved to (2374, 295)
# Pointer moved to (2376, 295)
# Pointer moved to (2380, 295)
# Pointer moved to (2383, 295)
# Pointer moved to (2384, 295)
# Pointer moved to (2385, 294)
# Pointer moved to (2388, 294)
# Pointer moved to (2389, 293)
# Pointer moved to (2389, 294)
# Pointer moved to (2391, 295)
# Pointer moved to (2394, 296)
# Pointer moved to (2397, 296)
# Pointer moved to (2399, 297)
# Pointer moved to (2401, 297)
# Pointer moved to (2404, 297)
# Pointer moved to (2406, 297)
# Pointer moved to (2408, 297)
# Pointer moved to (2409, 297)
# Pointer moved to (2410, 297)
# Pointer moved to (2412, 297)
# Pointer moved to (2413, 297)
# Pointer moved to (2412, 297)
# Pointer moved to (2409, 297)
# Pointer moved to (2404, 297)
# Pointer moved to (2402, 297)
# Pointer moved to (2394, 297)
# Pointer moved to (2381, 297)
# Pointer moved to (2371, 295)
# Pointer moved to (2358, 292)
# Pointer moved to (2344, 288)
# Pointer moved to (2330, 285)
# Pointer moved to (2330, 284)
# Pointer moved to (2319, 281)
# Pointer moved to (2314, 278)
# Pointer moved to (2312, 278)
# Pointer moved to (2310, 275)
# Pointer moved to (2308, 275)
# Pointer moved to (2307, 274)
# Pointer moved to (2307, 278)
# Pointer moved to (2307, 281)
# Pointer moved to (2307, 283)
# Pointer moved to (2307, 286)
# Pointer moved to (2307, 293)
# Pointer moved to (2308, 297)
# Pointer moved to (2310, 303)
# Pointer moved to (2310, 308)
# Pointer moved to (2312, 317)
# Pointer moved to (2312, 322)
# Pointer moved to (2314, 328)
# Pointer moved to (2315, 336)
# Pointer moved to (2317, 342)
# Pointer moved to (2317, 344)
# Pointer moved to (2317, 343)
# Pointer moved to (2317, 341)
# Pointer moved to (2317, 339)
# Pointer moved to (2317, 336)
# Pointer moved to (2317, 335)
# Pointer moved to (2313, 327)
# Pointer moved to (2308, 319)
# Pointer moved to (2306, 316)
# Pointer moved to (2301, 307)
# Pointer moved to (2299, 298)
# Pointer moved to (2294, 286)
# Pointer moved to (2290, 272)
# Pointer moved to (2288, 264)
# Pointer moved to (2285, 260)
# Pointer moved to (2284, 254)
# Pointer moved to (2283, 253)
# Pointer moved to (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 252)
# Scrolled down at (2282, 252)
# Pointer moved to (2282, 254)
# Pointer moved to (2282, 260)
# Pointer moved to (2282, 269)
# Pointer moved to (2283, 275)
# Pointer moved to (2289, 292)
# Pointer moved to (2307, 325)
# Pointer moved to (2308, 338)
# Pointer moved to (2323, 376)
# Pointer moved to (2333, 416)
# Pointer moved to (2340, 433)
# Pointer moved to (2349, 459)
# Pointer moved to (2353, 464)
# Pointer moved to (2353, 471)
# Pointer moved to (2353, 480)
# Pointer moved to (2354, 486)
# Pointer moved to (2361, 501)
# Pointer moved to (2379, 535)
# Pointer moved to (2407, 582)
# Pointer moved to (2415, 596)
# Pointer moved to (2443, 634)
# Pointer moved to (2465, 656)
# Pointer moved to (2469, 667)
# Pointer moved to (2472, 668)
# Pointer moved to (2472, 669)
# Pointer moved to (2472, 675)
# Pointer moved to (2472, 682)
# Pointer moved to (2473, 686)
# Pointer moved to (2475, 692)
# Pointer moved to (2479, 698)
# Pointer moved to (2490, 715)
# Pointer moved to (2508, 735)
# Pointer moved to (2524, 761)
# Pointer moved to (2525, 765)
# Pointer moved to (2537, 784)
# Pointer moved to (2547, 797)
# Pointer moved to (2553, 803)
# Pointer moved to (2555, 803)
# Pressed at (2555, 803)
# Released at (2555, 803)

# %%
from collections import deque
import numpy as np
from gym.spaces import Box
from gym import ObservationWrapper


class LazyFrames(object):
    r"""Ensures common frames are only stored once to optimize memory use.
    To further reduce the memory use, it is optionally to turn on lz4 to
    compress the observations.
    .. note::
        This object should only be converted to numpy array just before forward pass.
    Args:
        lz4_compress (bool): use lz4 to compress the frames internally
    """
    __slots__ = ("frame_shape", "dtype", "shape", "lz4_compress", "_frames")

    def __init__(self, frames, lz4_compress=False):
        self.frame_shape = tuple(frames[0].shape)
        self.shape = (len(frames),) + self.frame_shape
        self.dtype = frames[0].dtype
        if lz4_compress:
            from lz4.block import compress

            frames = [compress(frame) for frame in frames]
        self._frames = frames
        self.lz4_compress = lz4_compress

    def __array__(self, dtype=None):
        arr = self[:]
        if dtype is not None:
            return arr.astype(dtype)
        return arr

    def __len__(self):
        return self.shape[0]

    def __getitem__(self, int_or_slice):
        if isinstance(int_or_slice, int):
            return self._check_decompress(self._frames[int_or_slice])  # single frame
        return np.stack(
            [self._check_decompress(f) for f in self._frames[int_or_slice]], axis=0
        )

    def __eq__(self, other):
        return self.__array__() == other

    def _check_decompress(self, frame):
        if self.lz4_compress:
            from lz4.block import decompress

            return np.frombuffer(decompress(frame), dtype=self.dtype).reshape(
                self.frame_shape
            )
        return frame


class FrameStack(ObservationWrapper):
    r"""Observation wrapper that stacks the observations in a rolling manner.
    For example, if the number of stacks is 4, then the returned observation contains
    the most recent 4 observations. For environment 'Pendulum-v0', the original observation
    is an array with shape [3], so if we stack 4 observations, the processed observation
    has shape [4, 3].
    .. note::
        To be memory efficient, the stacked observations are wrapped by :class:`LazyFrame`.
    .. note::
        The observation space must be `Box` type. If one uses `Dict`
        as observation space, it should apply `FlattenDictWrapper` at first.
    Example::
        >>> import gym
        >>> env = gym.make('PongNoFrameskip-v0')
        >>> env = FrameStack(env, 4)
        >>> env.observation_space
        Box(4, 210, 160, 3)
    Args:
        env (Env): environment object
        num_stack (int): number of stacks
        lz4_compress (bool): use lz4 to compress the frames internally
    """

    def __init__(self, env, num_stack, lz4_compress=False):
        super(FrameStack, self).__init__(env)
        self.num_stack = num_stack
        self.lz4_compress = lz4_compress

        self.frames = deque(maxlen=num_stack)

        low = np.repeat(self.observation_space.low[np.newaxis, ...], num_stack, axis=0)
        high = np.repeat(
            self.observation_space.high[np.newaxis, ...], num_stack, axis=0
        )
        self.observation_space = Box(
            low=low, high=high, dtype=self.observation_space.dtype
        )

    def observation(self):
        assert len(self.frames) == self.num_stack, (len(self.frames), self.num_stack)
        return LazyFrames(list(self.frames), self.lz4_compress)

    def step(self, action):
        observation, reward, done, info = self.env.step(action)
        self.frames.append(observation)
        return self.observation(), reward, done, info

    def reset(self, **kwargs):
        observation = self.env.reset(**kwargs)
        [self.frames.append(observation) for _ in range(self.num_stack)]
        return self.observation()

# %%
import gym
from tqdm import tqdm
import numpy as np

import torch as th
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR

from stable_baselines3 import PPO, A2C, SAC, TD3
from stable_baselines3.common.evaluation import evaluate_policy

# Example for continuous actions
# env_id = "LunarLanderContinuous-v2"

# Example for discrete actions
#env_id = "CartPole-v1"

#env = gym.make(env_id)
env = Template_Gym()
#env = FrameStack(env, 4)
#env = Controller_Gym(env)
#env = DummyVecEnv([lambda: env])
#env = VecFrameStack(env, n_stack=1)
"""## Train Expert Model

We create an expert RL agent and let it learn to solve a task by interacting with the evironment.

"""

#ppo_expert = PPO('CnnPolicy', env, verbose=1, create_eval_env=True)
#ppo_expert.learn(total_timesteps=3e4, eval_freq=10000)
#ppo_expert.save("ppo_expert")
expert = MouseLogger()
"""check the performance of the trained agent"""

#mean_reward, std_reward = evaluate_policy(expert, env, n_eval_episodes=10)

#print(f"Mean reward = {mean_reward} +/- {std_reward}")

"""## Create Student

We also create a student RL agent, which will later be trained with the expert dataset

"""

ppo_student = PPO('CnnPolicy', env, verbose=1)

# only valid for continuous actions
# sac_student = SAC('MlpPolicy', env_id, verbose=1, policy_kwargs=dict(net_arch=[64, 64]))

"""
We now let our expert interact with the environment (except we already have expert data) and store resultant expert observations and actions to build an expert dataset.
"""

num_interactions = int(500)

if isinstance(env.action_space, gym.spaces.Box):
  expert_observations = np.empty((num_interactions,) + env.observation_space.shape)
  expert_actions = np.empty((num_interactions,) + (env.action_space.shape[0],))

else:
  expert_observations = np.empty((num_interactions,) + env.observation_space.shape)
  expert_actions = np.empty((num_interactions,) + env.action_space.shape)

obs = env.reset()

for i in tqdm(range(num_interactions)):
    action, _ = expert.actions(obs)
    print(action)
    expert_observations[i] = obs
    expert_actions[i] = action
    obs, reward, done, info = env.step(action)
    if done:
        obs = env.reset()

np.savez_compressed(
    "expert_data",
    expert_actions=expert_actions,
    expert_observations=expert_observations,
)

"""

- To seamlessly use PyTorch in the training process, we subclass an `ExpertDataset` from PyTorch's base `Dataset`.
- Note that we initialize the dataset with the previously generated expert observations and actions.
- We further implement Python's `__getitem__` and `__len__` magic functions to allow PyTorch's dataset-handling to access arbitrary rows in the dataset and inform it about the length of the dataset.
- For more information about PyTorch's datasets, you can read: https://pytorch.org/docs/stable/data.html.
"""
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# Pointer moved to (914, 566)
# Pointer moved to (914, 566)
# Pressed at (914, 566)
# Pointer moved to (914, 566)
# Released at (914, 566)
# start
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0
#   0%|          | 1/500 [00:00<02:11,  3.81it/s]
# 0
#   0%|          | 2/500 [00:00<02:14,  3.70it/s]
# 0
#   1%|          | 3/500 [00:00<02:12,  3.75it/s]
# 0
#   1%|          | 4/500 [00:01<02:11,  3.76it/s]
# 0
#   1%|          | 5/500 [00:01<02:12,  3.74it/s]
# 0
#   1%|          | 6/500 [00:01<02:11,  3.75it/s]
# 0
#   1%|▏         | 7/500 [00:01<02:10,  3.77it/s]
# 0
#   2%|▏         | 8/500 [00:02<02:08,  3.83it/s]
# 0
#   2%|▏         | 9/500 [00:02<02:09,  3.80it/s]
# 0
# [([[0, 0], [51, 0], [51, 17], [0, 17]], 'SCOR', 0.9772217869758606)]
# start
#   2%|▏         | 10/500 [00:08<16:13,  1.99s/it]
# 0
#   2%|▏         | 11/500 [00:08<11:59,  1.47s/it]
# 0
#   2%|▏         | 12/500 [00:08<08:58,  1.10s/it]
# 0
#   3%|▎         | 13/500 [00:09<06:54,  1.18it/s]
# 0
#   3%|▎         | 14/500 [00:09<05:25,  1.49it/s]
# 0
#   3%|▎         | 15/500 [00:09<04:25,  1.82it/s]
# 0
#   3%|▎         | 16/500 [00:09<03:46,  2.14it/s]
# 0
#   3%|▎         | 17/500 [00:10<03:16,  2.46it/s]
# 0
#   4%|▎         | 18/500 [00:10<02:56,  2.73it/s]
# 0
#   4%|▍         | 19/500 [00:10<02:41,  2.97it/s]
# 0
# [([[0, 0], [51, 0], [51, 17], [0, 17]], 'SCOR', 0.9772217869758606)]
# start
#   4%|▍         | 20/500 [00:16<15:54,  1.99s/it]
# 0
#   4%|▍         | 21/500 [00:16<11:46,  1.47s/it]
# 0
#   4%|▍         | 22/500 [00:17<08:51,  1.11s/it]
# 0
#   5%|▍         | 23/500 [00:17<06:48,  1.17it/s]
# 0
#   5%|▍         | 24/500 [00:17<05:24,  1.47it/s]
# 0
#   5%|▌         | 25/500 [00:17<04:24,  1.80it/s]
# 0
#   5%|▌         | 26/500 [00:18<03:44,  2.11it/s]
# 0
#   5%|▌         | 27/500 [00:18<03:13,  2.45it/s]
# 0
#   6%|▌         | 28/500 [00:18<02:52,  2.74it/s]
# 0
#   6%|▌         | 29/500 [00:19<05:10,  1.52it/s]
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-7de232f3f308> in <module>
#      71     expert_observations[i] = obs
#      72     expert_actions[i] = action
# ---> 73     obs, reward, done, info = env.step(action)
#      74     if done:
#      75         obs = env.reset()
#
# <ipython-input-34-d20ae92f1fdb> in step(self, action)
#      87         #print(action)
#      88         #self.placement = self.env.placement
# ---> 89         self.next_state, self.reward, self.done= self.env.step(action)
#      90         #self.info = 0
#      91         #print(self.reward)
#
# <ipython-input-33-634dcdc3c0f7> in step(self, action)
#      47             d=1
#      48         #self.player.action(self.action)
# ---> 49         state = self.state_maker()
#      50
#      51         ##self.rewards += 0.1
#
# <ipython-input-33-634dcdc3c0f7> in state_maker(self)
#      15
#      16     def state_maker(self):
# ---> 17         frame = self.image_pro.get_state(752, 188, 1228, 823)
#      18         #self.frame.insert(0, frame)
#      19         #elf.frame.pop()
#
# <ipython-input-3-31d54f8c157a> in get_state(self, tx, ty, bx, by)
#     124         bottomx = bx - topx
#     125         bottomy = by - topy
# --> 126         state= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
#     127         state = cv2.cvtColor(np.array(state), cv2.COLOR_RGB2GRAY)[..., np.newaxis]
#     128
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/pyscreeze/__init__.py in _screenshot_linux(imageFilename, region)
#     502         tmpFilename = imageFilename
#     503     if scrotExists:
# --> 504         subprocess.call(['scrot', '-z', tmpFilename])
#     505         im = Image.open(tmpFilename)
#     506
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/subprocess.py in call(timeout, *popenargs, **kwargs)
#     287     with Popen(*popenargs, **kwargs) as p:
#     288         try:
# --> 289             return p.wait(timeout=timeout)
#     290         except:
#     291             p.kill()
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/subprocess.py in wait(self, timeout, endtime)
#    1475                         if self.returncode is not None:
#    1476                             break  # Another thread waited.
# -> 1477                         (pid, sts) = self._try_wait(0)
#    1478                         # Check the pid and loop as waitpid has been known to
#    1479                         # return 0 even without WNOHANG in odd situations.
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/subprocess.py in _try_wait(self, wait_flags)
#    1422             """All callers to this function MUST hold self._waitpid_lock."""
#    1423             try:
# -> 1424                 (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1425             except ChildProcessError:
#    1426                 # This happens if SIGCLD is set to be ignored or waiting
#
# KeyboardInterrupt:

# %%
from torch.utils.data.dataset import Dataset, random_split

class ExpertDataSet(Dataset):
    def __init__(self, expert_observations, expert_actions):
        self.observations = expert_observations
        self.actions = expert_actions
        
    def __getitem__(self, index):
        return (self.observations[index], self.actions[index])

    def __len__(self):
        return len(self.observations)

"""

We now instantiate the `ExpertDataSet` and split it into training and test datasets.
"""

expert_dataset = ExpertDataSet(expert_observations, expert_actions)

train_size = int(0.8 * len(expert_dataset))

test_size = len(expert_dataset) - train_size

train_expert_dataset, test_expert_dataset = random_split(
    expert_dataset, [train_size, test_size]
)

print("test_expert_dataset: ", len(test_expert_dataset))
print("train_expert_dataset: ", len(train_expert_dataset))

"""

NOTE: The supervised learning section of this code is adapted from: https://github.com/pytorch/examples/blob/master/mnist/main.py
1. We extract the policy network of our RL student agent.
2. We load the (labeled) expert dataset containing expert observations as inputs and expert actions as targets.
3. We perform supervised learning, that is, we adjust the policy network's parameters such that given expert observations as inputs to the network, its outputs match the targets (expert actions).
By training the policy network in this way the corresponding RL student agent is taught to behave like the expert agent that was used to created the expert dataset (Behavior Cloning).
"""

def pretrain_agent(
    student,
    batch_size=64,
    epochs=1000,
    scheduler_gamma=0.7,
    learning_rate=1.0,
    log_interval=100,
    no_cuda=True,
    seed=1,
    test_batch_size=64,
):
    use_cuda = not no_cuda and th.cuda.is_available()
    th.manual_seed(seed)
    device = th.device("cuda" if use_cuda else "cpu")
    kwargs = {"num_workers": 1, "pin_memory": True} if use_cuda else {}

    if isinstance(env.action_space, gym.spaces.Box):
      criterion = nn.MSELoss()
    else:
      criterion = nn.CrossEntropyLoss()

    # Extract initial policy
    model = student.policy.to(device)

    def train(model, device, train_loader, optimizer):
        model.train()

        for batch_idx, (data, target) in enumerate(train_loader):
            data, target = data.to(device), target.to(device)
            optimizer.zero_grad()

            if isinstance(env.action_space, gym.spaces.Box):
              # A2C/PPO policy outputs actions, values, log_prob
              # SAC/TD3 policy outputs actions only
              if isinstance(student, (A2C, PPO)):
                action, _, _ = model(data)
              else:
                # SAC/TD3:
                action = model(data)
              action_prediction = action.double()
            else:
              # Retrieve the logits for A2C/PPO when using discrete actions
              latent_pi, _, _ = model._get_latent(data)
              logits = model.action_net(latent_pi)
              action_prediction = logits
              target = target.long()

            loss = criterion(action_prediction, target)
            loss.backward()
            optimizer.step()
            if batch_idx % log_interval == 0:
                print(
                    "Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
                        epoch,
                        batch_idx * len(data),
                        len(train_loader.dataset),
                        100.0 * batch_idx / len(train_loader),
                        loss.item(),
                    )
                )
    def test(model, device, test_loader):
        model.eval()
        test_loss = 0
        with th.no_grad():
            for data, target in test_loader:
                data, target = data.to(device), target.to(device)

                if isinstance(env.action_space, gym.spaces.Box):
                  # A2C/PPO policy outputs actions, values, log_prob
                  # SAC/TD3 policy outputs actions only
                  if isinstance(student, (A2C, PPO)):
                    action, _, _ = model(data)
                  else:
                    # SAC/TD3:
                    action = model(data)
                  action_prediction = action.double()
                else:
                  # Retrieve the logits for A2C/PPO when using discrete actions
                  latent_pi, _, _ = model._get_latent(data)
                  logits = model.action_net(latent_pi)
                  action_prediction = logits
                  target = target.long()

                test_loss = criterion(action_prediction, target)
        test_loss /= len(test_loader.dataset)
        print(f"Test set: Average loss: {test_loss:.4f}")

    # Here, we use PyTorch `DataLoader` to our load previously created `ExpertDataset` for training
    # and testing
    train_loader = th.utils.data.DataLoader(
        dataset=train_expert_dataset, batch_size=batch_size, shuffle=True, **kwargs
    )
    test_loader = th.utils.data.DataLoader(
        dataset=test_expert_dataset, batch_size=test_batch_size, shuffle=True, **kwargs,
    )

    # Define an Optimizer and a learning rate schedule.
    optimizer = optim.Adadelta(model.parameters(), lr=learning_rate)
    scheduler = StepLR(optimizer, step_size=1, gamma=scheduler_gamma)

    # Now we are finally ready to train the policy model.
    for epoch in range(1, epochs + 1):
        train(model, device, train_loader, optimizer)
        test(model, device, test_loader)
        scheduler.step()

    # Implant the trained policy network back into the RL student agent
    ppo_student.policy = model

"""Evaluate the agent before pretraining, it should be random"""

mean_reward, std_reward = evaluate_policy(ppo_student, env, n_eval_episodes=10)

print(f"Mean reward = {mean_reward} +/- {std_reward}")

"""

Having defined the training procedure we can now run the pretraining!
"""

pretrain_agent(
    ppo_student,
    epochs=10000000,
    scheduler_gamma=0.7,
    learning_rate=1.0,
    log_interval=100,
    no_cuda=True,
    seed=1,
    batch_size=64,
    test_batch_size=1000,
)
ppo_student.save("a2c_student")

"""

Finally, let us test how well our RL agent student learned to mimic the behavior of the expert
"""

mean_reward, std_reward = evaluate_policy(ppo_student, env, n_eval_episodes=10)

print(f"Mean reward = {mean_reward} +/- {std_reward}")
# Out:
# test_expert_dataset:  100
# train_expert_dataset:  400
# /home/adaptationai/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines3/common/evaluation.py:69: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# start
# [([[0, 0], [51, 0], [51, 17], [0, 17]], 'SCOR', 0.9772217869758606)]
# start
# [([[0, 0], [51, 0], [51, 17], [0, 17]], 'SCOR', 0.9772217869758606)]
# start
# [([[0, 0], [51, 0], [51, 17], [0, 17]], 'SCOR', 0.9772217869758606)]
# start
# [([[0, 0], [51, 0], [51, 17], [0, 17]], 'SCOR', 0.9772217869758606)]
# start
# [([[0, 0], [51, 0], [51, 17], [0, 17]], 'SCOR', 0.9772217869758606)]
# start
# [([[0, 0], [51, 0], [51, 17], [0, 17]], 'SCOR', 0.9772217869758606)]
# start
# [([[0, 0], [51, 0], [51, 17], [0, 17]], 'SCOR', 0.9772217869758606)]
# start
# [([[0, 0], [51, 0], [51, 17], [0, 17]], 'SCOR', 0.9772217869758606)]
# start
# [([[0, 0], [51, 0], [51, 17], [0, 17]], 'SCOR', 0.9772217869758606)]
# start
# [([[0, 0], [51, 0], [51, 17], [0, 17]], 'SCOR', 0.9772217869758606)]
# start
# Mean reward = 0.0 +/- 0.0
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-32-d2f7b6243d3f> in <module>
#     168     seed=1,
#     169     batch_size=64,
# --> 170     test_batch_size=1000,
#     171 )
#     172 ppo_student.save("a2c_student")
#
# <ipython-input-32-d2f7b6243d3f> in pretrain_agent(student, batch_size, epochs, scheduler_gamma, learning_rate, log_interval, no_cuda, seed, test_batch_size)
#     141     # Now we are finally ready to train the policy model.
#     142     for epoch in range(1, epochs + 1):
# --> 143         train(model, device, train_loader, optimizer)
#     144         test(model, device, test_loader)
#     145         scheduler.step()
#
# <ipython-input-32-d2f7b6243d3f> in train(model, device, train_loader, optimizer)
#      81             else:
#      82               # Retrieve the logits for A2C/PPO when using discrete actions
# ---> 83               latent_pi, _, _ = model._get_latent(data)
#      84               logits = model.action_net(latent_pi)
#      85               action_prediction = logits
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines3/common/policies.py in _get_latent(self, obs)
#     579         """
#     580         # Preprocess the observation if needed
# --> 581         features = self.extract_features(obs)
#     582         latent_pi, latent_vf = self.mlp_extractor(features)
#     583
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines3/common/policies.py in extract_features(self, obs)
#     126         assert self.features_extractor is not None, "No features extractor was set"
#     127         preprocessed_obs = preprocess_obs(obs, self.observation_space, normalize_images=self.normalize_images)
# --> 128         return self.features_extractor(preprocessed_obs)
#     129
#     130     def _get_constructor_parameters(self) -> Dict[str, Any]:
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines3/common/torch_layers.py in forward(self, observations)
#      91
#      92     def forward(self, observations: th.Tensor) -> th.Tensor:
# ---> 93         return self.linear(self.cnn(observations))
#      94
#      95
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/torch/nn/modules/container.py in forward(self, input)
#     137     def forward(self, input):
#     138         for module in self:
# --> 139             input = module(input)
#     140         return input
#     141
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     441
#     442     def forward(self, input: Tensor) -> Tensor:
# --> 443         return self._conv_forward(input, self.weight, self.bias)
#     444
#     445 class Conv3d(_ConvNd):
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     438                             _pair(0), self.dilation, self.groups)
#     439         return F.conv2d(input, weight, bias, self.stride,
# --> 440                         self.padding, self.dilation, self.groups)
#     441
#     442     def forward(self, input: Tensor) -> Tensor:
#
# RuntimeError: Given groups=1, weight of size [32, 1, 8, 8], expected input[64, 84, 84, 1] to have 1 channels, but got 84 channels instead

# %%
from stable_baselines import ACKTR, PPO2, SAC
env = Template_Gym()
#env = Controller_Gym(env)
env = DummyVecEnv([lambda: env])
env = VecFrameStack(env, n_stack=1)

expert_agent = MouseLogger()
model = expert_agent.actions
expert_agent 
      # Train a DQN agent for 1e5 timesteps and generate 10 trajectories
      # data will be saved in a numpy archive named `expert_cartpole.npz`


generate_expert_traj(expert_agent.actions, 'dummy_expert_cartpole', env, n_episodes=10)
# Out:
# ==========
# Images will be recorded to recorded_images/
# Image shape: (84, 84, 1)
# ==========
# Pointer moved to (914, 566)
# Pointer moved to (914, 566)
# Pressed at (914, 566)
# Pointer moved to (914, 566)
# Released at (914, 566)
# start
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-323-2d280cb1c291> in <module>
#      12
#      13
# ---> 14 generate_expert_traj(expert_agent.actions, 'dummy_expert_cartpole', env, n_episodes=10)
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines/gail/dataset/record_expert.py in generate_expert_traj(model, save_path, env, n_timesteps, n_episodes, image_folder)
#     120             action, state = model.predict(obs, state=state, mask=mask)
#     121         else:
# --> 122             action = model(obs)
#     123
#     124         obs, reward, done, _ = env.step(action)
#
# TypeError: actions() takes 1 positional argument but 2 were given

# %%
from stable_baselines3.common.cmd_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack ,DummyVecEnv, VecNormalize
from stable_baselines3 import A2C, PPO, DQN
import torch
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.callbacks import CheckpointCallback, EveryNTimesteps

# There already exists an environment generator
# that will make and wrap atari environments correctly.
# Here we are also multi-worker training (n_envs=4 => 4 environments)
env = Template_Gym()
#env = Controller_Gym(env)
env = DummyVecEnv([lambda: env])
#obs = env.reset()
# It will check your custom environment and output additional warnings if needed
#check_env(env)
#env = VecFrameStack(env,4)
#env = ScaledFloatFrame(env)
#env = MaxAndSkipEnv(env, skip=1)
#env = BufferWrapper(env, 2)
#env = DummyVecEnv(env)
#env2 = make_atari_env(env, n_envs=1, seed=0)
#Frame-stacking with 4 frames
#env = VecNormalize(env)
env = VecFrameStack(env, n_stack=4)

checkpoint_on_event = CheckpointCallback(save_freq=1, save_path='./logsnew/')
event_callback = EveryNTimesteps(n_steps=2500, callback=checkpoint_on_event)

model = DQN('CnnPolicy', env, verbose=1)
#model.load("dgn_flappy_new"+str(0))
for i in range(100):
    try:
        model.load("dgn_flappy_new"+str(i-1))
        model.load_replay_buffer("dgn_flappy_new_replay"+str(i-1))
    except:
        print("cnat load")
    model.learn(total_timesteps=2500000, callback=event_callback)
    model.save("dgn_flappy_new"+str(i))
    model.save_replay_buffer("dgn_flappy_new_replay"+str(i))
    

#obs = env.reset()
#while True:
    #action, _states = model.predict(obs)
    #print(model.predict(obs))
    #print(model.predict(obs[0]))
    #obs, rewards, dones, info = env.step(action)
    #env.render()

#model.save("ppo_flappy_3")
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# cnat load
# start
# /home/adaptationai/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines3/common/buffers.py:220: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 56.46GB > 20.06GB
#   "This system does not have apparently enough memory to store the complete "
# -0.9295
# start
# -0.9505
# start
# -0.9535
# start
# -0.9595
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.999    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 4        |
# |    time_elapsed     | 30       |
# |    total timesteps  | 138      |
# ----------------------------------
# -0.958
# start
# -0.9535
# start
# -0.9625
# start
# -0.964
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.999    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 4        |
# |    time_elapsed     | 55       |
# |    total timesteps  | 246      |
# ----------------------------------
# -0.955
# start
# -0.955
# start
# -0.952
# start
# -0.9565
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.999    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 4        |
# |    time_elapsed     | 81       |
# |    total timesteps  | 367      |
# ----------------------------------
# -0.9385
# start
# -0.958
# start
# -0.9565
# start
# -0.9339999999999999
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.998    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 4        |
# |    time_elapsed     | 107      |
# |    total timesteps  | 509      |
# ----------------------------------
# -0.9475
# start
# -0.9535
# start
# -0.9565
# start
# -0.952
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.998    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 4        |
# |    time_elapsed     | 133      |
# |    total timesteps  | 636      |
# ----------------------------------
# -0.952
# start
# -0.9565
# start
# -0.958
# start
# -0.964
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.997    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 4        |
# |    time_elapsed     | 159      |
# |    total timesteps  | 749      |
# ----------------------------------
# -0.9385
# start
# -0.9505
# start
# -0.952
# start
# -0.9565
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.997    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 4        |
# |    time_elapsed     | 184      |
# |    total timesteps  | 884      |
# ----------------------------------
# -0.961
# start
# -0.9565
# start
# -0.9385
# start
# -0.94
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.996    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 4        |
# |    time_elapsed     | 210      |
# |    total timesteps  | 1020     |
# ----------------------------------
# -0.94
# start
# -0.9475
# start
# -0.9595
# start
# -0.9355
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.996    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 4        |
# |    time_elapsed     | 236      |
# |    total timesteps  | 1165     |
# ----------------------------------
# -0.9595
# start
# -0.949
# start
# -0.9505
# start
# -0.946
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.995    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 4        |
# |    time_elapsed     | 261      |
# |    total timesteps  | 1295     |
# ----------------------------------
# -0.9595
# start
# -0.952
# start
# -0.9505
# start
# -0.9565
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.995    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 4        |
# |    time_elapsed     | 287      |
# |    total timesteps  | 1416     |
# ----------------------------------
# -0.943
# start
# -0.958
# start
# -0.943
# start
# -0.9565
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.994    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 4        |
# |    time_elapsed     | 313      |
# |    total timesteps  | 1549     |
# ----------------------------------
# -0.949
# start
# -0.9625
# start
# -0.9595
# start
# -0.9535
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.994    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 4        |
# |    time_elapsed     | 339      |
# |    total timesteps  | 1666     |
# ----------------------------------
# -0.955
# start
# -0.9385
# start
# -0.9565
# start
# -0.94
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.993    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 4        |
# |    time_elapsed     | 364      |
# |    total timesteps  | 1806     |
# ----------------------------------
# -0.9325
# start
# -0.9445
# start
# -0.958
# start
# -0.964
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.993    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 4        |
# |    time_elapsed     | 390      |
# |    total timesteps  | 1940     |
# ----------------------------------
# -0.9475
# start
# -0.9369999999999999
# start
# -0.9445
# start
# -0.964
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.992    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 4        |
# |    time_elapsed     | 416      |
# |    total timesteps  | 2078     |
# ----------------------------------
# -0.946
# start
# -0.9595
# start
# -0.943
# start
# -0.955
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.992    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 4        |
# |    time_elapsed     | 442      |
# |    total timesteps  | 2209     |
# ----------------------------------
# -0.9565
# start
# -0.9445
# start
# -0.9505
# start
# -0.955
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.991    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 4        |
# |    time_elapsed     | 467      |
# |    total timesteps  | 2338     |
# ----------------------------------
# -0.9505
# start
# -0.943
# start
# -0.9625
# start
# -0.955
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.991    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 4        |
# |    time_elapsed     | 493      |
# |    total timesteps  | 2464     |
# ----------------------------------
# -0.964
# start
# -0.9565
# start
# -0.9505
# start
# -0.946
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.99     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 4        |
# |    time_elapsed     | 519      |
# |    total timesteps  | 2586     |
# ----------------------------------
# -0.952
# start
# -0.9385
# start
# -0.9475
# start
# -0.952
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.99     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 5        |
# |    time_elapsed     | 544      |
# |    total timesteps  | 2726     |
# ----------------------------------
# -0.9445
# start
# -0.952
# start
# -0.952
# start
# -0.9595
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.989    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 4        |
# |    time_elapsed     | 570      |
# |    total timesteps  | 2854     |
# ----------------------------------
# -0.952
# start
# -0.961
# start
# -0.9369999999999999
# start
# -0.9475
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.989    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 5        |
# |    time_elapsed     | 596      |
# |    total timesteps  | 2989     |
# ----------------------------------
# -0.955
# start
# -0.9565
# start
# -0.9369999999999999
# start
# -0.9415
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.988    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 5        |
# |    time_elapsed     | 622      |
# |    total timesteps  | 3129     |
# ----------------------------------
# -0.9565
# start
# -0.9625
# start
# -0.9535
# start
# -0.955
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.988    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 5        |
# |    time_elapsed     | 648      |
# |    total timesteps  | 3244     |
# ----------------------------------
# -0.9505
# start
# -0.967
# start
# -0.946
# start
# -0.9535
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.987    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 4        |
# |    time_elapsed     | 674      |
# |    total timesteps  | 3366     |
# ----------------------------------
# -0.952
# start
# -0.955
# start
# -0.952
# start
# -0.9565
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.987    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 4        |
# |    time_elapsed     | 699      |
# |    total timesteps  | 3489     |
# ----------------------------------
# -0.9505
# start
# -0.9445
# start
# -0.952
# start
# -0.9445
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.986    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 4        |
# |    time_elapsed     | 725      |
# |    total timesteps  | 3628     |
# ----------------------------------
# -0.9535
# start
# -0.946
# start
# -0.949
# start
# -0.9279999999999999
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.986    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 5        |
# |    time_elapsed     | 751      |
# |    total timesteps  | 3777     |
# ----------------------------------
# -0.9595
# start
# -0.9535
# start
# -0.958
# start
# -0.9505
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.985    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 5        |
# |    time_elapsed     | 776      |
# |    total timesteps  | 3896     |
# ----------------------------------
# -0.9565
# start
# -0.949
# start
# -0.9309999999999999
# start
# -0.958
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.985    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 5        |
# |    time_elapsed     | 802      |
# |    total timesteps  | 4033     |
# ----------------------------------
# -0.9505
# start
# -0.9475
# start
# -0.9565
# start
# -0.9535
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.984    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 5        |
# |    time_elapsed     | 828      |
# |    total timesteps  | 4161     |
# ----------------------------------
# -0.943
# start
# -0.958
# start
# -0.964
# start
# -0.9475
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.984    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 5        |
# |    time_elapsed     | 854      |
# |    total timesteps  | 4286     |
# ----------------------------------
# -0.9625
# start
# -0.9369999999999999
# start
# -0.946
# start
# -0.955
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.983    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 5        |
# |    time_elapsed     | 880      |
# |    total timesteps  | 4419     |
# ----------------------------------
# -0.952
# start
# -0.9655
# start
# -0.946
# start
# -0.961
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.983    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 5        |
# |    time_elapsed     | 905      |
# |    total timesteps  | 4536     |
# ----------------------------------
# -0.9595
# start
# -0.949
# start
# -0.9565
# start
# -0.9505
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.982    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 5        |
# |    time_elapsed     | 931      |
# |    total timesteps  | 4659     |
# ----------------------------------
# -0.952
# start
# -0.9475
# start
# -0.955
# start
# -0.943
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.982    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 5        |
# |    time_elapsed     | 957      |
# |    total timesteps  | 4794     |
# ----------------------------------
# -0.952
# start
# -0.9385
# start
# -0.9535
# start
# -0.9625
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.981    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 5        |
# |    time_elapsed     | 983      |
# |    total timesteps  | 4923     |
# ----------------------------------
# -0.9415
# start
# -0.952
# start
# -0.9369999999999999
# start
# -0.9385
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.981    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 5        |
# |    time_elapsed     | 1008     |
# |    total timesteps  | 5077     |
# ----------------------------------
# -0.9505
# start
# -0.9309999999999999
# start
# -0.9445
# start
# -0.9445
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.98     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 5        |
# |    time_elapsed     | 1034     |
# |    total timesteps  | 5230     |
# ----------------------------------
# -0.9505
# start
# -0.961
# start
# -0.943
# start
# -0.943
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.98     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 5        |
# |    time_elapsed     | 1060     |
# |    total timesteps  | 5365     |
# ----------------------------------
# -0.952
# start
# -0.943
# start
# -0.9655
# start
# -0.9625
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.979    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 5        |
# |    time_elapsed     | 1086     |
# |    total timesteps  | 5483     |
# ----------------------------------
# -0.955
# start
# -0.9265
# start
# -0.949
# start
# -0.9535
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.979    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 5        |
# |    time_elapsed     | 1112     |
# |    total timesteps  | 5627     |
# ----------------------------------
# -0.961
# start
# -0.9475
# start
# -0.943
# start
# -0.9535
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.978    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 5        |
# |    time_elapsed     | 1137     |
# |    total timesteps  | 5757     |
# ----------------------------------
# -0.9565
# start
# -0.9625
# start
# -0.949
# start
# -0.9625
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.978    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 5        |
# |    time_elapsed     | 1163     |
# |    total timesteps  | 5870     |
# ----------------------------------
# -0.9595
# start
# -0.9565
# start
# -0.958
# start
# -0.946
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.977    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 5        |
# |    time_elapsed     | 1189     |
# |    total timesteps  | 5990     |
# ----------------------------------
# -0.9565
# start
# -0.9339999999999999
# start
# -0.958
# start
# -0.9415
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.977    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 5        |
# |    time_elapsed     | 1215     |
# |    total timesteps  | 6130     |
# ----------------------------------
# -0.952
# start
# -0.9565
# start
# -0.961
# start
# -0.943
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.976    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 5        |
# |    time_elapsed     | 1241     |
# |    total timesteps  | 6255     |
# ----------------------------------
# -0.949
# start
# -0.9535
# start
# -0.955
# start
# -0.9415
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.976    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 5        |
# |    time_elapsed     | 1266     |
# |    total timesteps  | 6389     |
# ----------------------------------
# -0.9595
# start
# -0.9535
# start
# -0.9505
# start
# -0.9505
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.975    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 5        |
# |    time_elapsed     | 1292     |
# |    total timesteps  | 6513     |
# ----------------------------------
# -0.952
# start
# -0.952
# start
# -0.9535
# start
# -0.958
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.975    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 5        |
# |    time_elapsed     | 1318     |
# |    total timesteps  | 6636     |
# ----------------------------------
# -0.946
# start
# -0.9655
# start
# -0.9445
# start
# -0.9415
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.974    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 5        |
# |    time_elapsed     | 1344     |
# |    total timesteps  | 6771     |
# ----------------------------------
# -0.9595
# start
# -0.9339999999999999
# start
# -0.952
# start
# -0.952
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.974    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 5        |
# |    time_elapsed     | 1373     |
# |    total timesteps  | 6906     |
# ----------------------------------
# -0.9505
# start
# -0.9535
# start
# -0.958
# start
# -0.9655
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.973    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 5        |
# |    time_elapsed     | 1398     |
# |    total timesteps  | 7021     |
# ----------------------------------
# -0.9369999999999999
# start
# -0.955
# start
# -0.9505
# start
# -0.9505
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.973    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 5        |
# |    time_elapsed     | 1424     |
# |    total timesteps  | 7159     |
# ----------------------------------
# -0.9505
# start
# -0.958
# start
# -0.949
# start
# -0.949
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.972    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 5        |
# |    time_elapsed     | 1450     |
# |    total timesteps  | 7288     |
# ----------------------------------
# -0.955
# start
# -0.952
# start
# -0.9535
# start
# -0.955
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.972    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 5        |
# |    time_elapsed     | 1476     |
# |    total timesteps  | 7411     |
# ----------------------------------
# -0.9505
# start
# -0.9595
# start
# -0.946
# start
# -0.9385
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.971    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 5        |
# |    time_elapsed     | 1501     |
# |    total timesteps  | 7548     |
# ----------------------------------
# -0.946
# start
# -0.9565
# start
# -0.9445
# start
# -0.9445
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.971    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 5        |
# |    time_elapsed     | 1527     |
# |    total timesteps  | 7687     |
# ----------------------------------
# -0.9385
# start
# -0.955
# start
# -0.9385
# start
# -0.9595
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.97     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 5        |
# |    time_elapsed     | 1553     |
# |    total timesteps  | 7826     |
# ----------------------------------
# -0.946
# start
# -0.946
# start
# -0.946
# start
# -0.9535
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.97     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 5        |
# |    time_elapsed     | 1579     |
# |    total timesteps  | 7965     |
# ----------------------------------
# -0.9369999999999999
# start
# -0.9505
# start
# -0.949
# start
# -0.949
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.969    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 5        |
# |    time_elapsed     | 1605     |
# |    total timesteps  | 8108     |
# ----------------------------------
# -0.964
# start
# -0.955
# start
# -0.9505
# start
# -0.9595
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.969    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 5        |
# |    time_elapsed     | 1630     |
# |    total timesteps  | 8222     |
# ----------------------------------
# -0.958
# start
# -0.9535
# start
# -0.943
# start
# -0.9445
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.968    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 5        |
# |    time_elapsed     | 1656     |
# |    total timesteps  | 8356     |
# ----------------------------------
# -0.9595
# start
# -0.964
# start
# -0.9565
# start
# -0.9595
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.968    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 5        |
# |    time_elapsed     | 1682     |
# |    total timesteps  | 8463     |
# ----------------------------------
# -0.955
# start
# -0.946
# start
# -0.9565
# start
# -0.958
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.967    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 5        |
# |    time_elapsed     | 1708     |
# |    total timesteps  | 8586     |
# ----------------------------------
# -0.9505
# start
# -0.9535
# start
# -0.9625
# start
# -0.949
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.967    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 5        |
# |    time_elapsed     | 1733     |
# |    total timesteps  | 8709     |
# ----------------------------------
# -0.9249999999999999
# start
# -0.958
# start
# -0.9565
# start
# -0.955
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.966    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 5        |
# |    time_elapsed     | 1759     |
# |    total timesteps  | 8846     |
# ----------------------------------
# -0.9535
# start
# -0.9565
# start
# -0.952
# start
# -0.946
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.966    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 5        |
# |    time_elapsed     | 1785     |
# |    total timesteps  | 8974     |
# ----------------------------------
# -0.9475
# start
# -0.94
# start
# -0.952
# start
# -0.955
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.965    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 5        |
# |    time_elapsed     | 1811     |
# |    total timesteps  | 9111     |
# ----------------------------------
# -0.958
# start
# -0.952
# start
# -0.9415
# start
# -0.9565
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.965    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 5        |
# |    time_elapsed     | 1837     |
# |    total timesteps  | 9239     |
# ----------------------------------
# -0.9475
# start
# -0.9505
# start
# -0.9625
# start
# -0.9535
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.964    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 5        |
# |    time_elapsed     | 1862     |
# |    total timesteps  | 9363     |
# ----------------------------------
# -0.9415
# start
# -0.952
# start
# -0.949
# start
# -0.952
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.964    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 5        |
# |    time_elapsed     | 1888     |
# |    total timesteps  | 9500     |
# ----------------------------------
# -0.9535
# start
# -0.9565
# start
# -0.955
# start
# -0.9565
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.963    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 5        |
# |    time_elapsed     | 1914     |
# |    total timesteps  | 9619     |
# ----------------------------------
# -0.958
# start
# -0.943
# start
# -0.9415
# start
# -0.943
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.963    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 5        |
# |    time_elapsed     | 1940     |
# |    total timesteps  | 9762     |
# ----------------------------------
# -0.943
# start
# -0.94
# start
# -0.955
# start
# -0.9355
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.962    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 5        |
# |    time_elapsed     | 1965     |
# |    total timesteps  | 9913     |
# ----------------------------------
# -0.9595
# start
# -0.9339999999999999
# start
# -0.9505
# start
# -0.958
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.962    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 5        |
# |    time_elapsed     | 1991     |
# |    total timesteps  | 10045    |
# ----------------------------------
# -0.9369999999999999
# start
# -0.94
# start
# -0.9445
# start
# -0.9415
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.961    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 5        |
# |    time_elapsed     | 2017     |
# |    total timesteps  | 10203    |
# ----------------------------------
# -0.9339999999999999
# start
# -0.961
# start
# -0.952
# start
# -0.9535
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.961    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 5        |
# |    time_elapsed     | 2043     |
# |    total timesteps  | 10336    |
# ----------------------------------
# -0.9475
# start
# -0.9565
# start
# -0.9475
# start
# -0.9505
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.96     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 5        |
# |    time_elapsed     | 2068     |
# |    total timesteps  | 10468    |
# ----------------------------------
# -0.9505
# start
# -0.9625
# start
# -0.949
# start
# -0.9625
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.96     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 5        |
# |    time_elapsed     | 2094     |
# |    total timesteps  | 10585    |
# ----------------------------------
# -0.949
# start
# -0.958
# start
# -0.955
# start
# -0.9535
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.959    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 5        |
# |    time_elapsed     | 2120     |
# |    total timesteps  | 10708    |
# ----------------------------------
# -0.94
# start
# -0.952
# start
# -0.9369999999999999
# start
# -0.943
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.959    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 5        |
# |    time_elapsed     | 2146     |
# |    total timesteps  | 10860    |
# ----------------------------------
# -0.952
# start
# -0.961
# start
# -0.958
# start
# -0.9505
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.958    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 5        |
# |    time_elapsed     | 2171     |
# |    total timesteps  | 10979    |
# ----------------------------------
# -0.964
# start
# -0.952
# start
# -0.9475
# start
# -0.952
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.958    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 5        |
# |    time_elapsed     | 2197     |
# |    total timesteps  | 11102    |
# ----------------------------------
# -0.952
# start
# -0.9565
# start
# -0.9475
# start
# -0.955
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.957    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 5        |
# |    time_elapsed     | 2223     |
# |    total timesteps  | 11228    |
# ----------------------------------
# -0.9565
# start
# -0.946
# start
# -0.952
# start
# -0.946
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.957    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 5        |
# |    time_elapsed     | 2249     |
# |    total timesteps  | 11361    |
# ----------------------------------
# -0.9475
# start
# -0.958
# start
# -0.9535
# start
# -0.943
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.956    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 5        |
# |    time_elapsed     | 2274     |
# |    total timesteps  | 11493    |
# ----------------------------------
# -0.9565
# start
# -0.9565
# start
# -0.9535
# start
# -0.9595
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.956    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 5        |
# |    time_elapsed     | 2300     |
# |    total timesteps  | 11609    |
# ----------------------------------
# -0.9535
# start
# -0.946
# start
# -0.952
# start
# -0.9565
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.955    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 5        |
# |    time_elapsed     | 2326     |
# |    total timesteps  | 11737    |
# ----------------------------------
# -0.949
# start
# -0.9415
# start
# -0.952
# start
# -0.9595
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.955    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 5        |
# |    time_elapsed     | 2352     |
# |    total timesteps  | 11869    |
# ----------------------------------
# -0.9385
# start
# -0.9505
# start
# -0.9445
# start
# -0.9535
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.954    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 5        |
# |    time_elapsed     | 2377     |
# |    total timesteps  | 12011    |
# ----------------------------------
# -0.9355
# start
# -0.94
# start
# -0.949
# start
# -0.955
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.954    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 5        |
# |    time_elapsed     | 2403     |
# |    total timesteps  | 12158    |
# ----------------------------------
# -0.9355
# start
# -0.9595
# start
# -0.952
# start
# -0.9565
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.953    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 5        |
# |    time_elapsed     | 2429     |
# |    total timesteps  | 12289    |
# ----------------------------------
# -0.94
# start
# -0.9385
# start
# -0.9355
# start
# -0.94
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.953    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 5        |
# |    time_elapsed     | 2454     |
# |    total timesteps  | 12453    |
# ----------------------------------
# -0.9535
# start
# -0.94
# start
# -0.946
# start
# -0.9505
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.952    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 5        |
# |    time_elapsed     | 2480     |
# |    total timesteps  | 12593    |
# ----------------------------------
# -0.9565
# start
# -0.9535
# start
# -0.9445
# start
# -0.9385
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.952    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 5        |
# |    time_elapsed     | 2506     |
# |    total timesteps  | 12731    |
# ----------------------------------
# -0.9535
# start
# -0.9535
# start
# -0.9445
# start
# -0.9505
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.951    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 5        |
# |    time_elapsed     | 2531     |
# |    total timesteps  | 12863    |
# ----------------------------------
# -0.943
# start
# -0.955
# start
# -0.949
# start
# -0.949
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.951    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 5        |
# |    time_elapsed     | 2557     |
# |    total timesteps  | 12999    |
# ----------------------------------
# -0.952
# start
# -0.9535
# start
# -0.9445
# start
# -0.9595
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.95     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 5        |
# |    time_elapsed     | 2583     |
# |    total timesteps  | 13126    |
# ----------------------------------
# -0.9505
# start
# -0.9535
# start
# -0.952
# start
# -0.9505
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.95     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 5        |
# |    time_elapsed     | 2609     |
# |    total timesteps  | 13255    |
# ----------------------------------
# -0.955
# start
# -0.9595
# start
# -0.946
# start
# -0.943
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.949    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 5        |
# |    time_elapsed     | 2634     |
# |    total timesteps  | 13386    |
# ----------------------------------
# -0.955
# start
# -0.955
# start
# -0.961
# start
# -0.955
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.949    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 5        |
# |    time_elapsed     | 2660     |
# |    total timesteps  | 13502    |
# ----------------------------------
# -0.94
# start
# -0.943
# start
# -0.9475
# start
# -0.952
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.948    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 5        |
# |    time_elapsed     | 2686     |
# |    total timesteps  | 13647    |
# ----------------------------------
# -0.967
# start
# -0.955
# start
# -0.9309999999999999
# start
# -0.955
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.948    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 5        |
# |    time_elapsed     | 2711     |
# |    total timesteps  | 13775    |
# ----------------------------------
# -0.9595
# start
# -0.9535
# start
# -0.94
# start
# -0.943
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.947    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 5        |
# |    time_elapsed     | 2740     |
# |    total timesteps  | 13911    |
# ----------------------------------
# -0.9505
# start
# -0.946
# start
# -0.946
# start
# -0.9505
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.947    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 5        |
# |    time_elapsed     | 2766     |
# |    total timesteps  | 14049    |
# ----------------------------------
# -0.9355
# start
# -0.955
# start
# -0.9595
# start
# -0.9355
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.946    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 5        |
# |    time_elapsed     | 2792     |
# |    total timesteps  | 14192    |
# ----------------------------------
# -0.958
# start
# -0.9535
# start
# -0.946
# start
# -0.958
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.946    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 5        |
# |    time_elapsed     | 2817     |
# |    total timesteps  | 14315    |
# ----------------------------------
# -0.9535
# start
# -0.955
# start
# -0.955
# start
# -0.949
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.945    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 5        |
# |    time_elapsed     | 2843     |
# |    total timesteps  | 14440    |
# ----------------------------------
# -0.9535
# start
# -0.9565
# start
# -0.955
# start
# -0.961
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.945    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 5        |
# |    time_elapsed     | 2869     |
# |    total timesteps  | 14556    |
# ----------------------------------
# -0.9535
# start
# -0.9505
# start
# -0.958
# start
# -0.952
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.944    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 5        |
# |    time_elapsed     | 2895     |
# |    total timesteps  | 14680    |
# ----------------------------------
# -0.9475
# start
# -0.9475
# start
# -0.9265
# start
# -0.964
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.944    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 5        |
# |    time_elapsed     | 2920     |
# |    total timesteps  | 14823    |
# ----------------------------------
# -0.9475
# start
# -0.955
# start
# -0.958
# start
# -0.955
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.943    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 5        |
# |    time_elapsed     | 2946     |
# |    total timesteps  | 14946    |
# ----------------------------------
# -0.955
# start
# -0.9595
# start
# -0.9385
# start
# -0.9565
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.943    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 5        |
# |    time_elapsed     | 2972     |
# |    total timesteps  | 15073    |
# ----------------------------------
# -0.946
# start
# -0.9535
# start
# -0.9505
# start
# -0.9415
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.942    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 5        |
# |    time_elapsed     | 2998     |
# |    total timesteps  | 15212    |
# ----------------------------------
# -0.9355
# start
# -0.955
# start
# -0.9445
# start
# -0.961
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.942    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 5        |
# |    time_elapsed     | 3023     |
# |    total timesteps  | 15348    |
# ----------------------------------
# -0.955
# start
# -0.946
# start
# -0.9505
# start
# -0.9565
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.941    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 5        |
# |    time_elapsed     | 3049     |
# |    total timesteps  | 15476    |
# ----------------------------------
# -0.955
# start
# -0.958
# start
# -0.952
# start
# -0.94
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.941    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 5        |
# |    time_elapsed     | 3075     |
# |    total timesteps  | 15606    |
# ----------------------------------
# -0.9475
# start
# -0.955
# start
# -0.9505
# start
# -0.955
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.94     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 5        |
# |    time_elapsed     | 3101     |
# |    total timesteps  | 15734    |
# ----------------------------------
# -0.958
# start
# -0.955
# start
# -0.958
# start
# -0.9625
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.94     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 5        |
# |    time_elapsed     | 3126     |
# |    total timesteps  | 15845    |
# ----------------------------------
# -0.952
# start
# -0.9535
# start
# -0.952
# start
# -0.949
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.939    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 5        |
# |    time_elapsed     | 3152     |
# |    total timesteps  | 15974    |
# ----------------------------------
# -0.9475
# start
# -0.946
# start
# -0.9445
# start
# -0.961
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.939    |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 5        |
# |    time_elapsed     | 3178     |
# |    total timesteps  | 16108    |
# ----------------------------------
# -0.949
# start
# -0.9445
# start
# -0.9355
# start
# -0.9535
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.938    |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 5        |
# |    time_elapsed     | 3204     |
# |    total timesteps  | 16253    |
# ----------------------------------
# -0.9565
# start
# -0.967
# start
# -0.949
# start
# -0.9505
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.938    |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 5        |
# |    time_elapsed     | 3229     |
# |    total timesteps  | 16371    |
# ----------------------------------
# -0.955
# start
# -0.9595
# start
# -0.949
# start
# -0.946
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.937    |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 5        |
# |    time_elapsed     | 3255     |
# |    total timesteps  | 16498    |
# ----------------------------------
# -0.9565
# start
# -0.958
# start
# -0.9565
# start
# -0.9565
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.937    |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 5        |
# |    time_elapsed     | 3281     |
# |    total timesteps  | 16613    |
# ----------------------------------
# -0.9235
# start
# -0.961
# start
# -0.949
# start
# -0.9565
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.936    |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 5        |
# |    time_elapsed     | 3306     |
# |    total timesteps  | 16753    |
# ----------------------------------
# -0.9325
# start
# -0.9415
# start
# -0.952
# start
# -0.949
# start
# ----------------------------------
# | rollout/            |          |
# ...
# -0.9235
# start
# -0.958
# start
# -0.952
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.853    |
# | time/               |          |
# |    episodes         | 1184     |
# |    fps              | 5        |
# |    time_elapsed     | 7647     |
# |    total timesteps  | 38770    |
# ----------------------------------
# -0.949
# start
# -0.9595
# start
# -0.9535
# start
# -0.943
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.852    |
# | time/               |          |
# |    episodes         | 1188     |
# |    fps              | 5        |
# |    time_elapsed     | 7673     |
# |    total timesteps  | 38900    |
# ----------------------------------
# -0.9565
# start
# -0.955
# start
# -0.9505
# start
# -0.9505
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.852    |
# | time/               |          |
# |    episodes         | 1192     |
# |    fps              | 5        |
# |    time_elapsed     | 7698     |
# |    total timesteps  | 39025    |
# ----------------------------------
# -0.952
# start
# -0.9475
# start
# -0.9595
# start
# -0.9685
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.851    |
# | time/               |          |
# |    episodes         | 1196     |
# |    fps              | 5        |
# |    time_elapsed     | 7724     |
# |    total timesteps  | 39140    |
# ----------------------------------
# -0.9595
# start
# -0.955
# start
# -0.952
# start
# -0.943
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.851    |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 5        |
# |    time_elapsed     | 7750     |
# |    total timesteps  | 39267    |
# ----------------------------------
# -0.958
# start
# -0.9505
# start
# -0.955
# start
# -0.9595
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.85     |
# | time/               |          |
# |    episodes         | 1204     |
# |    fps              | 5        |
# |    time_elapsed     | 7775     |
# |    total timesteps  | 39385    |
# ----------------------------------
# -0.9655
# start
# -0.952
# start
# -0.946
# start
# -0.9565
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.85     |
# | time/               |          |
# |    episodes         | 1208     |
# |    fps              | 5        |
# |    time_elapsed     | 7801     |
# |    total timesteps  | 39505    |
# ----------------------------------
# -0.9565
# start
# -0.9565
# start
# -0.955
# start
# -0.952
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.849    |
# | time/               |          |
# |    episodes         | 1212     |
# |    fps              | 5        |
# |    time_elapsed     | 7827     |
# |    total timesteps  | 39625    |
# ----------------------------------
# -0.958
# start
# -0.9475
# start
# -0.9385
# start
# -0.955
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.849    |
# | time/               |          |
# |    episodes         | 1216     |
# |    fps              | 5        |
# |    time_elapsed     | 7853     |
# |    total timesteps  | 39759    |
# ----------------------------------
# -0.958
# start
# -0.9565
# start
# -0.9565
# start
# -0.9565
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.848    |
# | time/               |          |
# |    episodes         | 1220     |
# |    fps              | 5        |
# |    time_elapsed     | 7878     |
# |    total timesteps  | 39874    |
# ----------------------------------
# -0.955
# start
# -0.949
# start
# -0.955
# start
# -0.949
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.848    |
# | time/               |          |
# |    episodes         | 1224     |
# |    fps              | 5        |
# |    time_elapsed     | 7904     |
# |    total timesteps  | 40002    |
# ----------------------------------
# -0.9595
# start
# -0.949
# start
# -0.9385
# start
# -0.949
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.847    |
# | time/               |          |
# |    episodes         | 1228     |
# |    fps              | 5        |
# |    time_elapsed     | 7930     |
# |    total timesteps  | 40138    |
# ----------------------------------
# -0.9595
# start
# -0.955
# start
# -0.946
# start
# -0.9625
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.847    |
# | time/               |          |
# |    episodes         | 1232     |
# |    fps              | 5        |
# |    time_elapsed     | 7956     |
# |    total timesteps  | 40256    |
# ----------------------------------
# -0.952
# start
# -0.949
# start
# -0.9565
# start
# -0.9415
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.847    |
# | time/               |          |
# |    episodes         | 1236     |
# |    fps              | 5        |
# |    time_elapsed     | 7982     |
# |    total timesteps  | 40390    |
# ----------------------------------
# -0.9565
# start
# -0.9415
# start
# -0.9369999999999999
# start
# -0.949
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.846    |
# | time/               |          |
# |    episodes         | 1240     |
# |    fps              | 5        |
# |    time_elapsed     | 8007     |
# |    total timesteps  | 40534    |
# ----------------------------------
# -0.949
# start
# -0.961
# start
# -0.9415
# start
# -0.955
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.845    |
# | time/               |          |
# |    episodes         | 1244     |
# |    fps              | 5        |
# |    time_elapsed     | 8033     |
# |    total timesteps  | 40663    |
# ----------------------------------
# -0.961
# start
# -0.9415
# start
# -0.94
# start
# -0.9445
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.845    |
# | time/               |          |
# |    episodes         | 1248     |
# |    fps              | 5        |
# |    time_elapsed     | 8059     |
# |    total timesteps  | 40805    |
# ----------------------------------
# -0.9369999999999999
# start
# -0.949
# start
# -0.958
# start
# -0.955
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.844    |
# | time/               |          |
# |    episodes         | 1252     |
# |    fps              | 5        |
# |    time_elapsed     | 8085     |
# |    total timesteps  | 40939    |
# ----------------------------------
# -0.9535
# start
# -0.9475
# start
# -0.964
# start
# -0.949
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.844    |
# | time/               |          |
# |    episodes         | 1256     |
# |    fps              | 5        |
# |    time_elapsed     | 8110     |
# |    total timesteps  | 41063    |
# ----------------------------------
# -0.961
# start
# -0.9565
# start
# -0.949
# start
# -0.943
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.843    |
# | time/               |          |
# |    episodes         | 1260     |
# |    fps              | 5        |
# |    time_elapsed     | 8136     |
# |    total timesteps  | 41190    |
# ----------------------------------
# -0.9415
# start
# -0.9625
# start
# -0.946
# start
# -0.9415
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.843    |
# | time/               |          |
# |    episodes         | 1264     |
# |    fps              | 5        |
# |    time_elapsed     | 8162     |
# |    total timesteps  | 41329    |
# ----------------------------------
# -0.946
# start
# -0.952
# start
# -0.961
# start
# -0.9505
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.842    |
# | time/               |          |
# |    episodes         | 1268     |
# |    fps              | 5        |
# |    time_elapsed     | 8188     |
# |    total timesteps  | 41456    |
# ----------------------------------
# -0.952
# start
# -0.949
# start
# -0.943
# start
# -0.9565
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.842    |
# | time/               |          |
# |    episodes         | 1272     |
# |    fps              | 5        |
# |    time_elapsed     | 8213     |
# |    total timesteps  | 41589    |
# ----------------------------------
# -0.9565
# start
# -0.9355
# start
# -0.958
# start
# -0.961
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.841    |
# | time/               |          |
# |    episodes         | 1276     |
# |    fps              | 5        |
# |    time_elapsed     | 8239     |
# |    total timesteps  | 41715    |
# ----------------------------------
# -0.958
# start
# -0.9445
# start
# -0.964
# start
# -0.9385
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.841    |
# | time/               |          |
# |    episodes         | 1280     |
# |    fps              | 5        |
# |    time_elapsed     | 8265     |
# |    total timesteps  | 41845    |
# ----------------------------------
# -0.9445
# start
# -0.949
# start
# -0.9595
# start
# -0.946
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.84     |
# | time/               |          |
# |    episodes         | 1284     |
# |    fps              | 5        |
# |    time_elapsed     | 8291     |
# |    total timesteps  | 41979    |
# ----------------------------------
# -0.955
# start
# -0.9625
# start
# -0.9355
# start
# -0.9355
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.84     |
# | time/               |          |
# |    episodes         | 1288     |
# |    fps              | 5        |
# |    time_elapsed     | 8316     |
# |    total timesteps  | 42120    |
# ----------------------------------
# -0.952
# start
# -0.9325
# start
# -0.9325
# start
# -0.955
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.839    |
# | time/               |          |
# |    episodes         | 1292     |
# |    fps              | 5        |
# |    time_elapsed     | 8342     |
# |    total timesteps  | 42272    |
# ----------------------------------
# -0.94
# start
# -0.9415
# start
# -0.9565
# start
# -0.958
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.839    |
# | time/               |          |
# |    episodes         | 1296     |
# |    fps              | 5        |
# |    time_elapsed     | 8368     |
# |    total timesteps  | 42408    |
# ----------------------------------
# -0.9625
# start
# -0.9565
# start
# -0.9565
# start
# -0.955
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.838    |
# | time/               |          |
# |    episodes         | 1300     |
# |    fps              | 5        |
# |    time_elapsed     | 8393     |
# |    total timesteps  | 42521    |
# ----------------------------------
# -0.94
# start
# -0.9535
# start
# -0.94
# start
# -0.9475
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.838    |
# | time/               |          |
# |    episodes         | 1304     |
# |    fps              | 5        |
# |    time_elapsed     | 8419     |
# |    total timesteps  | 42667    |
# ----------------------------------
# -0.9565
# start
# -0.958
# start
# -0.9565
# start
# -0.946
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.837    |
# | time/               |          |
# |    episodes         | 1308     |
# |    fps              | 5        |
# |    time_elapsed     | 8445     |
# |    total timesteps  | 42789    |
# ----------------------------------
# -0.955
# start
# -0.949
# start
# -0.952
# start
# -0.949
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.837    |
# | time/               |          |
# |    episodes         | 1312     |
# |    fps              | 5        |
# |    time_elapsed     | 8470     |
# |    total timesteps  | 42919    |
# ----------------------------------
# -0.946
# start
# -0.949
# start
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-0aeefe40cc31> in <module>
#      36     except:
#      37         print("cnat load")
# ---> 38     model.learn(total_timesteps=2500000, callback=event_callback)
#      39     model.save("dgn_flappy_new"+str(i))
#      40     model.save_replay_buffer("dgn_flappy_new_replay"+str(i))
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines3/dqn/dqn.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     246             tb_log_name=tb_log_name,
#     247             eval_log_path=eval_log_path,
# --> 248             reset_num_timesteps=reset_num_timesteps,
#     249         )
#     250
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines3/common/off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     357                 learning_starts=self.learning_starts,
#     358                 replay_buffer=self.replay_buffer,
# --> 359                 log_interval=log_interval,
#     360             )
#     361
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines3/common/off_policy_algorithm.py in collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     564
#     565                 # Rescale and perform action
# --> 566                 new_obs, reward, done, infos = env.step(action)
#     567
#     568                 self.num_timesteps += 1
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines3/common/vec_env/base_vec_env.py in step(self, actions)
#     160         """
#     161         self.step_async(actions)
# --> 162         return self.step_wait()
#     163
#     164     def get_images(self) -> Sequence[np.ndarray]:
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines3/common/vec_env/vec_transpose.py in step_wait(self)
#      81
#      82     def step_wait(self) -> VecEnvStepReturn:
# ---> 83         observations, rewards, dones, infos = self.venv.step_wait()
#      84
#      85         # Transpose the terminal observations
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines3/common/vec_env/vec_frame_stack.py in step_wait(self)
#      46     ) -> Tuple[Union[np.ndarray, Dict[str, np.ndarray]], np.ndarray, np.ndarray, List[Dict[str, Any]],]:
#      47
# ---> 48         observations, rewards, dones, infos = self.venv.step_wait()
#      49
#      50         observations, infos = self.stackedobs.update(observations, dones, infos)
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py in step_wait(self)
#      47                 # save final observation where user can get it, then reset
#      48                 self.buf_infos[env_idx]["terminal_observation"] = obs
# ---> 49                 obs = self.envs[env_idx].reset()
#      50             self._save_obs(env_idx, obs)
#      51         return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones), deepcopy(self.buf_infos))
#
# <ipython-input-4-d20ae92f1fdb> in reset(self)
#     141
#     142     def reset(self):
# --> 143         self.state = self.env.reset()
#     144         #self.reward = np.array([reward])
#     145         #self.state = self.state.tolist()
#
# <ipython-input-11-d335634f11c2> in reset(self)
#     112         time.sleep(.425)
#     113         pyautogui.click(x=795, y= 219, button='left')
# --> 114         time.sleep(.425)
#     115         pyautogui.click(x=795, y= 219, button='left')
#     116         time.sleep(.425)
#
# KeyboardInterrupt:

# %%
from stable_baselines3.common.cmd_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack ,DummyVecEnv, VecNormalize
from stable_baselines3 import A2C, PPO, DQN
import torch

# There already exists an environment generator
# that will make and wrap atari environments correctly.
# Here we are also multi-worker training (n_envs=4 => 4 environments)
env = Template_Gym()
#env = Controller_Gym(env)
env = DummyVecEnv([lambda: env])
#obs = env.reset()
# It will check your custom environment and output additional warnings if needed
#check_env(env)
#env = VecFrameStack(env,4)
#env = ScaledFloatFrame(env)
#env = MaxAndSkipEnv(env, skip=1)
#env = BufferWrapper(env, 2)
#env = DummyVecEnv(env)
#env2 = make_atari_env(env, n_envs=1, seed=0)
#Frame-stacking with 4 frames
#env = VecNormalize(env)
env = VecFrameStack(env, n_stack=4)


#model = PPO('CnnPolicy', env, verbose=1)
model.load("ppo_flappy_"+str(37))
for i in range(100):
    try:
        model.load("ppo_flappy_new"+str(i-1))
        #model.load_replay_buffer("ppo_flappy_new_replay"+str(i-1))
    except:
        print("cnat load")
    model.learn(total_timesteps=250000)
    model.save("ppo_flappy_new"+str(i))
    #model.save_replay_buffer("ppo_flappy_new_replay"+str(i))
    

#obs = env.reset()
#while True:
    #action, _states = model.predict(obs)
    #print(model.predict(obs))
    #print(model.predict(obs[0]))
    #obs, rewards, dones, info = env.step(action)
    #env.render()
# Out:
# cnat load
# start
# -0.9805
# start
# -0.982
# start
# -0.9805
# start
# -0.979
# start
# -0.9775
# start
# -0.9805
# start
# -0.9835
# start
# -0.9805
# start
# -0.979
# start
# -0.982
# start
# -0.9775
# start
# -0.973
# start
# -0.9805
# start
# -0.982
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.979
# start
# -0.982
# start
# -0.9805
# start
# -0.9805
# start
# -0.979
# start
# -0.982
# start
# -0.9805
# start
# -0.9805
# start
# -0.976
# start
# -0.982
# start
# -0.9805
# start
# -0.982
# start
# -0.982
# start
# -0.979
# start
# -0.9805
# start
# -0.9835
# start
# -0.979
# start
# -0.979
# start
# -0.9805
# start
# -0.973
# start
# -0.979
# start
# -0.9805
# start
# -0.979
# start
# -0.9835
# start
# -0.9805
# start
# -0.9775
# start
# -0.982
# start
# -0.9775
# start
# -0.982
# start
# -0.9805
# start
# -0.979
# start
# -0.982
# start
# -0.982
# start
# -0.982
# start
# -0.9835
# start
# -0.9835
# start
# -0.979
# start
# -0.979
# start
# -0.973
# start
# -0.979
# start
# -0.979
# start
# -0.9805
# start
# -0.982
# start
# -0.9805
# start
# -0.9805
# start
# -0.9805
# start
# -0.9805
# start
# -0.982
# start
# -0.973
# start
# -0.9805
# start
# -0.979
# start
# -0.982
# start
# -0.976
# start
# -0.9805
# start
# -0.979
# start
# -0.9775
# start
# -0.979
# start
# -0.982
# start
# -0.9805
# start
# -0.9775
# start
# -0.9745
# start
# -0.9805
# start
# -0.9805
# start
# -0.979
# start
# -0.979
# start
# -0.9775
# start
# -0.979
# start
# -0.9805
# start
# -0.982
# start
# -0.9805
# start
# -0.9835
# start
# -0.982
# start
# -0.982
# start
# -0.982
# start
# -0.9805
# start
# -0.9805
# start
# -0.9805
# start
# -0.979
# start
# -0.982
# start
# -0.9775
# start
# -0.982
# start
# -0.9805
# start
# -0.982
# start
# -0.9775
# start
# -0.9625
# start
# -0.9805
# start
# -0.9805
# start
# -0.9775
# start
# -0.982
# start
# -0.9805
# start
# -0.9775
# start
# -0.9805
# start
# -0.9805
# start
# -0.982
# start
# -0.9805
# start
# -0.9805
# start
# -0.982
# start
# -0.982
# start
# -0.982
# start
# -0.979
# start
# -0.9805
# start
# -0.979
# start
# -0.9835
# start
# -0.982
# start
# -0.9775
# start
# -0.9835
# start
# -0.9835
# start
# -0.982
# start
# -0.9805
# start
# -0.982
# start
# -0.9775
# start
# -0.9775
# start
# -0.9805
# start
# -0.9835
# start
# -0.982
# start
# -0.9805
# start
# -0.9805
# start
# -0.982
# start
# -0.982
# start
# -0.9805
# start
# -0.982
# start
# -0.9805
# start
# -0.982
# start
# -0.979
# start
# -0.9805
# start
# -0.9775
# start
# -0.9805
# start
# -0.9835
# start
# -0.979
# start
# -0.982
# start
# -0.982
# start
# -0.9805
# start
# -0.979
# start
# -0.982
# start
# -0.982
# start
# -0.979
# start
# -----------------------------
# | time/              |      |
# |    fps             | 2    |
# |    iterations      | 1    |
# |    time_elapsed    | 1007 |
# |    total_timesteps | 2048 |
# -----------------------------
# -0.994
# start
# -0.979
# start
# -0.9775
# start
# -0.9805
# start
# -0.9775
# start
# -0.982
# start
# -0.976
# start
# -0.9775
# start
# -0.9835
# start
# -0.9835
# start
# -0.979
# start
# -0.9805
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.979
# start
# -0.982
# start
# -0.973
# start
# -0.982
# start
# -0.979
# start
# -0.976
# start
# -0.9835
# start
# -0.9775
# start
# -0.9805
# start
# -0.976
# start
# -0.982
# start
# -0.979
# start
# -0.9775
# start
# -0.9805
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9835
# start
# -0.979
# start
# -0.982
# start
# -0.9805
# start
# -0.9805
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.979
# start
# -0.9775
# start
# -0.9715
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9835
# start
# -0.982
# start
# -0.9805
# start
# -0.982
# start
# -0.9805
# start
# -0.9775
# start
# -0.985
# start
# -0.982
# start
# -0.9805
# start
# -0.9805
# start
# -0.9745
# start
# -0.982
# start
# -0.9775
# start
# -0.979
# start
# -0.982
# start
# -0.979
# start
# -0.9805
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.982
# start
# -0.9595
# start
# -0.9835
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.982
# start
# -0.9805
# start
# -0.982
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.9835
# start
# -0.982
# start
# -0.9775
# start
# -0.979
# start
# -0.9805
# start
# -0.9775
# start
# -0.982
# start
# -0.9775
# start
# -0.9805
# start
# -0.973
# start
# -0.982
# start
# -0.979
# start
# -0.982
# start
# -0.9805
# start
# -0.982
# start
# -0.976
# start
# -0.982
# start
# -0.9805
# start
# -0.979
# start
# -0.982
# start
# -0.9805
# start
# -0.976
# start
# -0.976
# start
# -0.9805
# start
# -0.9775
# start
# -0.9805
# start
# -0.9805
# start
# -0.9835
# start
# -0.9805
# start
# -0.9775
# start
# -0.982
# start
# -0.9775
# start
# -0.979
# start
# -0.9805
# start
# -0.9775
# start
# -0.9805
# start
# -0.9805
# start
# -0.9775
# start
# -0.976
# start
# -0.9805
# start
# -0.982
# start
# -0.976
# start
# -0.979
# start
# -0.9805
# start
# -0.979
# start
# -0.979
# start
# -0.9805
# start
# -0.979
# start
# -0.9805
# start
# -0.976
# start
# -0.979
# start
# -0.9745
# start
# -0.9805
# start
# -0.979
# start
# -0.9775
# start
# -0.9805
# start
# -0.979
# start
# -0.982
# start
# -0.976
# start
# -0.979
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2            |
# |    iterations           | 2            |
# |    time_elapsed         | 1961         |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0048581986 |
# |    clip_fraction        | 0.073        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.648       |
# |    explained_variance   | -0.942       |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.036       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00565     |
# |    value_loss           | 0.00507      |
# ------------------------------------------
# -0.9865
# start
# -0.9775
# start
# -0.979
# start
# -0.9805
# start
# -0.979
# start
# -0.9835
# start
# -0.9775
# start
# -0.9805
# start
# -0.976
# start
# -0.9805
# start
# -0.9805
# start
# -0.979
# start
# -0.976
# start
# -0.9805
# start
# -0.9775
# start
# -0.979
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.9745
# start
# -0.9805
# start
# -0.9745
# start
# -0.979
# start
# -0.979
# start
# -0.9805
# start
# -0.9775
# start
# -0.9745
# start
# -0.979
# start
# -0.9805
# start
# -0.982
# start
# -0.982
# start
# -0.979
# start
# -0.9835
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.979
# start
# -0.9805
# start
# -0.976
# start
# -0.9775
# start
# -0.9805
# start
# -0.979
# start
# -0.979
# start
# -0.976
# start
# -0.9805
# start
# -0.979
# start
# -0.973
# start
# -0.979
# start
# -0.9775
# start
# -0.9805
# start
# -0.9805
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.982
# start
# -0.982
# start
# -0.979
# start
# -0.979
# start
# -0.982
# start
# -0.979
# start
# -0.979
# start
# -0.9835
# start
# -0.979
# start
# -0.9775
# start
# -0.982
# start
# -0.979
# start
# -0.979
# start
# -0.979
# start
# -0.9805
# start
# -0.982
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9805
# start
# -0.9745
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.982
# start
# -0.9805
# start
# -0.97
# start
# -0.979
# start
# -0.982
# start
# -0.979
# start
# -0.979
# start
# -0.9775
# start
# -0.9805
# start
# -0.9805
# start
# -0.9805
# start
# -0.9805
# start
# -0.9775
# start
# -0.982
# start
# -0.9775
# start
# -0.9805
# start
# -0.9775
# start
# -0.9775
# start
# -0.982
# start
# -0.9835
# start
# -0.985
# start
# -0.976
# start
# -0.9805
# start
# -0.979
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.9805
# start
# -0.9835
# start
# -0.976
# start
# -0.982
# start
# -0.9775
# start
# -0.982
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.9745
# start
# -0.979
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.9805
# start
# -0.979
# start
# -0.9745
# start
# -0.979
# start
# -0.976
# start
# -0.9805
# start
# -0.9745
# start
# -0.979
# start
# -0.982
# start
# -0.979
# start
# -0.9805
# start
# -0.9805
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.982
# start
# -0.976
# start
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2          |
# |    iterations           | 3          |
# |    time_elapsed         | 2894       |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01828891 |
# |    clip_fraction        | 0.223      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.555     |
# |    explained_variance   | 0.616      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0304    |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0158    |
# |    value_loss           | 0.00366    |
# ----------------------------------------
# -0.9835
# start
# -0.9775
# start
# -0.9805
# start
# -0.976
# start
# -0.982
# start
# -0.9775
# start
# -0.9805
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.979
# start
# -0.979
# start
# -0.9775
# start
# -0.982
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.9805
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.9805
# start
# -0.9775
# start
# -0.9805
# start
# -0.976
# start
# -0.9775
# start
# -0.979
# start
# -0.9805
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.982
# start
# -0.979
# start
# -0.9775
# start
# -0.9745
# start
# -0.979
# start
# -0.9745
# start
# -0.982
# start
# -0.973
# start
# -0.9715
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.982
# start
# -0.982
# start
# -0.9775
# start
# -0.9775
# start
# -0.9805
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9805
# start
# -0.9745
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9835
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.979
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.979
# start
# -0.9745
# start
# -0.9775
# start
# -0.9805
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.9835
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.982
# start
# -0.9775
# start
# -0.9775
# start
# -0.973
# start
# -0.976
# start
# -0.9805
# start
# -0.9805
# start
# -0.976
# start
# -0.982
# start
# -0.979
# start
# -0.9775
# start
# -0.9745
# start
# -0.979
# start
# -0.982
# start
# -0.9805
# start
# -0.979
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.982
# start
# -0.979
# start
# -0.976
# start
# -0.9835
# start
# -0.9805
# start
# -0.976
# start
# -0.979
# start
# -0.9805
# start
# -0.979
# start
# -0.9805
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9805
# start
# -0.982
# start
# -0.979
# start
# -0.9835
# start
# -0.9775
# start
# -0.982
# start
# -0.976
# start
# -0.9805
# start
# -0.979
# start
# -0.979
# start
# -0.9805
# start
# -0.979
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.973
# start
# -0.9775
# start
# -0.9805
# start
# -0.9805
# start
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2            |
# |    iterations           | 4            |
# |    time_elapsed         | 3807         |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0067393603 |
# |    clip_fraction        | 0.0919       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.532       |
# |    explained_variance   | 0.472        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00233      |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0055      |
# |    value_loss           | 0.00432      |
# ------------------------------------------
# -0.994
# start
# -0.976
# start
# -0.9775
# start
# -0.973
# start
# -0.9775
# start
# -0.982
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.982
# start
# -0.9805
# start
# -0.9835
# start
# -0.979
# start
# -0.982
# start
# -0.976
# start
# -0.9745
# start
# -0.9805
# start
# -0.9805
# start
# -0.9835
# start
# -0.979
# start
# -0.9805
# start
# -0.9775
# start
# -0.979
# start
# -0.979
# start
# -0.979
# start
# -0.979
# start
# -0.9775
# start
# -0.979
# start
# -0.982
# start
# -0.9835
# start
# -0.982
# start
# -0.979
# start
# -0.979
# start
# -0.979
# start
# -0.9775
# start
# -0.9805
# start
# -0.9775
# start
# -0.9805
# start
# -0.9775
# start
# -0.979
# start
# -0.982
# start
# -0.976
# start
# -0.9775
# start
# -0.9805
# start
# -0.976
# start
# -0.9775
# start
# -0.982
# start
# -0.979
# start
# -0.9805
# start
# -0.973
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.9745
# start
# -0.979
# start
# -0.9775
# start
# -0.9685
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.982
# start
# -0.9805
# start
# -0.9775
# start
# -0.982
# start
# -0.976
# start
# -0.976
# start
# -0.9805
# start
# -0.982
# start
# -0.9835
# start
# -0.9775
# start
# -0.976
# start
# -0.9805
# start
# -0.979
# start
# -0.9805
# start
# -0.982
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.982
# start
# -0.976
# start
# -0.9805
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.9835
# start
# -0.985
# start
# -0.9805
# start
# -0.976
# start
# -0.9805
# start
# -0.9775
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.979
# start
# -0.979
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.982
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.979
# start
# -0.979
# start
# -0.979
# start
# -0.9775
# start
# -0.9805
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.9745
# start
# -0.976
# start
# -0.982
# start
# -0.985
# start
# -0.9775
# start
# -0.982
# start
# -0.979
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.979
# start
# -0.9775
# start
# -0.9805
# start
# -0.979
# start
# -0.9775
# start
# -0.9805
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9745
# start
# -0.979
# start
# -0.979
# start
# -0.9835
# start
# -0.9835
# start
# -0.9775
# start
# -0.9805
# start
# -0.982
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.982
# start
# -0.9775
# start
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2            |
# |    iterations           | 5            |
# |    time_elapsed         | 4737         |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0056804493 |
# |    clip_fraction        | 0.0761       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.492       |
# |    explained_variance   | 0.741        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000395     |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00457     |
# |    value_loss           | 0.00324      |
# ------------------------------------------
# -0.994
# start
# -0.976
# start
# -0.982
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9835
# start
# -0.979
# start
# -0.9805
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.982
# start
# -0.976
# start
# -0.985
# start
# -0.982
# start
# -0.976
# start
# -0.9805
# start
# -0.979
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.979
# start
# -0.979
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.982
# start
# -0.979
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.973
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.9805
# start
# -0.9835
# start
# -0.9775
# start
# -0.982
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9805
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.9805
# start
# -0.976
# start
# -0.9805
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.97
# start
# -0.9775
# start
# -0.979
# start
# -0.9745
# start
# -0.9745
# start
# -0.9775
# start
# -0.9745
# start
# -0.9745
# start
# -0.979
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.985
# start
# -0.9775
# start
# -0.976
# start
# -0.973
# start
# -0.976
# start
# -0.982
# start
# -0.9775
# start
# -0.9775
# start
# -0.9745
# start
# -0.9805
# start
# -0.9775
# start
# -0.979
# start
# -0.979
# start
# -0.976
# start
# -0.9745
# start
# -0.979
# start
# -0.9745
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.982
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.973
# start
# -0.9745
# start
# -0.979
# start
# -0.9745
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.9835
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2           |
# |    iterations           | 6           |
# |    time_elapsed         | 5618        |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.018403392 |
# |    clip_fraction        | 0.0987      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.497      |
# |    explained_variance   | 0.28        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.036      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00866    |
# |    value_loss           | 0.00276     |
# -----------------------------------------
# -0.988
# start
# -0.979
# start
# -0.9745
# start
# -0.9775
# start
# -0.97
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.982
# start
# -0.9805
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.973
# start
# -0.9775
# start
# -0.97
# start
# -0.979
# start
# -0.973
# start
# -0.979
# start
# -0.9775
# start
# -0.982
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.982
# start
# -0.982
# start
# -0.982
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9805
# start
# -0.976
# start
# -0.9745
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.964
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.973
# start
# -0.9775
# start
# -0.9745
# start
# -0.982
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.973
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.964
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.973
# start
# -0.979
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.973
# start
# -0.9775
# start
# -0.9775
# start
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2           |
# |    iterations           | 7           |
# |    time_elapsed         | 6482        |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.020011788 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.448      |
# |    explained_variance   | 0.553       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000919    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00329    |
# |    value_loss           | 0.00389     |
# -----------------------------------------
# -0.997
# start
# -0.9775
# start
# -0.979
# start
# -0.9595
# start
# -0.979
# start
# -0.9835
# start
# -0.9775
# start
# -0.976
# start
# -0.9805
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.982
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9805
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.979
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.9805
# start
# -0.9775
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.9715
# start
# -0.976
# start
# -0.982
# start
# -0.9775
# start
# -0.9805
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.9805
# start
# -0.9745
# start
# -0.982
# start
# -0.9775
# start
# -0.9775
# start
# -0.9715
# start
# -0.9775
# start
# -0.982
# start
# -0.9745
# start
# -0.9835
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.9805
# start
# -0.9835
# start
# -0.982
# start
# -0.979
# start
# -0.979
# start
# -0.982
# start
# -0.9805
# start
# -0.982
# start
# -0.9745
# start
# -0.979
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.9745
# start
# -0.982
# start
# -0.979
# start
# -0.9805
# start
# -0.976
# start
# -0.979
# start
# -0.979
# start
# -0.982
# start
# -0.976
# start
# -0.9775
# start
# -0.9715
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.9745
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.982
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.979
# start
# -0.979
# start
# -0.982
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.982
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.9745
# start
# -0.9805
# start
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2           |
# |    iterations           | 8           |
# |    time_elapsed         | 7373        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.026090587 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.492      |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0235     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.00334     |
# -----------------------------------------
# -0.9955
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9805
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.973
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.982
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.979
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.973
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.979
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.9745
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.9835
# start
# -0.976
# start
# -0.9805
# start
# -0.979
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.985
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9835
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.9805
# start
# -0.982
# start
# -0.9775
# start
# -0.9745
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2           |
# |    iterations           | 9           |
# |    time_elapsed         | 8239        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.021636201 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.419      |
# |    explained_variance   | 0.563       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0302     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 0.00295     |
# -----------------------------------------
# -0.9925
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.979
# start
# -0.9745
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.979
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9715
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.9805
# start
# -0.979
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9715
# start
# -0.979
# start
# -0.976
# start
# -0.9745
# start
# -0.979
# start
# -0.976
# start
# -0.973
# start
# -0.979
# start
# -0.976
# start
# -0.973
# start
# -0.9775
# start
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2           |
# |    iterations           | 10          |
# |    time_elapsed         | 9079        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.017031215 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.35       |
# |    explained_variance   | 0.0835      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00382    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00539    |
# |    value_loss           | 0.00244     |
# -----------------------------------------
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.979
# start
# -0.9835
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.97
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.979
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.9745
# start
# -0.9745
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.9835
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.9745
# start
# -0.9745
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.979
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.97
# start
# -0.976
# start
# -0.982
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2           |
# |    iterations           | 11          |
# |    time_elapsed         | 9920        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.013491844 |
# |    clip_fraction        | 0.0652      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.325      |
# |    explained_variance   | 0.35        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0378      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00179    |
# |    value_loss           | 0.00184     |
# -----------------------------------------
# -0.9895
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.979
# start
# -0.979
# start
# -0.979
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9715
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.973
# start
# -0.9775
# start
# -0.9805
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.9715
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.979
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.979
# start
# -0.9745
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2           |
# |    iterations           | 12          |
# |    time_elapsed         | 10773       |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.024083473 |
# |    clip_fraction        | 0.133       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.365      |
# |    explained_variance   | 0.682       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0333     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 0.00157     |
# -----------------------------------------
# -0.9835
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.973
# start
# -0.9775
# start
# -0.9805
# start
# -0.979
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9805
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.979
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.979
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -0.982
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.9805
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2          |
# |    iterations           | 13         |
# |    time_elapsed         | 11651      |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.01910925 |
# |    clip_fraction        | 0.14       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.4       |
# |    explained_variance   | 0.757      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0413    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.00995   |
# |    value_loss           | 0.00177    |
# ----------------------------------------
# -0.9955
# start
# -0.979
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.9745
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.9745
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.979
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.97
# start
# -0.9745
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9805
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.9745
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.9715
# start
# -0.9745
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.9745
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.97
# start
# -0.979
# start
# -0.9745
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.979
# start
# -0.976
# start
# -0.9745
# start
# -0.973
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.979
# start
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2           |
# |    iterations           | 14          |
# |    time_elapsed         | 12511       |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017085418 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.4        |
# |    explained_variance   | 0.794       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0144     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 0.00147     |
# -----------------------------------------
# -0.9895
# start
# -0.9745
# start
# -0.9745
# start
# -0.9775
# start
# -0.9805
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9805
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.9745
# start
# -0.9775
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.979
# start
# -0.9805
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.979
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.973
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2           |
# |    iterations           | 15          |
# |    time_elapsed         | 13362       |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.012389492 |
# |    clip_fraction        | 0.0965      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.361      |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0103     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 0.0016      |
# -----------------------------------------
# -0.991
# start
# -0.9745
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9715
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.979
# start
# -0.9745
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.9745
# start
# -0.973
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.979
# start
# -0.9745
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.9805
# start
# -0.976
# start
# -0.9745
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.979
# start
# -0.9745
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.979
# start
# -0.97
# start
# -0.979
# start
# -0.97
# start
# -0.973
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.9745
# start
# -0.97
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -0.973
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.973
# start
# -0.9775
# start
# -0.979
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.9775
# start
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2          |
# |    iterations           | 16         |
# |    time_elapsed         | 14208      |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01930637 |
# |    clip_fraction        | 0.11       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.33      |
# |    explained_variance   | 0.802      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0139    |
# |    n_updates            | 160        |
# |    policy_gradient_loss | -0.0121    |
# |    value_loss           | 0.00134    |
# ----------------------------------------
# -0.985
# start
# -0.979
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.973
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9685
# start
# -0.9745
# start
# -0.9745
# start
# -0.9745
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.9685
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9745
# start
# -0.9745
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.9745
# start
# -0.9805
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.979
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.97
# start
# -0.976
# start
# -0.979
# start
# -0.9745
# start
# -0.9745
# start
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 2          |
# |    iterations           | 17         |
# |    time_elapsed         | 15043      |
# |    total_timesteps      | 34816      |
# | train/                  |            |
# |    approx_kl            | 0.03048764 |
# |    clip_fraction        | 0.124      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.316     |
# |    explained_variance   | 0.566      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0346    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.00925   |
# |    value_loss           | 0.00138    |
# ----------------------------------------
# -0.997
# start
# -0.9745
# start
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.973
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9775
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# -0.9745
# start
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# -0.9775
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.979
# start
# -0.9775
# start
# -0.976
# start
# -0.9715
# start
# -0.9775
# start
# -0.9775
# start
# -0.976
# start
# -0.979
# start
# -0.979
# start
# -0.9745
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9715
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.97
# start
# -0.9775
# start
# -0.9745
# start
# -0.976
# start
# -0.976
# start
# -0.9745
# start
# -0.976
# start
# -0.9745
# start
# -0.9775
# start
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-15447b9f76c9> in <module>
#      32     except:
#      33         print("cnat load")
# ---> 34     model.learn(total_timesteps=250000)
#      35     model.save("ppo_flappy_new"+str(i))
#      36     #model.save_replay_buffer("ppo_flappy_new_replay"+str(i))
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines3/ppo/ppo.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     306             tb_log_name=tb_log_name,
#     307             eval_log_path=eval_log_path,
# --> 308             reset_num_timesteps=reset_num_timesteps,
#     309         )
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     232         while self.num_timesteps < total_timesteps:
#     233
# --> 234             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     235
#     236             if continue_training is False:
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines3/common/on_policy_algorithm.py in collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     173                 clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
#     174
# --> 175             new_obs, rewards, dones, infos = env.step(clipped_actions)
#     176
#     177             self.num_timesteps += env.num_envs
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines3/common/vec_env/base_vec_env.py in step(self, actions)
#     160         """
#     161         self.step_async(actions)
# --> 162         return self.step_wait()
#     163
#     164     def get_images(self) -> Sequence[np.ndarray]:
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines3/common/vec_env/vec_transpose.py in step_wait(self)
#      81
#      82     def step_wait(self) -> VecEnvStepReturn:
# ---> 83         observations, rewards, dones, infos = self.venv.step_wait()
#      84
#      85         # Transpose the terminal observations
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines3/common/vec_env/vec_frame_stack.py in step_wait(self)
#      46     ) -> Tuple[Union[np.ndarray, Dict[str, np.ndarray]], np.ndarray, np.ndarray, List[Dict[str, Any]],]:
#      47
# ---> 48         observations, rewards, dones, infos = self.venv.step_wait()
#      49
#      50         observations, infos = self.stackedobs.update(observations, dones, infos)
#
# ~/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py in step_wait(self)
#      47                 # save final observation where user can get it, then reset
#      48                 self.buf_infos[env_idx]["terminal_observation"] = obs
# ---> 49                 obs = self.envs[env_idx].reset()
#      50             self._save_obs(env_idx, obs)
#      51         return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones), deepcopy(self.buf_infos))
#
# <ipython-input-4-d20ae92f1fdb> in reset(self)
#     141
#     142     def reset(self):
# --> 143         self.state = self.env.reset()
#     144         #self.reward = np.array([reward])
#     145         #self.state = self.state.tolist()
#
# <ipython-input-3-f8dcd82b4937> in reset(self)
#     116         time.sleep(.425)
#     117         pyautogui.click(x=795, y= 219, button='left')
# --> 118         time.sleep(.425)
#     119         pyautogui.click(x=795, y= 219, button='left')
#     120
#
# KeyboardInterrupt:

# %%
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.cmd_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack ,DummyVecEnv, VecNormalize
from stable_baselines3 import A2C, PPO, DQN
import torch

# There already exists an environment generator
# that will make and wrap atari environments correctly.
# Here we are also multi-worker training (n_envs=4 => 4 environments)
env = Template_Gym()
#env = Controller_Gym(env)
env = DummyVecEnv([lambda: env])
#obs = env.reset()
# It will check your custom environment and output additional warnings if needed
#check_env(env)
#env = VecFrameStack(env,4)
#env = ScaledFloatFrame(env)
#env = MaxAndSkipEnv(env, skip=1)
#env = BufferWrapper(env, 2)
#env = DummyVecEnv(env)
#env2 = make_atari_env(env, n_envs=1, seed=0)
#Frame-stacking with 4 frames
#env = VecNormalize(env)
env = VecFrameStack(env, n_stack=4)
model = DQN.load("./logs/rl_model_712500_steps")
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=20, deterministic=True)

print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# start
# -0.973
# start
# -0.9445
# start
# -0.973
# start
# -0.976
# start
# -0.976
# start
# -0.9279999999999999
# start
# -0.976
# start
# -0.9129999999999999
# start
# -0.943
# start
# -0.979
# start
# -0.9775
# start
# -0.9595
# start
# -0.9715
# start
# -0.9129999999999999
# start
# -0.964
# start
# -0.9715
# start
# -0.973
# start
# -0.9595
# start
# -0.9715
# start
# -0.9595
# start
# mean_reward=-0.96 +/- 0.020404411465120505

# %%
# !pip install split-folders tqdm
# Out:
# Requirement already satisfied: split-folders in /home/adaptationai/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages (0.4.3)
# Requirement already satisfied: tqdm in /home/adaptationai/anaconda3/envs/Shaman-AI/lib/python3.6/site-packages (4.62.2)

# %%
import splitfolders
splitfolders.ratio('home/adaptationai/Documents/git/adaptationio/Shaman-AI/Shaman-AI/images', output="/home/adaptationai/Documents/git/adaptationio/Shaman-AI/Shaman-AI/output", seed=1337, ratio=(.8, 0.2,0.0))
# Out:
# Copying files: 0 files [00:00, ? files/s]

# %%
import splitfolders  
# The path to the directory where the original dataset was uncompressed
input_folder = '/home/adaptationai/Documents/git/adaptationio/Shaman-AI/Shaman-AI/images'
# The directory where we will store our smaller dataset
output_folder = '/home/adaptationai/Documents/git/adaptationio/Shaman-AI/Shaman-AI/output'

splitfolders.ratio(input_folder, output_folder, seed=1337, ratio=(.8, .1, .1), group_prefix=None)
# Out:
# Copying files: 447 files [00:00, 10062.22 files/s]

# %%
r= [(0,None), (1,None)]
#2 = (np.array(r), None)
r2 = (r[0], None)
r3 = (r[0], None)
print(r2)
print(r2[0])
print(r3)
#response = (r)
#print(response)
#print(response[0])
# Out:
# ((0, None), None)
# (0, None)
# ((0, None), None)

# %%
from stable_baselines3.common.cmd_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack ,DummyVecEnv
from stable_baselines3 import A2C, PPO, DQN
import torch
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.env_checker import check_env

env = Template_Gym()
env = DummyVecEnv([lambda: env])
#obs = env.reset()
# It will check your custom environment and output additional warnings if needed
#check_env(env)
env = VecFrameStack(env,4)
# There already exists an environment generator
# that will make and wrap atari environments correctly.
# Here we are also multi-worker training (n_envs=4 => 4 environments)
#env = Template_Gym()
#env = MaxAndSkipEnv(env, skip=4)
#env = ProcessFrame84(env)
#env = ImageToPyTorch(env) 
#env = BufferWrapper(env, 4)
#obs = env.reset()
#obs = env.step(1)
#bs = env.step(4)
#obs = env.step(4)
#obs = env.step(4)
obs.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-505a6a7f7ad5> in <module>
#      25 #obs = env.step(4)
#      26 #obs = env.step(4)
# ---> 27 obs.shape
#
# NameError: name 'obs' is not defined

# %%
from stable_baselines3.common.cmd_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3 import A2C, PPO, DQN
import torch
# There already exists an environment generator
# that will make and wrap atari environments correctly.
# Here we are also multi-worker training (n_envs=4 => 4 environments)
env = Template_Gym()
#env = make_atari_env(env, n_envs=1, seed=0)
#Frame-stacking with 4 frames
#env = VecFrameStack(env, n_stack=4)

#model = PPO('CnnPolicy', env, verbose=1)
#model.learn(total_timesteps=250000)

obs = env.reset()
obs.shape
# Out:
# [([[12, 8], [124, 8], [124, 34], [12, 34]], 'RESTART', 0.9832305775554079)]
# RESTART
# start
# (84, 84, 1)

# %%
from stable_baselines3.common.cmd_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3 import A2C
import torch
# There already exists an environment generator
# that will make and wrap atari environments correctly.
# Here we are also multi-worker training (n_envs=4 => 4 environments)
env = make_atari_env('PongNoFrameskip-v4', n_envs=1, seed=0)
# Frame-stacking with 4 frames
env = VecFrameStack(env, n_stack=4)

model = A2C('CnnPolicy', env, verbose=1)
#model.learn(total_timesteps=25000)

obs = env.reset()
#while True:
    #action, _states = model.predict(obs)
    #obs, rewards, dones, info = env.step(action)
    #env.render()
obs.shape
# Out:
# Using cuda device
# Wrapping the env in a VecTransposeImage.
# (1, 84, 84, 4)

# %%
! wget http://www.atarimania.com/roms/Roms.rar
! mkdir /content/ROM/
! unrar e /content/Roms.rar /content/ROM/
! python -m atari_py.import_roms /content/ROM/
# Out:
# --2021-09-13 08:56:44--  http://www.atarimania.com/roms/Roms.rar
# Resolving www.atarimania.com (www.atarimania.com)... 195.154.81.199
# Connecting to www.atarimania.com (www.atarimania.com)|195.154.81.199|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11128004 (11M) [application/x-rar-compressed]
# Saving to: 'Roms.rar.1’
#
# Roms.rar.1          100%[===================>]  10.61M   175KB/s    in 64s
#
# 2021-09-13 08:57:49 (169 KB/s) - 'Roms.rar.1’ saved [11128004/11128004]
#
# mkdir: cannot create directory ‘/content/ROM/’: No such file or directory
# /bin/bash: unrar: command not found

# %%
import numpy as np
#from utilities import DataGrabber
#import torch
import random
#from ..common import DataGrabber
class TetrisEnv():
    def __init__(self):
        self.love = 14
        self.actions = [1,2,3,4]
        self.state = None
        self.state_full = None
        self.state_current = None
        self.count = 0
        self.load = True
        self.eval = False
        self.live_state =[2]
        self.live = True
        self.player = Player(self.config)
        #self.numbergen = NumberGen()

    
    def make_episode(self):
        #NumberGen.to_array(10000000, True)
        #self.numbergen = NumberGen()
        #self.numbergen.to_array(10000000, True)
        #self.state_full = np.load('data/game10000000.npy')
        #self.state_full []
        print('make episode')

    def make_current_state(self, count):
        if self.live:
            self.state = self.live_state
            
        else:
            start = (0+count+self.rand)
            end = (1001+count+self.rand)
            #self.state = self.state_full[start:end]
            
        return self.state

    def get_state(self):
        self.state_current = self.state[-1]
        return self.state_current

    def step(self, action):
        self.count += 1
        self.player.action(self.state_current, action)
        self.make_current_state(self.count)
        state = self.state_maker()
        reward = self.reward(self.get_state(), self.bet_value)
        self.player.balance += reward
        done = self.done(self.count)
        if done:
            self.render()
        
        return state, reward, done


    def reset(self):
        self.player.balance = 0
        self.count = 0
        self.make_episode()
        #if self.eval:
            #self.rand = np.random.random_integers(len(self.state_full / 10 * 9), len(self.state_full))
        #else:
            #self.rand = np.random.random_integers(len(self.state_full / 10 * 9))
        self.state = self.make_current_state(self.count)
        #print(len(self.state))
        state = self.state_maker()
        return state

    def render(self):
        print(self.player.balance)


    def state_maker(self):
        #user = self.player.details(self.count)
        state_details = self.state_details(self.state)
        count = np.array([self.count])
        state = self.data_grabber.flatten(state_details, count)

        return state

    def reward(self, state):
        reward = 0
    

        return reward
    
    def done(self, count):
        if count == 10000:
            
            return True
        else:
            return False 

    def state_details(self, state):
        ind = Indicators()
        details = []
        mean = ind.mean(state)
        median = ind.mean(state)
        black, red = ind.bandr(state)
        details.append([mean, median, black, red])
        return details[0]
         

         
class Player():
    def __init__(self, config):
        self.config = config
    
    def action_user(self, m_price, pm_price):
        #print(len)
        #self.update(m_price)
        x = input('buy, sell, close, hold?:')
        x = str(x)
        if x == "buy":
            self.open_position_long(m_price, pm_price)
        elif  x == "sell":
            self.open_position_short(m_price, pm_price)
        elif x == "close":
            self.close_position(m_price, pm_price)
        elif x == "hold":
            self.hold_position(m_price, pm_price)
        else:
            self.hold_position(m_price, pm_price)

    def action(self, m_price, action, pm_price):
        #print(len)
        #self.update(m_price)
        x = action
        #x = self.normalize(x)
        #x = int(x)
        #if self.placement < -0.200 or self.placement > 0.200:
            #self.close_position(m_price, pm_price)
        if self.config.buy == True:
        
            if x == 2:
                self.open_position_long(m_price, pm_price, x)
            elif x == 1:
                self.close_position(m_price, pm_price, x)
            elif x == 0:
                self.open_position_short(m_price, pm_price, x)
        else:   
            if x == 0:
                self.open_position_short(m_price, pm_price, x)
            elif x == 1:
                self.close_position(m_price, pm_price, x)
            elif x == 2:
                self.open_position_long(m_price, pm_price, x)
        if x == 3:
            self.hold_position(m_price, pm_price)

class PlayerAI():
    def __init__(self, config):
        self.config = config
        

    def action_user(self, m_price, pm_price):
        #print(len)
        #self.update(m_price)
        x = input('buy, sell, close, hold?:')
        x = str(x)
        if x == "buy":
            self.open_position_long(m_price, pm_price)
        elif  x == "sell":
            self.open_position_short(m_price, pm_price)
        elif x == "close":
            self.close_position(m_price, pm_price)
        elif x == "hold":
            self.hold_position(m_price, pm_price)
        else:
            self.hold_position(m_price, pm_price)

    def action(self, m_price, action, pm_price):
        #print(len)
        #self.update(m_price)
        x = action
        #x = self.normalize(x)
        #x = int(x)
        #if self.placement < -0.200 or self.placement > 0.200:
            #self.close_position(m_price, pm_price)
        if self.config.buy == True:
        
            if x == 2:
                self.open_position_long(m_price, pm_price, x)
            elif x == 1:
                self.close_position(m_price, pm_price, x)
            elif x == 0:
                self.open_position_short(m_price, pm_price, x)
        else:   
            if x == 0:
                self.open_position_short(m_price, pm_price, x)
            elif x == 1:
                self.close_position(m_price, pm_price, x)
            elif x == 2:
                self.open_position_long(m_price, pm_price, x)
        if x == 3:
            self.hold_position(m_price, pm_price)

# %%
import numpy as np
import pyautogui
import imutils
import cv2
import pytesseract
from pynput import mouse
import time
import easyocr
#pytesseract.pytesseract.tesseract_cmd = r'C:\Users\adaptation\anaconda3\envs\Shaman-AI\Library\bin\tesseract.exe'

# %%
while True:
    try:

        state= pyautogui.screenshot(region=(1025, 260, 100, 50))
        state = cv2.cvtColor(np.array(state), cv2.COLOR_RGB2BGR)
        cv2.imshow("Stream", state)
        if cv2.waitKey(1)& 0xFF == ord('q'):
            break      
    except KeyboardInterrupt:
        cv2.destroyAllWindows()
        break

# %%
class ImageProcess():
    def __init__(self):
        self.love = "ramona"
        self.reader = easyocr.Reader(['en'])

    def on_click(self, x, y, button, pressed):
        if button == mouse.Button.left:
            print('{} at {}'.format('Pressed Left Click' if pressed else 'Released Left Click', (x, y)))
        
            return False # Returning False if you need to stop the program when Left clicked.
        else:
            print('{} at {}'.format('Pressed Right Click' if pressed else 'Released Right Click', (x, y)))
            return False # Returning False if you need to stop the program when Left clicked.

    def get_position(self):
        print("Please select top corner")
        listener = mouse.Listener(on_click=self.on_click)
        listener.start()
        listener.join()
        X=pyautogui.position()
        self.topx = X[0]
        self.topy= X[1]
        time.sleep(1)
        print(self.topx)
        print(self.topy)
        print("Please select bottom corner")
        listener = mouse.Listener(on_click=self.on_click)
        listener.start()
        listener.join()
        B=pyautogui.position()
        self.bottomx = B[0]
        self.bottomy= B[1]
        print(self.bottomx)
        print(self.bottomy)
        return self.topx, self.topy, self.bottomx, self.bottomy

    def image_ocr(self):
        topx = self.topx
        topy = self.topy
        bottomx = self.bottomx - topx
        bottomy =  self.bottomy - topy
        state= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
        #state = cv2.cvtColor(np.array(state), cv2.COLOR_BGR2GRAY)
        state = cv2.cvtColor(np.array(state), cv2.COLOR_RGB2BGR)
        #cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        text = pytesseract.image_to_string(state)
        print(text)
        return text

    def easy_ocr(self):
        topx = self.topx
        topy = self.topy
        bottomx = self.bottomx - topx
        bottomy =  self.bottomy - topy
        state= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
        state = cv2.cvtColor(np.array(state), cv2.COLOR_RGB2BGR)

        #state = 255 - cv2.threshold(state, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

        # Blur and perform text extraction
        #state = cv2.GaussianBlur(state, (3,3), 0)
        #self.reader = easyocr.Reader(['en'])
        result = self.reader.readtext(state)
        return result

    

    def image_ocr_2(self):
        topx = self.topx
        topy = self.topy
        bottomx = self.bottomx - topx
        bottomy =  self.bottomy - topy
        custom_config = r'--oem 3 --psm 10'
        image = pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
        gray= cv2.cvtColor(np.array(image), cv2.COLOR_BGR2GRAY)
        thresh = 255 - cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

        # Blur and perform text extraction
        thresh = cv2.GaussianBlur(thresh, (3,3), 0)
        text = pytesseract.image_to_string(thresh, config=custom_config)
        print(text)
        return text

    def image_stream(self):
        topx = self.topx
        topy = self.topy
        bottomx = self.bottomx - topx
        bottomy =  self.bottomy - topy 
        while True:
            try:
                state= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
                state = cv2.cvtColor(np.array(state), cv2.COLOR_RGB2BGR)
                cv2.imshow("Stream", state)
                if cv2.waitKey(1)& 0xFF == ord('q'):
                    break      
            except KeyboardInterrupt:
                cv2.destroyAllWindows()
                break

# %%
image_process = ImageProcess()
image_process.get_position()
#image_process. image_ocr()
#image_process.image_stream()
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# Please select top corner
# Pressed Left Click at (847, 543)
# 847
# 543
# Please select bottom corner
# Pressed Left Click at (983, 589)
# 983
# 589
# (847, 543, 983, 589)

# %%
image_process.image_stream()

# %%
image_process.image_ocr_2()
# Out:
# (Gera)
# '(Gera)\n\x0c'

# %%
image_process.easy_ocr()
# Out:
# [([[16, 10], [130, 10], [130, 38], [16, 38]], 'RESTART', 0.9978891767276541)]

# %%
def get_position():
    print("Please select top corner")
    listener = mouse.Listener(on_click=on_click)
    listener.start()
    listener.join()
    X=pyautogui.position()
    topx = X[0]
    topy= X[1]
    time.sleep(1)
    print(topx)
    print(topy)
    print("Please select bottom corner")
    listener = mouse.Listener(on_click=on_click)
    listener.start()
    listener.join()
    B=pyautogui.position()
    bottomx = B[0]
    bottomy= B[1]
    print(bottomx)
    print(bottomy)
    return topx, topy, bottomx, bottomy

# %%
def image_ocr(tx, ty, bx, by):
    topx = tx
    topy = ty
    bottomx = bx - topx
    bottomy =  by - topy
    state= pyautogui.screenshot(region=(int(topx), int(topy), int(bottomx), int(bottomy)))
    state = cv2.cvtColor(np.array(state), cv2.COLOR_RGB2BGR)
    text = pytesseract.image_to_string(state)
    print(text)
    return text

# %%
# break between test and live code

# %%
def on_click(x, y, button, pressed):
    if button == mouse.Button.left:
        print('{} at {}'.format('Pressed Left Click' if pressed else 'Released Left Click', (x, y)))
        
        return False # Returning False if you need to stop the program when Left clicked.
    else:
        print('{} at {}'.format('Pressed Right Click' if pressed else 'Released Right Click', (x, y)))
        return False # Returning False if you need to stop the program when Left clicked.
print("Please select top corner")
listener = mouse.Listener(on_click=on_click)
listener.start()
listener.join()
X=pyautogui.position()
topx = X[0]
topy= X[1]
time.sleep(1)
print(topx)
print(topy)
print("Please select bottom corner")
listener = mouse.Listener(on_click=on_click)
listener.start()
listener.join()
B=pyautogui.position()
bottomx = B[0]
bottomy= B[1]
print(bottomx)
print(bottomy)

# %%
import numpy as np
import pyautogui
import imutils
import cv2
import pytesseract
from bs4 import BeautifulSoup
from selenium import webdriver
import time
# %matplotlib auto

pytesseract.pytesseract.tesseract_cmd = r'C:\Users\adaptation\anaconda3\envs\Shaman-AI\Library\bin\tesseract.exe'
# Out:
# Using matplotlib backend: TkAgg

# %%
image = pyautogui.screenshot(region=(0,0, 290, 30))
image = cv2.cvtColor(np.array(image), cv2.COLOR_RGB2BGR)
#image = cv2.cvtColor(np.array(image), cv2.COLOR_BGR2GRAY)
# image = cv2.GaussianBlur(image, (5, 5), 0)
#image = cv2.Canny(image, 50, 200, 255)
#image = cv2.medianBlur(image,5)
#cv2.imwrite("i1n_memory_to_disk.png", image)
#image = cv2.imread("in_memory_to_disk.png")
#cv2.imshow('HSV image', image); cv2.waitKey(1); cv2.destroyAllWindows(); cv2.waitKey(1)
#pytesseract.image_to_string(image, lang='eng', \
#config='--psm 10 --oem 3 -c tessedit_char_whitelist=0123456789')
#custom_config = r'--oem 1 --psm 1'
#custom_config = r'--oem 3 --psm 6'
#game = pytesseract.image_to_string(image, config=custom_config)
#game = game.replace('x', '')
#game = game.replace('%', '')
#games.append(float(game))
#count = count + 1
#print(game)
text = pytesseract.image_to_string(image)
print(text)
# Out:
# lamenimenemen Ca

# %%
while True:
    try:

        state= pyautogui.screenshot(region=(538, 373, 800, 600))
        state = cv2.cvtColor(np.array(state), cv2.COLOR_RGB2BGR)
        cv2.imshow("Stream", state)
        if cv2.waitKey(1)& 0xFF == ord('q'):
            break      
    except KeyboardInterrupt:
        cv2.destroyAllWindows()
        break

# %%
#from stable_baselines3.common.cmd_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack ,DummyVecEnv, VecNormalize
from stable_baselines3 import A2C, PPO, DQN
import torch
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.callbacks import CheckpointCallback, EveryNTimesteps

# There already exists an environment generator
# that will make and wrap atari environments correctly.
# Here we are also multi-worker training (n_envs=4 => 4 environments)
env = Template_Gym()
#env = Controller_Gym(env)
env = DummyVecEnv([lambda: env])
#obs = env.reset()
# It will check your custom environment and output additional warnings if needed
#check_env(env)
#env = VecFrameStack(env,4)
#env = ScaledFloatFrame(env)
#env = MaxAndSkipEnv(env, skip=1)
#env = BufferWrapper(env, 2)
#env = DummyVecEnv(env)
#env2 = make_atari_env(env, n_envs=1, seed=0)
#Frame-stacking with 4 frames
#env = VecNormalize(env)
env = VecFrameStack(env, n_stack=4)

checkpoint_on_event = CheckpointCallback(save_freq=1, save_path='./logsnew/')
event_callback = EveryNTimesteps(n_steps=2500, callback=checkpoint_on_event)

model = DQN('MlpPolicy', env, verbose=1)
#model.load("dgn_flappy_new"+str(0))
for i in range(100):
    try:
        model.load("dgn_flappy_mlp"+str(i-1))
        model.load_replay_buffer("dgn_flappy_new_mlp"+str(i-1))
    except:
        print("cnat load")
    model.learn(total_timesteps=2500000, callback=event_callback)
    model.save("dgn_flappy_mlp"+str(i))
    model.save_replay_buffer("dgn_flappy_new_mlp"+str(i))
    

#obs = env.reset()
#while True:
    #action, _states = model.predict(obs)
    #print(model.predict(obs))
    #print(model.predict(obs[0]))
    #obs, rewards, dones, info = env.step(action)
    #env.render()

#model.save("ppo_flappy_3")
# Out:
# Using cuda device
# cnat load
# start
# -0.9835
# start
# -0.979
# start
# -0.9805
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 1        |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1        |
# |    time_elapsed     | 33       |
# |    total timesteps  | 52       |
# ----------------------------------
# -0.9805
# start
# -0.9745
# start
# -0.9805
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 1        |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1        |
# |    time_elapsed     | 59       |
# |    total timesteps  | 109      |
# ----------------------------------
# -0.979
# start
# -0.982
# start
# -0.982
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.999    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1        |
# |    time_elapsed     | 85       |
# |    total timesteps  | 159      |
# ----------------------------------
# -0.9835
# start
# -0.9835
# start
# -0.982
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.999    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1        |
# |    time_elapsed     | 111      |
# |    total timesteps  | 206      |
# ----------------------------------
# -0.979
# start
# -0.979
# start
# -0.9835
# start
# -0.9835
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.999    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1        |
# |    time_elapsed     | 137      |
# |    total timesteps  | 256      |
# ----------------------------------
# -0.982
# start
# -0.982
# start
# -0.982
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.999    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1        |
# |    time_elapsed     | 163      |
# |    total timesteps  | 304      |
# ----------------------------------
# -0.9805
# start
# -0.9775
# start
# -0.9775
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.999    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1        |
# |    time_elapsed     | 189      |
# |    total timesteps  | 360      |
# ----------------------------------
# -0.9805
# start
# -0.982
# start
# -0.9805
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.998    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1        |
# |    time_elapsed     | 215      |
# |    total timesteps  | 411      |
# ----------------------------------
# -0.9805
# start
# -0.982
# start
# -0.982
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.998    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1        |
# |    time_elapsed     | 241      |
# |    total timesteps  | 461      |
# ----------------------------------
# -0.9805
# start
# -0.9805
# start
# -0.979
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.998    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1        |
# |    time_elapsed     | 267      |
# |    total timesteps  | 514      |
# ----------------------------------
# -0.982
# start
# -0.982
# start
# -0.982
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.998    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1        |
# |    time_elapsed     | 293      |
# |    total timesteps  | 563      |
# ----------------------------------
# -0.9805
# start
# -0.9745
# start
# -0.9805
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.998    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1        |
# |    time_elapsed     | 320      |
# |    total timesteps  | 619      |
# ----------------------------------
# -0.9775
# start
# -0.9805
# start
# -0.979
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.997    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1        |
# |    time_elapsed     | 346      |
# |    total timesteps  | 674      |
# ----------------------------------
# -0.9835
# start
# -0.976
# start
# -0.982
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.997    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1        |
# |    time_elapsed     | 372      |
# |    total timesteps  | 727      |
# ----------------------------------
# -0.979
# start
# -0.9805
# start
# -0.9775
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.997    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1        |
# |    time_elapsed     | 398      |
# |    total timesteps  | 781      |
# ----------------------------------
# -0.9805
# start
# -0.982
# start
# -0.9835
# start
# -0.9775
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.997    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1        |
# |    time_elapsed     | 427      |
# |    total timesteps  | 832      |
# ----------------------------------
# -0.9775
# start
# -0.982
# start
# -0.979
# start
# -0.9775
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.997    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1        |
# |    time_elapsed     | 454      |
# |    total timesteps  | 888      |
# ----------------------------------
# -0.9835
# start
# -0.982
# start
# -0.9775
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.996    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1        |
# |    time_elapsed     | 480      |
# |    total timesteps  | 939      |
# ----------------------------------
# -0.9775
# start
# -0.979
# start
# -0.982
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.996    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1        |
# |    time_elapsed     | 506      |
# |    total timesteps  | 994      |
# ----------------------------------
# -0.9805
# start
# -0.979
# start
# -0.979
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.996    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1        |
# |    time_elapsed     | 532      |
# |    total timesteps  | 1048     |
# ----------------------------------
# -0.979
# start
# -0.9805
# start
# -0.982
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.996    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1        |
# |    time_elapsed     | 558      |
# |    total timesteps  | 1099     |
# ----------------------------------
# -0.982
# start
# -0.985
# start
# -0.982
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.996    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1        |
# |    time_elapsed     | 584      |
# |    total timesteps  | 1147     |
# ----------------------------------
# -0.982
# start
# -0.979
# start
# -0.9805
# start
# -0.9775
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.995    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1        |
# |    time_elapsed     | 610      |
# |    total timesteps  | 1201     |
# ----------------------------------
# -0.973
# start
# -0.9805
# start
# -0.979
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.995    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1        |
# |    time_elapsed     | 637      |
# |    total timesteps  | 1259     |
# ----------------------------------
# -0.979
# start
# -0.976
# start
# -0.979
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.995    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1        |
# |    time_elapsed     | 663      |
# |    total timesteps  | 1315     |
# ----------------------------------
# -0.982
# start
# -0.9805
# start
# -0.985
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.995    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1        |
# |    time_elapsed     | 689      |
# |    total timesteps  | 1362     |
# ----------------------------------
# -0.9805
# start
# -0.9835
# start
# -0.979
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.995    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1        |
# |    time_elapsed     | 715      |
# |    total timesteps  | 1412     |
# ----------------------------------
# -0.982
# start
# -0.9805
# start
# -0.979
# start
# -0.985
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.994    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1        |
# |    time_elapsed     | 741      |
# |    total timesteps  | 1461     |
# ----------------------------------
# -0.9805
# start
# -0.982
# start
# -0.979
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.994    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1        |
# |    time_elapsed     | 767      |
# |    total timesteps  | 1513     |
# ----------------------------------
# -0.9805
# start
# -0.979
# start
# -0.982
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.994    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1        |
# |    time_elapsed     | 793      |
# |    total timesteps  | 1565     |
# ----------------------------------
# -0.9835
# start
# -0.9775
# start
# -0.9805
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.994    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1        |
# |    time_elapsed     | 819      |
# |    total timesteps  | 1617     |
# ----------------------------------
# -0.982
# start
# -0.9775
# start
# -0.9805
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.994    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1        |
# |    time_elapsed     | 845      |
# |    total timesteps  | 1671     |
# ----------------------------------
# -0.9835
# start
# -0.9775
# start
# -0.9745
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.993    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1        |
# |    time_elapsed     | 872      |
# |    total timesteps  | 1727     |
# ----------------------------------
# -0.985
# start
# -0.9805
# start
# -0.985
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.993    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1        |
# |    time_elapsed     | 898      |
# |    total timesteps  | 1773     |
# ----------------------------------
# -0.9835
# start
# -0.982
# start
# -0.982
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.993    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1        |
# |    time_elapsed     | 924      |
# |    total timesteps  | 1820     |
# ----------------------------------
# -0.9805
# start
# -0.9805
# start
# -0.9745
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.993    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1        |
# |    time_elapsed     | 950      |
# |    total timesteps  | 1876     |
# ----------------------------------
# -0.9835
# start
# -0.979
# start
# -0.9775
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.993    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1        |
# |    time_elapsed     | 976      |
# |    total timesteps  | 1928     |
# ----------------------------------
# -0.985
# start
# -0.9835
# start
# -0.9805
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.992    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1        |
# |    time_elapsed     | 1002     |
# |    total timesteps  | 1975     |
# ----------------------------------
# -0.9805
# start
# -0.9805
# start
# -0.9775
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.992    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1        |
# |    time_elapsed     | 1028     |
# |    total timesteps  | 2029     |
# ----------------------------------
# -0.982
# start
# -0.9775
# start
# -0.9775
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.992    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1        |
# |    time_elapsed     | 1055     |
# |    total timesteps  | 2084     |
# ----------------------------------
# -0.982
# start
# -0.982
# start
# -0.976
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.992    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1        |
# |    time_elapsed     | 1081     |
# |    total timesteps  | 2137     |
# ----------------------------------
# -0.9805
# start
# -0.9805
# start
# -0.982
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.992    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1        |
# |    time_elapsed     | 1107     |
# |    total timesteps  | 2188     |
# ----------------------------------
# -0.982
# start
# -0.979
# start
# -0.982
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.991    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1        |
# |    time_elapsed     | 1132     |
# |    total timesteps  | 2238     |
# ----------------------------------
# -0.982
# start
# -0.982
# start
# -0.9805
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.991    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1        |
# |    time_elapsed     | 1159     |
# |    total timesteps  | 2287     |
# ----------------------------------
# -0.9805
# start
# -0.979
# start
# -0.9775
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.991    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1        |
# |    time_elapsed     | 1185     |
# |    total timesteps  | 2342     |
# ----------------------------------
# -0.9805
# start
# -0.9775
# start
# -0.982
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.991    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1        |
# |    time_elapsed     | 1211     |
# |    total timesteps  | 2396     |
# ----------------------------------
# -0.9805
# start
# -0.982
# start
# -0.979
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.991    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1        |
# |    time_elapsed     | 1237     |
# |    total timesteps  | 2449     |
# ----------------------------------
# -0.9805
# start
# -0.982
# start
# -0.9835
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.991    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1        |
# |    time_elapsed     | 1264     |
# |    total timesteps  | 2497     |
# ----------------------------------
# -0.9805
# start
# -0.9805
# start
# -0.982
# start
# -0.9835
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.99     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1        |
# |    time_elapsed     | 1290     |
# |    total timesteps  | 2546     |
# ----------------------------------
# -0.9835
# start
# -0.982
# start
# -0.979
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.99     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1        |
# |    time_elapsed     | 1316     |
# |    total timesteps  | 2595     |
# ----------------------------------
# -0.982
# start
# -0.979
# start
# -0.979
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.99     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1        |
# |    time_elapsed     | 1342     |
# |    total timesteps  | 2649     |
# ----------------------------------
# -0.985
# start
# -0.9805
# start
# -0.985
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.99     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1        |
# |    time_elapsed     | 1368     |
# |    total timesteps  | 2695     |
# ----------------------------------
# -0.9835
# start
# -0.979
# start
# -0.979
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.99     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1        |
# |    time_elapsed     | 1395     |
# |    total timesteps  | 2746     |
# ----------------------------------
# -0.9835
# start
# -0.9835
# start
# -0.9805
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.989    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1        |
# |    time_elapsed     | 1421     |
# |    total timesteps  | 2795     |
# ----------------------------------
# -0.976
# start
# -0.9805
# start
# -0.985
# start
# -0.9775
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.989    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1        |
# |    time_elapsed     | 1447     |
# |    total timesteps  | 2849     |
# ----------------------------------
# -0.982
# start
# -0.9775
# start
# -0.9805
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.989    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1        |
# |    time_elapsed     | 1473     |
# |    total timesteps  | 2902     |
# ----------------------------------
# -0.982
# start
# -0.982
# start
# -0.979
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.989    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1        |
# |    time_elapsed     | 1499     |
# |    total timesteps  | 2952     |
# ----------------------------------
# -0.9805
# start
# -0.979
# start
# -0.9805
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.989    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1        |
# |    time_elapsed     | 1525     |
# |    total timesteps  | 3005     |
# ----------------------------------
# -0.982
# start
# -0.9805
# start
# -0.9805
# start
# -0.9775
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.988    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1        |
# |    time_elapsed     | 1551     |
# |    total timesteps  | 3058     |
# ----------------------------------
# -0.9775
# start
# -0.9835
# start
# -0.9805
# start
# -0.9835
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.988    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1        |
# |    time_elapsed     | 1581     |
# |    total timesteps  | 3108     |
# ----------------------------------
# -0.9835
# start
# -0.982
# start
# -0.979
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.988    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1        |
# |    time_elapsed     | 1607     |
# |    total timesteps  | 3159     |
# ----------------------------------
# -0.9775
# start
# -0.9805
# start
# -0.9775
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.988    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1        |
# |    time_elapsed     | 1633     |
# |    total timesteps  | 3215     |
# ----------------------------------
# -0.9805
# start
# -0.9805
# start
# -0.979
# start
# -0.985
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.988    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1        |
# |    time_elapsed     | 1659     |
# |    total timesteps  | 3265     |
# ----------------------------------
# -0.9805
# start
# -0.982
# start
# -0.979
# start
# -0.9835
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.987    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1        |
# |    time_elapsed     | 1685     |
# |    total timesteps  | 3315     |
# ----------------------------------
# -0.982
# start
# -0.982
# start
# -0.982
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.987    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1        |
# |    time_elapsed     | 1711     |
# |    total timesteps  | 3365     |
# ----------------------------------
# -0.9835
# start
# -0.9805
# start
# -0.9805
# start
# -0.973
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.987    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1        |
# |    time_elapsed     | 1738     |
# |    total timesteps  | 3420     |
# ----------------------------------
# -0.982
# start
# -0.982
# start
# -0.9805
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.987    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1        |
# |    time_elapsed     | 1764     |
# |    total timesteps  | 3470     |
# ----------------------------------
# -0.982
# start
# -0.9805
# start
# -0.982
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.987    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1        |
# |    time_elapsed     | 1790     |
# |    total timesteps  | 3520     |
# ----------------------------------
# -0.976
# start
# -0.979
# start
# -0.9835
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.986    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1        |
# |    time_elapsed     | 1816     |
# |    total timesteps  | 3573     |
# ----------------------------------
# -0.982
# start
# -0.9805
# start
# -0.9775
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.986    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1        |
# |    time_elapsed     | 1842     |
# |    total timesteps  | 3625     |
# ----------------------------------
# -0.9835
# start
# -0.9805
# start
# -0.982
# start
# -0.9775
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.986    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1        |
# |    time_elapsed     | 1868     |
# |    total timesteps  | 3676     |
# ----------------------------------
# -0.9775
# start
# -0.982
# start
# -0.9805
# start
# -0.9835
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.986    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1        |
# |    time_elapsed     | 1894     |
# |    total timesteps  | 3727     |
# ----------------------------------
# -0.9835
# start
# -0.9805
# start
# -0.9805
# start
# -0.9775
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.986    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1        |
# |    time_elapsed     | 1920     |
# |    total timesteps  | 3779     |
# ----------------------------------
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.985    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1        |
# |    time_elapsed     | 1947     |
# |    total timesteps  | 3837     |
# ----------------------------------
# -0.9805
# start
# -0.979
# start
# -0.9835
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.985    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1        |
# |    time_elapsed     | 1973     |
# |    total timesteps  | 3888     |
# ----------------------------------
# -0.9835
# start
# -0.982
# start
# -0.9805
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.985    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1        |
# |    time_elapsed     | 1999     |
# |    total timesteps  | 3937     |
# ----------------------------------
# -0.982
# start
# -0.9805
# start
# -0.9745
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.985    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1        |
# |    time_elapsed     | 2025     |
# |    total timesteps  | 3991     |
# ----------------------------------
# -0.979
# start
# -0.9805
# start
# -0.9835
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.985    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1        |
# |    time_elapsed     | 2052     |
# |    total timesteps  | 4043     |
# ----------------------------------
# -0.982
# start
# -0.982
# start
# -0.976
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.984    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1        |
# |    time_elapsed     | 2078     |
# |    total timesteps  | 4097     |
# ----------------------------------
# -0.9745
# start
# -0.9805
# start
# -0.985
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.984    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1        |
# |    time_elapsed     | 2104     |
# |    total timesteps  | 4149     |
# ----------------------------------
# -0.9805
# start
# -0.9835
# start
# -0.982
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.984    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1        |
# |    time_elapsed     | 2130     |
# |    total timesteps  | 4199     |
# ----------------------------------
# -0.979
# start
# -0.9805
# start
# -0.982
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.984    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1        |
# |    time_elapsed     | 2156     |
# |    total timesteps  | 4250     |
# ----------------------------------
# -0.982
# start
# -0.9805
# start
# -0.979
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.984    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1        |
# |    time_elapsed     | 2182     |
# |    total timesteps  | 4301     |
# ----------------------------------
# -0.9835
# start
# -0.9805
# start
# -0.9805
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.983    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1        |
# |    time_elapsed     | 2209     |
# |    total timesteps  | 4351     |
# ----------------------------------
# -0.9805
# start
# -0.982
# start
# -0.979
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.983    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1        |
# |    time_elapsed     | 2235     |
# |    total timesteps  | 4402     |
# ----------------------------------
# -0.982
# start
# -0.982
# start
# -0.979
# start
# -0.976
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.983    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1        |
# |    time_elapsed     | 2261     |
# |    total timesteps  | 4456     |
# ----------------------------------
# -0.979
# start
# -0.982
# start
# -0.982
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.983    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1        |
# |    time_elapsed     | 2287     |
# |    total timesteps  | 4506     |
# ----------------------------------
# -0.982
# start
# -0.982
# start
# -0.9775
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.983    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1        |
# |    time_elapsed     | 2314     |
# |    total timesteps  | 4559     |
# ----------------------------------
# -0.9805
# start
# -0.985
# start
# -0.979
# start
# -0.9775
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.982    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1        |
# |    time_elapsed     | 2340     |
# |    total timesteps  | 4611     |
# ----------------------------------
# -0.9805
# start
# -0.982
# start
# -0.985
# start
# -0.9835
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.982    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1        |
# |    time_elapsed     | 2366     |
# |    total timesteps  | 4657     |
# ----------------------------------
# -0.982
# start
# -0.979
# start
# -0.976
# start
# -0.9835
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.982    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1        |
# |    time_elapsed     | 2392     |
# |    total timesteps  | 4710     |
# ----------------------------------
# -0.9835
# start
# -0.9775
# start
# -0.9805
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.982    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 1        |
# |    time_elapsed     | 2418     |
# |    total timesteps  | 4762     |
# ----------------------------------
# -0.9835
# start
# -0.982
# start
# -0.982
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.982    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 1        |
# |    time_elapsed     | 2444     |
# |    total timesteps  | 4811     |
# ----------------------------------
# -0.982
# start
# -0.982
# start
# -0.979
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.982    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 1        |
# |    time_elapsed     | 2470     |
# |    total timesteps  | 4862     |
# ----------------------------------
# -0.9805
# start
# -0.9805
# start
# -0.982
# start
# -0.9775
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.981    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 1        |
# |    time_elapsed     | 2496     |
# |    total timesteps  | 4915     |
# ----------------------------------
# -0.9835
# start
# -0.979
# start
# -0.9835
# start
# -0.976
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.981    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 1        |
# |    time_elapsed     | 2522     |
# |    total timesteps  | 4967     |
# ----------------------------------
# -0.9805
# start
# -0.9835
# start
# -0.9805
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.981    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 1        |
# |    time_elapsed     | 2548     |
# |    total timesteps  | 5017     |
# ----------------------------------
# -0.9805
# start
# -0.979
# start
# -0.979
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.981    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 1        |
# |    time_elapsed     | 2574     |
# |    total timesteps  | 5071     |
# ----------------------------------
# -0.9805
# start
# -0.9835
# start
# -0.9805
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.981    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 1        |
# |    time_elapsed     | 2600     |
# |    total timesteps  | 5121     |
# ----------------------------------
# -0.982
# start
# -0.9805
# start
# -0.982
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.98     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 1        |
# |    time_elapsed     | 2627     |
# |    total timesteps  | 5171     |
# ----------------------------------
# -0.982
# start
# -0.9805
# start
# -0.982
# start
# -0.9835
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.98     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 1        |
# |    time_elapsed     | 2653     |
# |    total timesteps  | 5219     |
# ----------------------------------
# -0.9715
# start
# -0.9805
# start
# -0.9805
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.98     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 1        |
# |    time_elapsed     | 2679     |
# |    total timesteps  | 5277     |
# ----------------------------------
# -0.982
# start
# -0.982
# start
# -0.982
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.98     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 1        |
# |    time_elapsed     | 2705     |
# |    total timesteps  | 5325     |
# ----------------------------------
# -0.9805
# start
# -0.982
# start
# -0.9805
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.98     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 1        |
# |    time_elapsed     | 2731     |
# |    total timesteps  | 5375     |
# ----------------------------------
# -0.982
# start
# -0.982
# start
# -0.9745
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.979    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1        |
# |    time_elapsed     | 2758     |
# |    total timesteps  | 5429     |
# ----------------------------------
# -0.9775
# start
# -0.982
# start
# -0.979
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.979    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 1        |
# |    time_elapsed     | 2784     |
# |    total timesteps  | 5482     |
# ----------------------------------
# -0.9805
# start
# -0.9805
# start
# -0.982
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.979    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 1        |
# |    time_elapsed     | 2810     |
# |    total timesteps  | 5534     |
# ----------------------------------
# -0.9805
# start
# -0.9805
# start
# -0.9835
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.979    |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 1        |
# |    time_elapsed     | 2836     |
# |    total timesteps  | 5584     |
# ----------------------------------
# -0.9805
# start
# -0.9805
# start
# -0.982
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.979    |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 1        |
# |    time_elapsed     | 2862     |
# |    total timesteps  | 5635     |
# ----------------------------------
# -0.9805
# start
# -0.982
# start
# -0.9805
# start
# -0.9715
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.978    |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 1        |
# |    time_elapsed     | 2888     |
# |    total timesteps  | 5692     |
# ----------------------------------
# -0.9805
# start
# -0.9835
# start
# -0.979
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.978    |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 1        |
# |    time_elapsed     | 2914     |
# |    total timesteps  | 5743     |
# ----------------------------------
# -0.982
# start
# -0.982
# start
# -0.982
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.978    |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 1        |
# |    time_elapsed     | 2941     |
# |    total timesteps  | 5792     |
# ----------------------------------
# -0.982
# start
# -0.9805
# start
# -0.982
# start
# -0.9835
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.978    |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 1        |
# |    time_elapsed     | 2967     |
# |    total timesteps  | 5840     |
# ----------------------------------
# -0.9805
# start
# -0.982
# start
# -0.9805
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.978    |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 1        |
# |    time_elapsed     | 2992     |
# |    total timesteps  | 5892     |
# ----------------------------------
# -0.985
# start
# -0.9805
# start
# -0.9775
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.977    |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 1        |
# |    time_elapsed     | 3019     |
# |    total timesteps  | 5944     |
# ----------------------------------
# -0.9805
# start
# -0.9805
# start
# -0.979
# start
# -0.9835
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.977    |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 1        |
# |    time_elapsed     | 3044     |
# |    total timesteps  | 5995     |
# ----------------------------------
# -0.979
# start
# -0.9805
# start
# -0.9805
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.977    |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 1        |
# |    time_elapsed     | 3071     |
# |    total timesteps  | 6048     |
# ----------------------------------
# -0.976
# start
# -0.982
# start
# -0.982
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.977    |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 1        |
# |    time_elapsed     | 3097     |
# |    total timesteps  | 6102     |
# ----------------------------------
# -0.982
# start
# -0.982
# start
# -0.9805
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.977    |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 1        |
# |    time_elapsed     | 3123     |
# |    total timesteps  | 6152     |
# ----------------------------------
# -0.979
# start
# -0.979
# start
# -0.979
# start
# -0.9835
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.976    |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 1        |
# |    time_elapsed     | 3148     |
# |    total timesteps  | 6205     |
# ----------------------------------
# -0.9805
# start
# -0.9835
# start
# -0.9835
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.976    |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 1        |
# |    time_elapsed     | 3174     |
# |    total timesteps  | 6254     |
# ----------------------------------
# -0.982
# start
# -0.982
# start
# -0.9805
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.976    |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 1        |
# |    time_elapsed     | 3200     |
# |    total timesteps  | 6304     |
# ----------------------------------
# -0.979
# start
# -0.9805
# start
# -0.9775
# start
# -0.9835
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.976    |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 1        |
# |    time_elapsed     | 3226     |
# |    total timesteps  | 6357     |
# ----------------------------------
# -0.9775
# start
# -0.9805
# start
# -0.9775
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.976    |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 1        |
# |    time_elapsed     | 3252     |
# |    total timesteps  | 6414     |
# ----------------------------------
# -0.9805
# start
# -0.979
# start
# -0.9805
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.975    |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 1        |
# |    time_elapsed     | 3279     |
# |    total timesteps  | 6466     |
# ----------------------------------
# -0.979
# start
# -0.982
# start
# -0.982
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.975    |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 1        |
# |    time_elapsed     | 3305     |
# |    total timesteps  | 6516     |
# ----------------------------------
# -0.9775
# start
# -0.982
# start
# -0.9805
# start
# -0.976
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.975    |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 1        |
# |    time_elapsed     | 3331     |
# |    total timesteps  | 6572     |
# ----------------------------------
# -0.9805
# start
# -0.9805
# start
# -0.9775
# start
# -0.9835
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.975    |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 1        |
# |    time_elapsed     | 3357     |
# |    total timesteps  | 6624     |
# ----------------------------------
# -0.9805
# start
# -0.9835
# start
# -0.9805
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.975    |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 1        |
# |    time_elapsed     | 3383     |
# |    total timesteps  | 6674     |
# ----------------------------------
# -0.982
# start
# -0.9805
# start
# -0.976
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.974    |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 1        |
# |    time_elapsed     | 3409     |
# |    total timesteps  | 6729     |
# ...
# |    time_elapsed     | 79315    |
# |    total timesteps  | 163022   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.744    |
# |    n_updates        | 28255    |
# ----------------------------------
# -0.979
# start
# -0.979
# start
# -0.979
# start
# -0.9775
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.38     |
# | time/               |          |
# |    episodes         | 12196    |
# |    fps              | 2        |
# |    time_elapsed     | 79341    |
# |    total timesteps  | 163079   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.94     |
# |    n_updates        | 28269    |
# ----------------------------------
# -0.9775
# start
# -0.9775
# start
# -0.9805
# start
# -0.9775
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.38     |
# | time/               |          |
# |    episodes         | 12200    |
# |    fps              | 2        |
# |    time_elapsed     | 79367    |
# |    total timesteps  | 163137   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.744    |
# |    n_updates        | 28284    |
# ----------------------------------
# -0.9805
# start
# -0.9805
# start
# -0.982
# start
# -0.9775
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.38     |
# | time/               |          |
# |    episodes         | 12204    |
# |    fps              | 2        |
# |    time_elapsed     | 79393    |
# |    total timesteps  | 163190   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.499    |
# |    n_updates        | 28297    |
# ----------------------------------
# -0.976
# start
# -0.976
# start
# -0.979
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.38     |
# | time/               |          |
# |    episodes         | 12208    |
# |    fps              | 2        |
# |    time_elapsed     | 79419    |
# |    total timesteps  | 163250   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.627    |
# |    n_updates        | 28312    |
# ----------------------------------
# -0.9805
# start
# -0.9745
# start
# -0.9835
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.379    |
# | time/               |          |
# |    episodes         | 12212    |
# |    fps              | 2        |
# |    time_elapsed     | 79444    |
# |    total timesteps  | 163304   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.238    |
# |    n_updates        | 28325    |
# ----------------------------------
# -0.9775
# start
# -0.9805
# start
# -0.9835
# start
# -0.9745
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.379    |
# | time/               |          |
# |    episodes         | 12216    |
# |    fps              | 2        |
# |    time_elapsed     | 79471    |
# |    total timesteps  | 163360   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.911    |
# |    n_updates        | 28339    |
# ----------------------------------
# -0.982
# start
# -0.9775
# start
# -0.9805
# start
# -0.9775
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.379    |
# | time/               |          |
# |    episodes         | 12220    |
# |    fps              | 2        |
# |    time_elapsed     | 79496    |
# |    total timesteps  | 163415   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.744    |
# |    n_updates        | 28353    |
# ----------------------------------
# -0.976
# start
# -0.9805
# start
# -0.979
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.379    |
# | time/               |          |
# |    episodes         | 12224    |
# |    fps              | 2        |
# |    time_elapsed     | 79522    |
# |    total timesteps  | 163471   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.495    |
# |    n_updates        | 28367    |
# ----------------------------------
# -0.982
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.379    |
# | time/               |          |
# |    episodes         | 12228    |
# |    fps              | 2        |
# |    time_elapsed     | 79548    |
# |    total timesteps  | 163527   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.596    |
# |    n_updates        | 28381    |
# ----------------------------------
# -0.9775
# start
# -0.9745
# start
# -0.979
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.378    |
# | time/               |          |
# |    episodes         | 12232    |
# |    fps              | 2        |
# |    time_elapsed     | 79574    |
# |    total timesteps  | 163587   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.647    |
# |    n_updates        | 28396    |
# ----------------------------------
# -0.9775
# start
# -0.9775
# start
# -0.9805
# start
# -0.976
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.378    |
# | time/               |          |
# |    episodes         | 12236    |
# |    fps              | 2        |
# |    time_elapsed     | 79600    |
# |    total timesteps  | 163646   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.929    |
# |    n_updates        | 28411    |
# ----------------------------------
# -0.9805
# start
# -0.9805
# start
# -0.9805
# start
# -0.9775
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.378    |
# | time/               |          |
# |    episodes         | 12240    |
# |    fps              | 2        |
# |    time_elapsed     | 79626    |
# |    total timesteps  | 163700   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.376    |
# |    n_updates        | 28424    |
# ----------------------------------
# -0.979
# start
# -0.982
# start
# -0.9775
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.378    |
# | time/               |          |
# |    episodes         | 12244    |
# |    fps              | 2        |
# |    time_elapsed     | 79652    |
# |    total timesteps  | 163755   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.55     |
# |    n_updates        | 28438    |
# ----------------------------------
# -0.9775
# start
# -0.976
# start
# -0.9775
# start
# -0.9775
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.377    |
# | time/               |          |
# |    episodes         | 12248    |
# |    fps              | 2        |
# |    time_elapsed     | 79678    |
# |    total timesteps  | 163816   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.808    |
# |    n_updates        | 28453    |
# ----------------------------------
# -0.9775
# start
# -0.9745
# start
# -0.9805
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.377    |
# | time/               |          |
# |    episodes         | 12252    |
# |    fps              | 2        |
# |    time_elapsed     | 79704    |
# |    total timesteps  | 163875   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.596    |
# |    n_updates        | 28468    |
# ----------------------------------
# -0.9805
# start
# -0.976
# start
# -0.979
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.377    |
# | time/               |          |
# |    episodes         | 12256    |
# |    fps              | 2        |
# |    time_elapsed     | 79730    |
# |    total timesteps  | 163930   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.579    |
# |    n_updates        | 28482    |
# ----------------------------------
# -0.979
# start
# -0.982
# start
# -0.976
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.377    |
# | time/               |          |
# |    episodes         | 12260    |
# |    fps              | 2        |
# |    time_elapsed     | 79756    |
# |    total timesteps  | 163984   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.02     |
# |    n_updates        | 28495    |
# ----------------------------------
# -0.979
# start
# -0.9775
# start
# -0.979
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.377    |
# | time/               |          |
# |    episodes         | 12264    |
# |    fps              | 2        |
# |    time_elapsed     | 79781    |
# |    total timesteps  | 164041   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.443    |
# |    n_updates        | 28510    |
# ----------------------------------
# -0.976
# start
# -0.982
# start
# -0.9775
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.376    |
# | time/               |          |
# |    episodes         | 12268    |
# |    fps              | 2        |
# |    time_elapsed     | 79807    |
# |    total timesteps  | 164098   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.701    |
# |    n_updates        | 28524    |
# ----------------------------------
# -0.976
# start
# -0.9805
# start
# -0.9805
# start
# -0.982
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.376    |
# | time/               |          |
# |    episodes         | 12272    |
# |    fps              | 2        |
# |    time_elapsed     | 79832    |
# |    total timesteps  | 164152   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.975    |
# |    n_updates        | 28537    |
# ----------------------------------
# -0.9805
# start
# -0.9775
# start
# -0.9775
# start
# -0.9805
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.376    |
# | time/               |          |
# |    episodes         | 12276    |
# |    fps              | 2        |
# |    time_elapsed     | 79858    |
# |    total timesteps  | 164208   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.715    |
# |    n_updates        | 28551    |
# ----------------------------------
# -0.9775
# start
# -0.979
# start
# -0.9775
# start
# -0.9775
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.376    |
# | time/               |          |
# |    episodes         | 12280    |
# |    fps              | 2        |
# |    time_elapsed     | 79884    |
# |    total timesteps  | 164267   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.565    |
# |    n_updates        | 28566    |
# ----------------------------------
# -0.9775
# start
# -0.9775
# start
# -0.9805
# start
# -0.979
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.376    |
# | time/               |          |
# |    episodes         | 12284    |
# |    fps              | 2        |
# |    time_elapsed     | 79910    |
# |    total timesteps  | 164324   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.46     |
# |    n_updates        | 28580    |
# ----------------------------------
# -0.976
# start
# -0.979
# start
# -0.976
# start
# -0.976
# start
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.375    |
# | time/               |          |
# |    episodes         | 12288    |
# |    fps              | 2        |
# |    time_elapsed     | 79937    |
# |    total timesteps  | 164386   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.927    |
# |    n_updates        | 28596    |
# ----------------------------------
# -0.979
# start
# -0.976
# start
# -0.979
# start
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_8429/369890869.py in <module>
#      36     except:
#      37         print("cnat load")
# ---> 38     model.learn(total_timesteps=2500000, callback=event_callback)
#      39     model.save("dgn_flappy_mlp"+str(i))
#      40     model.save_replay_buffer("dgn_flappy_new_mlp"+str(i))
#
# ~/anaconda3/envs/shamanai/lib/python3.8/site-packages/stable_baselines3/dqn/dqn.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     239     ) -> OffPolicyAlgorithm:
#     240
# --> 241         return super(DQN, self).learn(
#     242             total_timesteps=total_timesteps,
#     243             callback=callback,
#
# ~/anaconda3/envs/shamanai/lib/python3.8/site-packages/stable_baselines3/common/off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     350
#     351         while self.num_timesteps < total_timesteps:
# --> 352             rollout = self.collect_rollouts(
#     353                 self.env,
#     354                 train_freq=self.train_freq,
#
# ~/anaconda3/envs/shamanai/lib/python3.8/site-packages/stable_baselines3/common/off_policy_algorithm.py in collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     569
#     570                 # Rescale and perform action
# --> 571                 new_obs, reward, done, infos = env.step(action)
#     572
#     573                 self.num_timesteps += 1
#
# ~/anaconda3/envs/shamanai/lib/python3.8/site-packages/stable_baselines3/common/vec_env/base_vec_env.py in step(self, actions)
#     160         """
#     161         self.step_async(actions)
# --> 162         return self.step_wait()
#     163
#     164     def get_images(self) -> Sequence[np.ndarray]:
#
# ~/anaconda3/envs/shamanai/lib/python3.8/site-packages/stable_baselines3/common/vec_env/vec_frame_stack.py in step_wait(self)
#      46     ) -> Tuple[Union[np.ndarray, Dict[str, np.ndarray]], np.ndarray, np.ndarray, List[Dict[str, Any]],]:
#      47
# ---> 48         observations, rewards, dones, infos = self.venv.step_wait()
#      49
#      50         observations, infos = self.stackedobs.update(observations, dones, infos)
#
# ~/anaconda3/envs/shamanai/lib/python3.8/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py in step_wait(self)
#      47                 # save final observation where user can get it, then reset
#      48                 self.buf_infos[env_idx]["terminal_observation"] = obs
# ---> 49                 obs = self.envs[env_idx].reset()
#      50             self._save_obs(env_idx, obs)
#      51         return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones), deepcopy(self.buf_infos))
#
# /tmp/ipykernel_8429/2351392262.py in reset(self)
#     144     def reset(self):
#     145
# --> 146         self.state = self.env.reset()
#     147         #self.reward = np.array([reward])
#     148         #self.state = self.state.tolist()
#
# /tmp/ipykernel_8429/3150230643.py in reset(self)
#     118         time.sleep(.425)
#     119         pyautogui.click(x=795, y= 219, button='left')
# --> 120         time.sleep(.425)
#     121         pyautogui.click(x=795, y= 219, button='left')
#     122         time.sleep(.425)
#
# KeyboardInterrupt:

# %%
#from stable_baselines3.common.cmd_util import make_atari_env
from stable_baselines3.common.vec_env import VecFrameStack ,DummyVecEnv, VecNormalize
from stable_baselines3 import A2C, PPO, DQN
import torch
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.callbacks import CheckpointCallback, EveryNTimesteps

# There already exists an environment generator
# that will make and wrap atari environments correctly.
# Here we are also multi-worker training (n_envs=4 => 4 environments)
env = Template_Gym()
#env = Controller_Gym(env)
env = DummyVecEnv([lambda: env])
#obs = env.reset()
# It will check your custom environment and output additional warnings if needed
#check_env(env)
#env = VecFrameStack(env,4)
#env = ScaledFloatFrame(env)
#env = MaxAndSkipEnv(env, skip=1)
#env = BufferWrapper(env, 2)
#env = DummyVecEnv(env)
#env2 = make_atari_env(env, n_envs=1, seed=0)
#Frame-stacking with 4 frames
env = VecNormalize(env)
obs = env.reset()
print(obs)
# Out:
# start
# ['bird']
# [179.2613678  282.27993774 237.72994995 335.61282349   0.
#    0.           0.           0.        ]
# [[0.00999984 0.00999994 0.00999991 0.00999996 0.         0.
#   0.         0.        ]]

# %%
testing = ImageProcess()
testing.object_detection()
# Out:
# ['bird', 'hole']
# [ 62.431435 517.1903   115.55981  565.75397  237.23041  238.50233
#  339.6007   475.2897  ]
# array([ 62.431435, 517.1903  , 115.55981 , 565.75397 , 237.23041 ,
#        238.50233 , 339.6007  , 475.2897  ], dtype=float32)
